# %%
# =========================================================
# Kernel Search (KS) for sparse quadratic SVM with CoP(K)
#   - Step (13): D-Shor-Co (MOSEK Fusion)
#   - Step (17)+(18): CoP(K) w/ indicator constraints (Gurobi)
#   * Robust changes:
#       A) ensure |K_it| >= B each iteration
#       B) provide explicit feasible MIP Start to get a finite UB fast
#       C) (optional) Gurobi params to favor feasibility
# =========================================================
from __future__ import annotations
import math
import itertools
import numpy as np
from typing import List, Dict, Tuple, Optional, Iterable

# ---------- helpers ----------
def _fmt_num(x):
    return "inf" if (x is None or not np.isfinite(x)) else f"{x:.6g}"

def _fusion_set_time_limit(M, seconds: float | None, is_mip: bool = False):
    """MOSEK Fusion time limit with fallback param names across versions."""
    if seconds is None:
        return
    try:
        import mosek
        M.setSolverParam(mosek.dparam.optimizer_max_time, float(seconds))
        if is_mip:
            M.setSolverParam(mosek.dparam.mio_max_time, float(seconds))
    except Exception:
        # textual fallbacks
        M.setSolverParam("optimizerMaxTime", float(seconds))
        if is_mip:
            M.setSolverParam("mioMaxTime", float(seconds))

def _fusion_obj_value(M):
    """Get MOSEK objective value in a version-compatible way."""
    try:
        return float(M.primalObjValue())
    except Exception:
        return float(M.objectiveValue())

def _ensure_kernel_size(order: np.ndarray | List[int], K_it: List[int], B: int, extra: int = 0) -> List[int]:
    """
    Ensure |K_it| >= B (and optionally >= B+extra) by augmenting with the best-ranked
    features from 'order' that are not yet in K_it.
    """
    want = max(B + extra, len(K_it))
    Kset = set(int(j) for j in K_it)
    for idx in list(order):
        if len(Kset) >= want:
            break
        if int(idx) not in Kset:
            Kset.add(int(idx))
    return sorted(Kset)

# ---------- 0) 二次映射（显式） ----------
def quad_map(X: np.ndarray):
    """
    返回：Phi_diag (m×n), Phi_cross_list (list of length P, 每个 m-vector), pairs (索引对列表)
    二次映射采用：phi(x) = [ x_1^2, ..., x_n^2, sqrt(2)*x_1x_2, ... ]
    """
    m, n = X.shape
    Phi_diag = X ** 2
    pairs = list(itertools.combinations(range(n), 2))
    sqrt2 = np.sqrt(2.0)
    Phi_cross_list = [sqrt2 * (X[:, i] * X[:, j]) for (i, j) in pairs]
    return Phi_diag, Phi_cross_list, pairs

# ---------- 1) (13) D-Shor-Co by MOSEK (逐样本约束，避免维度问题) ----------
def solve_dshor_co_mosek(
    X: np.ndarray, y: np.ndarray, B: int, C: float,
    time_limit: Optional[float] = None, verbose: bool = False
) -> Dict:
    """
    近似实现 (13)：min 0.5*sum(Wjj) + C*sum xi
    s.t. y_i (b + sum_j w_j * x_{ij}^2) >= 1 - xi_i
         xi >= 0
         0 <= t <= 1,  sum t = n - B
         w_j^2 <= Wjj   (用 rotated QC)
    备注：margin 只用对角基（x_j^2）。
    """
    try:
        import mosek.fusion as mf
    except Exception as e:
        raise RuntimeError("需要安装 MOSEK（mosek, mosek.fusion）。") from e

    m, n = X.shape
    Phi_diag, _, _ = quad_map(X)

    M = mf.Model("DShorCo")
    if not verbose:
        M.setLogHandler(None)
    _fusion_set_time_limit(M, time_limit, is_mip=False)

    # 变量
    w  = M.variable("w",  n, mf.Domain.unbounded())
    Wd = M.variable("Wd", n, mf.Domain.greaterThan(0.0))        # diag(W)
    b  = M.variable("b",  1, mf.Domain.unbounded())
    xi = M.variable("xi", m, mf.Domain.greaterThan(0.0))
    t  = M.variable("t",  n, mf.Domain.inRange(0.0, 1.0))

    # 预算 e^T t = n - B
    M.constraint(mf.Expr.sum(t), mf.Domain.equalsTo(float(n - B)))

    # w_j^2 <= Wjj  —— 旋转二阶锥：2*x*y >= z^2，取 x=Wd[j], y=0.5, z=w[j]
    half = mf.Expr.constTerm(1, 0.5)
    for j in range(n):
        M.constraint(mf.Expr.hstack(Wd.index(j), half, w.index(j)), mf.Domain.inRotatedQCone())

    # margin：逐样本 y_i*(b + <phi_i, w>) >= 1 - xi_i
    A = mf.Matrix.dense(Phi_diag)          # m×n
    sAw = mf.Expr.mul(A, w)                # 长度 m 的表达式向量
    for i in range(m):
        lhs = mf.Expr.mul(float(y[i]), mf.Expr.add(sAw.index(i), b))  # 标量
        M.constraint(mf.Expr.sub(lhs, mf.Expr.sub(1.0, xi.index(i))), mf.Domain.greaterThan(0.0))

    # 目标：0.5*sum(Wd) + C*sum(xi)
    obj = mf.Expr.add( mf.Expr.mul(0.5, mf.Expr.sum(Wd)), mf.Expr.mul(C, mf.Expr.sum(xi)) )
    M.objective(mf.ObjectiveSense.Minimize, obj)

    M.solve()
    objval = _fusion_obj_value(M)

    sol = {
        "status": str(M.getPrimalSolutionStatus()),
        "objval": objval,
        "t": np.array(t.level()).reshape(-1),
        "w": np.array(w.level()).reshape(-1),
        "Wd": np.array(Wd.level()).reshape(-1),
    }
    M.dispose()
    return sol

# ---------- 2) CoP(K)（Gurobi：指示约束，无 Big-M，含可行 MIP Start） ----------
def build_and_solve_cop_kernel(
    X: np.ndarray, y: np.ndarray, B: int, C: float,
    feature_names: Optional[List[str]],
    kernel_set: Iterable[int],        # 当前允许“可能被选”的原始特征索引集合 K_it
    UB: Optional[float],              # 若给定，则加入 (17)：0.5||w||^2 + CΣxi <= UB
    time_limit: float = 120.0,
    mipgap: Optional[float] = None,
    verbose: bool = False,
    start_idx: Optional[List[int]] = None,   # ★ 新增：MIP Start（优先用历史最优，否则 K_it 前B）
    favor_feasible: bool = True              # ★ 可选：更有利于先找到可行解
) -> Dict:
    """
    原始 CoP(K)：使用“指示约束”实现 t_j=1=>w_j=0, (t_i=1 or t_j=1)=>w_ij=0
    仅允许 kernel_set 中的原始特征被启用（其余 t_j 固定为 1）。
    附加 (17)(18)：
      (17) 0.5||w||^2 + CΣxi <= UB   （若 UB 非空）
      (18) Σ_{j∈K_it} t_j <= |K_it| - 1  （至少选 K_it 中的一个）
    """
    import gurobipy as gp
    from gurobipy import GRB

    m, n = X.shape
    Phi_diag, Phi_cross_list, pairs = quad_map(X)
    P = len(pairs)

    model = gp.Model("CoP_KS")
    model.Params.OutputFlag = 1 if verbose else 0
    model.Params.TimeLimit = time_limit
    if mipgap is not None:
        model.Params.MIPGap = mipgap
    # 可行解友好（可选）
    if favor_feasible:
        model.Params.MIPFocus = 1      # 优先找可行解
        model.Params.Heuristics = 0.5
        model.Params.Presolve = 2
        model.Params.Cuts = 1
    model.Params.Seed = 0

    # 变量
    w_diag  = model.addVars(n, lb=-GRB.INFINITY, vtype=GRB.CONTINUOUS, name="w_sq")
    w_cross = model.addVars(P, lb=-GRB.INFINITY, vtype=GRB.CONTINUOUS, name="w_cross")
    b       = model.addVar(lb=-GRB.INFINITY, vtype=GRB.CONTINUOUS, name="b")
    xi      = model.addVars(m, lb=0.0, vtype=GRB.CONTINUOUS, name="xi")
    t       = model.addVars(n, vtype=GRB.BINARY, name="t")  # 1=禁用

    # 指示：t_j=1 ⇒ w_diag_j=0
    for j in range(n):
        t[j].BranchPriority = 10
        model.addGenConstrIndicator(t[j], 1, w_diag[j], GRB.EQUAL, 0.0, name=f"diag_zero_{j}")

    # 指示：t_i=1 or t_j=1 ⇒ w_cross_ij=0
    for k, (i, j) in enumerate(pairs):
        model.addGenConstrIndicator(t[i], 1, w_cross[k], GRB.EQUAL, 0.0, name=f"cross_i_zero_{k}")
        model.addGenConstrIndicator(t[j], 1, w_cross[k], GRB.EQUAL, 0.0, name=f"cross_j_zero_{k}")

    # 预算：sum t = n - B
    model.addConstr(gp.quicksum(t[j] for j in range(n)) == n - B, name="budget")

    # margin 逐样本
    for i in range(m):
        expr = b
        for j in range(n):
            expr += w_diag[j] * float(Phi_diag[i, j])
        for k in range(P):
            expr += w_cross[k] * float(Phi_cross_list[k][i])
        model.addConstr(float(y[i]) * expr >= 1.0 - xi[i], name=f"margin_{i}")

    # (18) 至少选 K_it 中的一个：sum t_j <= |K|-1
    K_it = sorted(set(int(j) for j in kernel_set))
    if len(K_it) > 0:
        model.addConstr(gp.quicksum(t[j] for j in K_it) <= len(K_it) - 1, name="atleast_one_in_kernel")

    # 强制：非 kernel_set 的特征一律禁用（t_j=1）
    outside = sorted(set(range(n)) - set(K_it))
    for j in outside:
        model.addConstr(t[j] == 1, name=f"fix_outside_{j}")

    # 目标与 (17) 上界约束
    quad = gp.QuadExpr()
    for j in range(n): quad += w_diag[j] * w_diag[j]
    for k in range(P): quad += w_cross[k] * w_cross[k]
    obj = 0.5 * quad + C * gp.quicksum(xi[i] for i in range(m))
    model.setObjective(obj, GRB.MINIMIZE)
    if (UB is not None) and np.isfinite(UB):
        model.addQConstr(obj <= UB + 1e-9, name="obj_ub")  # (17)

    # ---------- ★ MIP Start：强制给出可行解，确保立刻有有限 UB ----------
    # 先全部禁用，再在 K_it 中挑 B 个置 0
    for j in range(n):
        t[j].Start = 1
    seed = (start_idx if (start_idx is not None and len(start_idx)>0) else K_it)[:min(B, len(K_it))]
    for j in seed:
        t[j].Start = 0
    # 连续变量的平凡可行值：w=0, b=0, xi=1  => y_i*(0) >= 1-1 == 0  ✔
    b.Start = 0.0
    for j in range(n):
        w_diag[j].Start = 0.0
    for k in range(P):
        w_cross[k].Start = 0.0
    for i in range(m):
        xi[i].Start = 1.0
    # ---------------------------------------------------------------

    # 求解
    model.optimize()
    sol = {
        "status": model.Status,
        "runtime": model.Runtime,
        "objval": model.ObjVal if model.SolCount > 0 else None,
        "gap": model.MIPGap if model.SolCount > 0 else None,
        "selected_idx": [],
        "selected_features": [],
        "t": None
    }
    if model.SolCount > 0:
        idx = [j for j in range(n) if t[j].X < 0.5]  # t=0 ⇒ 选中
        sol["selected_idx"] = idx
        if feature_names:
            sol["selected_features"] = [feature_names[j] for j in idx]
        sol["t"] = np.array([t[j].X for j in range(n)])
    return sol

# ---------- 3) Kernel Search 主流程（含 |K_it|≥B 与 MIP Start） ----------
def kernel_search(
    X: np.ndarray, y: np.ndarray, B: int, C: float, rho: int,
    feature_names: Optional[List[str]] = None,
    # 解器参数
    mosek_time: Optional[float] = None,
    mip_time: float = 120.0,
    mip_gap: Optional[float] = None,
    verbose: bool = True
) -> Dict:
    """
    输入：X (m×n), y∈{-1,+1}^m, 预算 B, 正则 C, 参数 rho（每组大小）
    步骤：
      1) 解 D-Shor-Co（13），得到 t* 并按升序对特征排序
      2) 把排序结果均匀分成 N=ceil(n/rho) 组 K1..KN
      3) 迭代 k=1..N：
           K_it := ensure_size(K_k ∪ K_bar)  # ★ 确保 |K_it|≥B
           以历史最优作为 start_idx（否则用 K_it 前B），解 CoP(K_it) + (17)(18)
           若可行：更新 UB、K^+、K^-、K_bar
    输出：最优可行解（特征集合）与 UB
    """
    m, n = X.shape
    # 1) D-Shor-Co
    rel = solve_dshor_co_mosek(X, y, B=B, C=C, time_limit=mosek_time, verbose=verbose)
    t_relax = rel["t"]
    order = np.argsort(t_relax)  # 越小越“该选”
    if verbose:
        print(f"[D-Shor-Co] obj={_fmt_num(rel['objval'])}  t_min..max=({_fmt_num(float(t_relax.min()))}, {_fmt_num(float(t_relax.max()))})")

    # 2) 分组
    rho = max(1, min(rho, n))
    N = math.ceil(n / rho)
    groups = [order[i*rho : min((i+1)*rho, n)].tolist() for i in range(N)]
    if verbose:
        print(f"[KS] n={n}, rho={rho}  => N={N} groups (each ≤{rho})")

    # 3) 迭代
    K_bar: List[int] = []           # 累积核
    stale: Dict[int, int] = {}      # 不被选中的迭代次数
    UB = np.inf
    best = {"objval": np.inf, "selected_idx": [], "selected_features": []}

    for k in range(N):
        K_k = groups[k]
        K_it_raw = sorted(set(K_k) | set(K_bar))
        # ★ A) 确保 |K_it| ≥ B（也可给点冗余 extra）
        K_it = _ensure_kernel_size(order, K_it_raw, B, extra=max(1, B//2))

        if verbose:
            print(f"[KS] iter {k+1}/{N}  |K_k|={len(K_k)}  |K_bar|={len(K_bar)}  |K_it|={len(K_it)}  UB={_fmt_num(UB)}")

        # ★ B) 选择 MIP Start（优先历史最优，否则 K_it 前B）
        seed = best["selected_idx"] if best["selected_idx"] else K_it[:B]

        sol = build_and_solve_cop_kernel(
            X, y, B, C, feature_names=feature_names,
            kernel_set=K_it,
            UB=UB,
            time_limit=mip_time,
            mipgap=mip_gap,
            verbose=verbose,
            start_idx=seed,              # ★ 传入 MIP Start
            favor_feasible=True          # ★ 更友好可行解
        )

        if sol["objval"] is None:
            if verbose:
                print("   -> infeasible or no incumbent under limits.")
            # 若不可行，可适度扩大 K_it 或放宽 gap/time，下次迭代继续
            continue

        # 可行：更新上界与最优
        UB = min(UB, sol["objval"])
        if sol["objval"] < best["objval"]:
            best = {"objval": sol["objval"],
                    "selected_idx": sol["selected_idx"],
                    "selected_features": sol["selected_features"]}
        sel_set = set(sol["selected_idx"])

        # K^+ ：本轮 K_k 中被选的
        K_plus = [j for j in K_k if j in sel_set]
        # K^- ：K_bar 中连续两轮未被选的（这里用 stale>=1 的简化版）
        K_minus = [j for j in K_bar if j not in sel_set and stale.get(j, 0) >= 1]

        # 更新 stale 计数
        for j in K_bar:
            stale[j] = 0 if j in sel_set else stale.get(j, 0) + 1

        # 更新 K_bar
        K_bar = sorted(set(K_bar).union(K_plus) - set(K_minus))

        if verbose:
            print(f"   -> obj={sol['objval']:.6g},  |K^+|={len(K_plus)},  |K^-|={len(K_minus)},  |K_bar|={len(K_bar)}")

    if verbose:
        print("[KS] DONE.  best obj=", _fmt_num(best["objval"]), "  |S|=", len(best["selected_idx"]))
    return {
        "UB": float(UB),
        "best_obj": (float(best["objval"]) if np.isfinite(best["objval"]) else None),
        "selected_idx": list(best["selected_idx"]),
        "selected_features": list(best.get("selected_features", [])),
        "best": best  # 兼容旧用法（里面有 objval/selected_idx/selected_features）
    }

# %%
# --- 放在文件前面工具区 ---
def _fusion_obj_value(M):
    """取 MOSEK Fusion 的目标值，兼容不同版本接口。"""
    try:
        return float(M.primalObjValue())   # 常用
    except Exception:
        return float(M.objectiveValue())   # 备用

# %%
def _fmt_num(x):
    return "inf" if (x is None or not np.isfinite(x)) else f"{x:.6g}"

# %%
# =========================================================
# Heuristic procedure (Algorithm 3) using Kernel Search (Alg. 2)
#   (13) D-Shor-Co  .......... MOSEK Fusion (conic)
#   (19) bound M_j^l / M_j^u . MOSEK Fusion (conic) with UB
#   (14) D-Shor-Co-BigM ...... MOSEK Fusion (MISOCP, diag part for warm start)
#   CoP(K) ................... Gurobi (indicator constraints, full quadratic map)
# =========================================================
from __future__ import annotations
import math
import itertools
import numpy as np
from typing import List, Dict, Optional, Iterable

# -------------------- explicit quadratic map --------------------
def quad_map(X: np.ndarray):
    """
    phi(x) = [ x_1^2, ..., x_n^2, sqrt(2)*x_1x_2, ..., sqrt(2)*x_{n-1}x_n ]
    返回：
      Phi_diag: m×n  （平方项）
      Phi_cross_list: 长度 P 的 list，每个是 m-vector（交叉项）
      pairs: P 个 (i,j) 索引对，与 Phi_cross_list 对应
    """
    m, n = X.shape
    Phi_diag = X ** 2
    pairs = list(itertools.combinations(range(n), 2))
    sqrt2 = np.sqrt(2.0)
    Phi_cross_list = [sqrt2 * (X[:, i] * X[:, j]) for (i, j) in pairs]
    return Phi_diag, Phi_cross_list, pairs

# -------------------- objective helper --------------------
def obj_value(w_diag: np.ndarray, w_cross: np.ndarray, xi: np.ndarray, C: float) -> float:
    return 0.5 * (float(np.dot(w_diag, w_diag)) + float(np.dot(w_cross, w_cross))) + C * float(np.sum(xi))

# -------------------- Fusion time-limit helper --------------------
def _fusion_set_time_limit(M, seconds: float | None, is_mip: bool = False):
    """
    给 MOSEK Fusion 模型设定时间上限；兼容不同版本。
    - is_mip=True 时，同时对 MIP 专用和全局优化器时间都限时。
    """
    if seconds is None:
        return
    try:
        import mosek
        M.setSolverParam(mosek.dparam.optimizer_max_time, float(seconds))
        if is_mip:
            M.setSolverParam(mosek.dparam.mio_max_time, float(seconds))
    except Exception:
        M.setSolverParam("optimizerMaxTime", float(seconds))
        if is_mip:
            M.setSolverParam("mioMaxTime", float(seconds))

# =========================================================
# (13) D-Shor-Co (MOSEK) —— 使用对角二次基，足够用于 KS 排序
# =========================================================
def solve_dshor_co_mosek(X: np.ndarray, y: np.ndarray, B: int, C: float,
                         time_limit: Optional[float] = None, verbose: bool = False) -> Dict:
    import mosek.fusion as mf
    m, n = X.shape
    Phi_diag, _, _ = quad_map(X)

    M = mf.Model("DShorCo")
    if not verbose: M.setLogHandler(None)
    _fusion_set_time_limit(M, time_limit, is_mip=False)

    w  = M.variable("w",  n, mf.Domain.unbounded())
    Wd = M.variable("Wd", n, mf.Domain.greaterThan(0.0))
    b  = M.variable("b",  1, mf.Domain.unbounded())
    xi = M.variable("xi", m, mf.Domain.greaterThan(0.0))
    t  = M.variable("t",  n, mf.Domain.inRange(0.0, 1.0))

    M.constraint(mf.Expr.sum(t), mf.Domain.equalsTo(float(n - B)))

    half = mf.Expr.constTerm(1, 0.5)
    for j in range(n):
        M.constraint(mf.Expr.hstack(Wd.index(j), half, w.index(j)), mf.Domain.inRotatedQCone())

    A = mf.Matrix.dense(Phi_diag)
    sAw = mf.Expr.mul(A, w)
    for i in range(m):
        lhs = mf.Expr.mul(y[i], mf.Expr.add(sAw.index(i), b))
        M.constraint(mf.Expr.sub(lhs, mf.Expr.sub(1.0, xi.index(i))), mf.Domain.greaterThan(0.0))

    obj = mf.Expr.add(mf.Expr.mul(0.5, mf.Expr.sum(Wd)), mf.Expr.mul(C, mf.Expr.sum(xi)))
    M.objective(mf.ObjectiveSense.Minimize, obj)
    M.solve()

    objval = _fusion_obj_value(M)  # ★ 改这里

    sol = {
        "status": str(M.getPrimalSolutionStatus()),
        "objval": objval,                                 # ★ 改这里
        "t": np.array(t.level()).reshape(-1),
        "w": np.array(w.level()).reshape(-1),
        "Wd": np.array(Wd.level()).reshape(-1),
    }
    M.dispose()
    return sol

def compute_M_by_prop41(X: np.ndarray, y: np.ndarray, B: int, C: float, UB: float,
                        time_per_bound: Optional[float] = None, verbose: bool = False) -> float:
    """
    命题 4.1：M = max_j max{|M_j^l|, |M_j^u|}
    其中 M_j^l = min w_j, M_j^u = max w_j，均在 (19) 约束下求解。
    """
    n = X.shape[1]
    Ms = []
    for j in range(n):
        lo = bound_wj_mosek(X, y, B, C, UB, j, "min", time_limit=time_per_bound, verbose=verbose)
        hi = bound_wj_mosek(X, y, B, C, UB, j, "max", time_limit=time_per_bound, verbose=verbose)
        Ms.append(max(abs(lo), abs(hi)))
        if verbose:
            print(f"[Prop4.1] j={j}  lo={lo:.6g}  hi={hi:.6g}  max={Ms[-1]:.6g}")
    M = float(np.max(Ms))
    if verbose:
        print(f"[Prop4.1] M = {M:.6g}")
    return M

# =========================================================
# (1) l2-NLSVM（对角+交叉二次显式映射） —— MOSEK（凸二次）
# =========================================================
def solve_l2_nlsvm_mosek(X: np.ndarray, y: np.ndarray, C: float,
                         time_limit: Optional[float] = None, verbose: bool = False) -> Dict:
    try:
        import mosek
        import mosek.fusion as mf
    except Exception as e:
        raise RuntimeError("请先安装 MOSEK 与 mosek.fusion。") from e

    m, n = X.shape
    Phi_diag, Phi_cross_list, pairs = quad_map(X)
    P = len(pairs)
    Phi_cross = np.vstack([pc for pc in Phi_cross_list]).T if P > 0 else np.zeros((m, 0))

    M = mf.Model("l2-NLSVM")
    if not verbose:
        M.setLogHandler(None)
    _fusion_set_time_limit(M, time_limit, is_mip=False)

    w_d = M.variable("w_d", n, mf.Domain.unbounded())
    w_c = M.variable("w_c", P, mf.Domain.unbounded()) if P > 0 else None
    b   = M.variable("b", 1, mf.Domain.unbounded())
    xi  = M.variable("xi", m, mf.Domain.greaterThan(0.0))

    # margin: for each i, y_i*(b + <phi_diag_i, w_d> + <phi_cross_i, w_c>) >= 1 - xi_i
    A_d = mf.Matrix.dense(Phi_diag)
    s_d = mf.Expr.mul(A_d, w_d)  # length m
    if P > 0:
        A_c = mf.Matrix.dense(Phi_cross)
        s_c = mf.Expr.mul(A_c, w_c)  # length m
        s = mf.Expr.add(s_d, s_c)
    else:
        s = s_d
    for i in range(m):
        lhs = mf.Expr.mul(y[i], mf.Expr.add(s.index(i), b))
        M.constraint(mf.Expr.sub(lhs, mf.Expr.sub(1.0, xi.index(i))), mf.Domain.greaterThan(0.0))

    # 目标：0.5*(||w_d||^2 + ||w_c||^2) + C*sum xi
    quad_norm = mf.Expr.dot(w_d, w_d)
    if P > 0:
        quad_norm = mf.Expr.add(quad_norm, mf.Expr.dot(w_c, w_c))
    obj = mf.Expr.add(mf.Expr.mul(0.5, quad_norm), mf.Expr.mul(C, mf.Expr.sum(xi)))
    M.objective(mf.ObjectiveSense.Minimize, obj)
    M.solve()

    w_diag = np.array(w_d.level()).reshape(-1)
    w_cross = np.array(w_c.level()).reshape(-1) if P > 0 else np.zeros(P)
    bval = float(b.level()[0])
    xi_v = np.array(xi.level()).reshape(-1)
    M.dispose()
    return {
        "w_diag": w_diag, "w_cross": w_cross, "b": bval, "xi": xi_v,
        "obj": obj_value(w_diag, w_cross, xi_v, C),
        "l1_over_B": float(np.sum(np.abs(np.r_[w_diag, w_cross]))) / max(1, X.shape[1])
    }

# =========================================================
# (14) D-Shor-Co-BigM（MOSEK, MISOCP, diag-only，用作启发式起点）
# =========================================================
def solve_dshor_co_bigm_mosek(X: np.ndarray, y: np.ndarray, B: int, C: float, Mbig: float,
                              time_limit: Optional[float] = None, verbose: bool = False) -> Dict:
    import mosek.fusion as mf
    m, n = X.shape
    Phi_diag, _, _ = quad_map(X)

    M = mf.Model("DShorCoBigM")
    if not verbose: M.setLogHandler(None)
    _fusion_set_time_limit(M, time_limit, is_mip=True)

    w  = M.variable("w",  n, mf.Domain.unbounded())
    Wd = M.variable("Wd", n, mf.Domain.greaterThan(0.0))
    b  = M.variable("b",  1, mf.Domain.unbounded())
    xi = M.variable("xi", m, mf.Domain.greaterThan(0.0))
    t  = M.variable("t",  n, mf.Domain.binary())

    M.constraint(mf.Expr.sum(t), mf.Domain.equalsTo(float(n - B)))

    one = mf.Expr.ones(n)
    M.constraint(mf.Expr.sub(w, mf.Expr.mul(Mbig, mf.Expr.sub(one, t))), mf.Domain.lessThan(0.0))
    M.constraint(mf.Expr.add(w, mf.Expr.mul(Mbig, mf.Expr.sub(one, t))), mf.Domain.greaterThan(0.0))

    half = mf.Expr.constTerm(1, 0.5)
    for j in range(n):
        M.constraint(mf.Expr.hstack(Wd.index(j), half, w.index(j)), mf.Domain.inRotatedQCone())

    A = mf.Matrix.dense(Phi_diag)
    sAw = mf.Expr.mul(A, w)
    for i in range(m):
        lhs = mf.Expr.mul(y[i], mf.Expr.add(sAw.index(i), b))
        M.constraint(mf.Expr.sub(lhs, mf.Expr.sub(1.0, xi.index(i))), mf.Domain.greaterThan(0.0))

    obj = mf.Expr.add(mf.Expr.mul(0.5, mf.Expr.sum(Wd)), mf.Expr.mul(C, mf.Expr.sum(xi)))
    M.objective(mf.ObjectiveSense.Minimize, obj)
    M.solve()

    objval = _fusion_obj_value(M)  # ★ 改这里

    sol = {
        "status": str(M.getPrimalSolutionStatus()),
        "t": np.array(t.level()).reshape(-1),
        "w": np.array(w.level()).reshape(-1),
        "obj": objval,                                   # ★ 改这里
    }
    M.dispose()
    return sol

# =========================================================
# CoP(K) (Gurobi) —— 指示约束，返回完整解 (w,b,xi,t)
# =========================================================
def solve_cop_kernel_gurobi(X: np.ndarray, y: np.ndarray, B: int, C: float,
                            kernel_set: Iterable[int], UB: Optional[float],
                            time_limit: float = 120.0, mipgap: Optional[float] = None,
                            verbose: bool = False, feature_names: Optional[List[str]] = None) -> Dict:
    import gurobipy as gp
    from gurobipy import GRB

    m, n = X.shape
    Phi_diag, Phi_cross_list, pairs = quad_map(X)
    P = len(pairs)

    model = gp.Model("CoP_K")
    model.Params.OutputFlag = 1 if verbose else 0
    model.Params.TimeLimit = time_limit
    if mipgap is not None:
        model.Params.MIPGap = mipgap
    model.Params.Seed = 0  # 可复现

    w_d  = model.addVars(n, lb=-GRB.INFINITY, vtype=GRB.CONTINUOUS, name="w_d")
    w_c  = model.addVars(P, lb=-GRB.INFINITY, vtype=GRB.CONTINUOUS, name="w_c")
    b    = model.addVar(lb=-GRB.INFINITY, vtype=GRB.CONTINUOUS, name="b")
    xi   = model.addVars(m, lb=0.0, vtype=GRB.CONTINUOUS, name="xi")
    t    = model.addVars(n, vtype=GRB.BINARY, name="t")  # 1=禁用

    # 指示约束：若 t_j=1，则 w_d[j]=0；交叉项同理
    for j in range(n):
        model.addGenConstrIndicator(t[j], 1, w_d[j], GRB.EQUAL, 0.0)
    for k, (i, j) in enumerate(pairs):
        model.addGenConstrIndicator(t[i], 1, w_c[k], GRB.EQUAL, 0.0)
        model.addGenConstrIndicator(t[j], 1, w_c[k], GRB.EQUAL, 0.0)

    # 预算
    model.addConstr(gp.quicksum(t[j] for j in range(n)) == n - B)

    # margin 逐样本
    for i in range(m):
        expr = b
        for j in range(n):
            expr += w_d[j] * float(Phi_diag[i, j])
        for k in range(P):
            expr += w_c[k] * float(Phi_cross_list[k][i])
        model.addConstr(float(y[i]) * expr >= 1.0 - xi[i])

    # (18) 至少从 kernel_set 里选一个
    K = sorted(set(int(j) for j in kernel_set))
    if K:
        model.addConstr(gp.quicksum(t[j] for j in K) <= len(K) - 1)

    # 固定核外特征禁用
    outside = sorted(set(range(n)) - set(K))
    for j in outside:
        model.addConstr(t[j] == 1)

    # 目标
    quad = gp.QuadExpr()
    for j in range(n): quad += w_d[j] * w_d[j]
    for k in range(P): quad += w_c[k] * w_c[k]
    obj = 0.5 * quad + C * gp.quicksum(xi[i] for i in range(m))
    model.setObjective(obj, GRB.MINIMIZE)
    if (UB is not None) and np.isfinite(UB):
        model.addQConstr(obj <= UB + 1e-9)

    model.optimize()

    sol = {
        "status": model.Status,
        "runtime": model.Runtime,
        "gap": model.MIPGap if model.SolCount > 0 else None,
        "obj": model.ObjVal if model.SolCount > 0 else None,
        "t": None,
        "selected_idx": [],
        "w_diag": None, "w_cross": None, "b": None, "xi": None
    }
    if model.SolCount > 0:
        tvec = np.array([t[j].X for j in range(n)])
        idx  = [j for j in range(n) if t[j].X < 0.5]  # t=0 selected
        w_dv = np.array([w_d[j].X for j in range(n)])
        w_cv = np.array([w_c[k].X for k in range(P)])
        bval = float(b.X)
        xiv  = np.array([xi[i].X for i in range(m)])
        sol.update(dict(t=tvec, selected_idx=idx, w_diag=w_dv, w_cross=w_cv, b=bval, xi=xiv))
        if feature_names:
            sol["selected_features"] = [feature_names[j] for j in idx]
    return sol



# =========================================================
# Algorithm 3: Heuristic procedure（全部使用 Algorithm 2）
# =========================================================
def heuristic_procedure_algo3(
    X: np.ndarray, y: np.ndarray, B: int, C: float,
    rho: int,
    ks_mosek_time: Optional[float] = 30.0,
    ks_mip_time: float = 60.0,
    ks_mip_gap: Optional[float] = 0.03,
    bound_time_per_j: Optional[float] = 10.0,
    l2_time: Optional[float] = 60.0,
    bigm_time: Optional[float] = 120.0,
    verbose: bool = True,
    feature_names: Optional[List[str]] = None
) -> Dict:
    # Step 2: KS#1
    ks1 = kernel_search(X, y, B, C, rho,
                        mosek_time=ks_mosek_time, mip_time=ks_mip_time, mip_gap=ks_mip_gap,
                        verbose=verbose, feature_names=feature_names)
    UB_hat = ks1["UB"]
    best   = ks1["best"]
    if verbose:
        print(f"[Alg3] KS#1 done: UB_hat={ 'inf' if not np.isfinite(UB_hat) else f'{UB_hat:.6g}' }, |S|={len(best['idx'])}")

    # 先把当前最优 UB 设成 KS#1 的 UB
    UB_star = UB_hat

    # ---------- NEW: 为 (19) 准备一个有限的 UB ----------
    l2_cached = None
    UB_for_bounds = UB_hat
    if not np.isfinite(UB_for_bounds):
        if verbose:
            print("[Alg3] KS 未得到有限 UB，尝试用 l2-NLSVM 生成 fallback UB...")
        try:
            l2_cached = solve_l2_nlsvm_mosek(X, y, C, time_limit=l2_time, verbose=verbose)
            UB_for_bounds = float(l2_cached["obj"])
            if verbose:
                print(f"[Alg3] Fallback UB from l2-NLSVM = {UB_for_bounds:.6g}")
            # 同时用它更新 UB_star（更好的上界）
            UB_star = UB_for_bounds
        except Exception as e:
            if verbose:
                print(f"[Alg3] l2-NLSVM 失败（{e}），将跳过 Big-M 步。")
            UB_for_bounds = np.nan  # 标记为不可用
    # ----------------------------------------------------

    # Step 4: 依据命题 4.1 计算 Big-M（仅当 UB 可用）
    M_val = None
    if np.isfinite(UB_for_bounds):
        M_val = compute_M_by_prop41(X, y, B, C, UB_for_bounds,
                                    time_per_bound=bound_time_per_j, verbose=verbose)
    else:
        if verbose:
            print("[Alg3] 无有限 UB，跳过 Big-M 边界计算与后续 Big-M → KS#2 流程。")
        # 直接输出 KS#1 的结果
        out = {
            "UB": UB_star,
            "w_diag": best["w_diag"], "w_cross": best["w_cross"], "b": best["b"], "xi": best["xi"],
            "selected_idx": best["idx"],
        }
        if feature_names:
            out["selected_features"] = [feature_names[j] for j in best["idx"]]
        return out

    # Step 5: 解 (1) l2-NLSVM（若前面已算，用缓存）
    if l2_cached is not None:
        l2 = l2_cached
    else:
        l2 = solve_l2_nlsvm_mosek(X, y, C, time_limit=l2_time, verbose=verbose)
    l1_over_B = float(np.sum(np.abs(np.r_[l2["w_diag"], l2["w_cross"]]))) / max(1, B)
    if verbose:
        print(f"[Alg3] l2-NLSVM obj={l2['obj']:.6g},  ||w||_1/B = {l1_over_B:.6g}  vs  M = {M_val:.6g}")

    # Step 6: 判断
    if (M_val is not None) and (M_val < l1_over_B):
        # Step 7: 用 Big-M 求一个起点
        bigm = solve_dshor_co_bigm_mosek(X, y, B, C, Mbig=M_val, time_limit=bigm_time, verbose=verbose)
        t0 = bigm["t"]
        init_sel = [j for j in range(X.shape[1]) if t0[j] < 0.5]
        if verbose:
            print(f"[Alg3] DShorCo-BigM done: |u*|={len(init_sel)}, obj={bigm['obj']:.6g}")

        # Step 8: KS#2
        ks2 = kernel_search(X, y, B, C, rho,
                            init_kernel=init_sel, init_UB=UB_star,
                            mosek_time=ks_mosek_time, mip_time=ks_mip_time, mip_gap=ks_mip_gap,
                            verbose=verbose, feature_names=feature_names)
        UB_bar = ks2["UB"]
        if verbose:
            print(f"[Alg3] KS#2 done: UB_bar={ 'inf' if not np.isfinite(UB_bar) else f'{UB_bar:.6g}' }, |S|={len(ks2['best']['idx'])}")

        if (UB_bar is not None) and np.isfinite(UB_bar) and (UB_bar <= UB_star):
            best = ks2["best"]
            UB_star = UB_bar
            if verbose:
                print(f"[Alg3] Accept KS#2 solution. New UB={UB_star:.6g}")
    else:
        if verbose:
            print("[Alg3] M ≥ ||w||_1/B，不触发 Big-M → KS#2；沿用 KS#1 解。")

    # 输出
    out = {
        "UB": UB_star,
        "w_diag": best["w_diag"], "w_cross": best["w_cross"], "b": best["b"], "xi": best["xi"],
        "selected_idx": best["idx"],
    }
    if feature_names:
        out["selected_features"] = [feature_names[j] for j in best["idx"]]
    return out

# %%
import numpy as np
import pandas as pd
from gurobipy import Model, GRB, quicksum
from sklearn.metrics.pairwise import rbf_kernel
from ucimlrepo import fetch_ucirepo
import time

# %%
from ucimlrepo import fetch_ucirepo
import pandas as pd
from sklearn.preprocessing import StandardScaler

breast_cancer = fetch_ucirepo(id=15)
X_df = breast_cancer.data.features.replace('?', np.nan).dropna()
y_series = breast_cancer.data.targets['Class'].loc[X_df.index]
feature_names = list(X_df.columns)
X = StandardScaler().fit_transform(X_df.values)
y_int = pd.to_numeric(y_series, errors='raise').values
y = np.where(y_int == 2, 1.0, -1.0)  # 2→+1, 4→-1

B, C, rho = 5, 1.0, 4
res = kernel_search(
    X, y, B, C, rho,
    feature_names=feature_names,
    mosek_time=20.0,   # D-Shor-Co 限时
    mip_time=60.0,     # CoP(K) 限时
    mip_gap=0.03,
    verbose=True
)
print("UB:", res["UB"])
print("best obj:", res["best_obj"])
print("selected:", res.get("selected_features", res["selected_idx"]))
# Out:
# [D-Shor-Co] obj=87.9394  t_min..max=(0.444444, 0.444444)
# [KS] n=9, rho=4  => N=3 groups (each ≤4)
# [KS] iter 1/3  |K_k|=4  |K_bar|=0  |K_it|=7  UB=inf
# Set parameter Username
# Set parameter LicenseID to value 2629579
# Academic license - for non-commercial use only - expires 2026-02-28
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 60
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  60
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 687 rows, 738 columns and 32119 nonzeros
# Model fingerprint: 0x1328cec4
# Model has 45 quadratic objective terms
# Model has 81 simple general constraints
#   81 INDICATOR
# Variable types: 729 continuous, 9 integer (9 binary)
# Coefficient statistics:
#   Matrix range     [2e-03, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+00]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# Loaded user MIP start with objective 683
#
# Presolve removed 343 rows and 359 columns
# Presolve time: 0.03s
# Presolved: 344 rows, 379 columns, 10297 nonzeros
# Presolved model has 49 SOS constraint(s)
# Presolved model has 28 quadratic objective terms
# Variable types: 372 continuous, 7 integer (7 binary)
# Root relaxation presolved: 343 rows, 372 columns, 10290 nonzeros
# Root relaxation presolved model has 28 quadratic objective terms
#
#
# Root relaxation: objective 7.543444e+01, 342 iterations, 0.03 seconds (0.02 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   75.43444    0   14  683.00000   75.43444  89.0%     -    0s
# H    0     0                     288.9004940   75.43444  73.9%     -    0s
# H    0     0                     163.1408796   75.43444  53.8%     -    0s
#      0     0   75.43444    0   14  163.14088   75.43444  53.8%     -    0s
# H    0     0                      98.2894637   75.43444  23.3%     -    0s
#      0     2   75.43444    0   14   98.28946   75.43444  23.3%     -    0s
# *   10     6               5      88.9436709   75.43444  15.2%  48.3    0s
# H   11     6                      83.9689537   75.43444  10.2%  43.9    0s
# *   19     6               5      83.4328650   75.43444  9.59%  51.7    0s
# *   20     6               6      81.3116102   75.43444  7.23%  53.0    0s
#
# Explored 28 nodes (1748 simplex iterations) in 0.29 seconds (0.14 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 7: 81.3116 83.4329 83.969 ... 683
#
# Optimal solution found (tolerance 3.00e-02)
# Best objective 8.131161023790e+01, best bound 8.131161023790e+01, gap 0.0000%
#    -> obj=81.3116,  |K^+|=2,  |K^-|=0,  |K_bar|=2
# [KS] iter 2/3  |K_k|=4  |K_bar|=2  |K_it|=7  UB=81.3116
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 60
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  60
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 687 rows, 738 columns and 32119 nonzeros
# Model fingerprint: 0x74e52bc1
# Model has 45 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 81 simple general constraints
#   81 INDICATOR
# Variable types: 729 continuous, 9 integer (9 binary)
# Coefficient statistics:
#   Matrix range     [2e-03, 2e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+00]
#   QRHS range       [8e+01, 8e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 95 rows and 0 columns
# Presolve removed 0 rows and 19 columns
# Presolve time: 0.10s
# Presolved: 783 rows, 747 columns, 21404 nonzeros
# Presolved model has 28 quadratic objective terms
# Presolved model has 28 quadratic constraint(s)
# Variable types: 740 continuous, 7 integer (7 binary)
# Root relaxation presolved: 783 rows, 719 columns, 21376 nonzeros
# Root relaxation presolved model has 28 quadratic objective terms
#
#
# Root relaxation: objective 7.233063e+01, 462 iterations, 0.07 seconds (0.04 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      81.3116115   72.33063  11.0%     -    0s
# H    0     0                      81.3116102   72.33063  11.0%     -    0s
#      0     0   72.33063    0    3   81.31161   72.33063  11.0%     -    0s
#      0     0   72.33063    0    3   81.31161   72.33063  11.0%     -    0s
#      0     0   76.90263    0    4   81.31161   76.90263  5.42%     -    0s
#      0     0   76.90263    0    4   81.31161   76.90263  5.42%     -    0s
#
# Cutting planes:
#   MIR: 4
#   Relax-and-lift: 2
#
# Explored 1 nodes (571 simplex iterations) in 0.87 seconds (0.30 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 81.3116
#
# Optimal solution found (tolerance 3.00e-02)
# Best objective 8.131161023790e+01, best bound 8.131161023790e+01, gap 0.0000%
#    -> obj=81.3116,  |K^+|=3,  |K^-|=0,  |K_bar|=5
# [KS] iter 3/3  |K_k|=1  |K_bar|=5  |K_it|=7  UB=81.3116
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 60
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  60
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 687 rows, 738 columns and 32119 nonzeros
# Model fingerprint: 0x9a37292e
# Model has 45 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 81 simple general constraints
#   81 INDICATOR
# Variable types: 729 continuous, 9 integer (9 binary)
# Coefficient statistics:
#   Matrix range     [2e-03, 2e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+00]
#   QRHS range       [8e+01, 8e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 95 rows and 0 columns
# Presolve removed 0 rows and 19 columns
# Presolve time: 0.07s
# Presolved: 783 rows, 747 columns, 21404 nonzeros
# Presolved model has 28 quadratic objective terms
# Presolved model has 28 quadratic constraint(s)
# Variable types: 740 continuous, 7 integer (7 binary)
# Root relaxation presolved: 783 rows, 719 columns, 21376 nonzeros
# Root relaxation presolved model has 28 quadratic objective terms
#
#
# Root relaxation: objective 5.556166e+01, 379 iterations, 0.08 seconds (0.04 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      81.3116102   55.56166  31.7%     -    0s
#      0     0   55.56166    0    3   81.31161   55.56166  31.7%     -    0s
#      0     0   55.56166    0    3   81.31161   55.56166  31.7%     -    0s
#      0     0   55.56166    0    4   81.31161   55.56166  31.7%     -    0s
#      0     0   55.56166    0    4   81.31161   55.56166  31.7%     -    0s
#      0     0   55.56166    0    4   81.31161   55.56166  31.7%     -    0s
#      0     0   55.56166    0    3   81.31161   55.56166  31.7%     -    1s
#      0     0   55.56166    0    4   81.31161   55.56166  31.7%     -    1s
# H    0     0                      64.4639999   55.56166  13.8%     -    2s
#
# Cutting planes:
#   MIR: 1
#
# Explored 1 nodes (857 simplex iterations) in 2.03 seconds (0.86 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 64.464 81.3116
#
# Optimal solution found (tolerance 3.00e-02)
# Best objective 6.446399988435e+01, best bound 6.446399988435e+01, gap 0.0000%
#    -> obj=64.464,  |K^+|=1,  |K^-|=0,  |K_bar|=6
# [KS] DONE.  best obj= 64.464   |S|= 5
# UB: 64.46399988434796
# best obj: 64.46399988434796
# selected: ['Clump_thickness', 'Uniformity_of_cell_size', 'Marginal_adhesion', 'Bare_nuclei', 'Normal_nucleoli']

# %%
breast_cancer_wisconsin_prognostic = fetch_ucirepo(id=16)
X_df = breast_cancer_wisconsin_prognostic.data.features.replace('?', np.nan).dropna()
y_series = breast_cancer_wisconsin_prognostic.data.targets['Outcome'].loc[X_df.index]
feature_names = list(X_df.columns)
X = StandardScaler().fit_transform(X_df.values)

# y_series: 形如包含 'N' / 'R' 的 pandas Series
y_str = y_series.astype(str).str.strip().str.upper().values

# 检查是否真的是二分类且只含 N/R
uniq = np.unique(y_str)
if not set(uniq).issubset({"N", "R"}) or len(uniq) != 2:
    raise ValueError(f"期望标签为 {{'N','R'}}，但实际唯一取值={uniq}")

# 约定：N -> +1，R -> -1  （和你之前的一致）
y = np.where(y_str == "N", 1.0, -1.0)

B, C, rho = 5, 1.0, 4
res = kernel_search(
    X, y, B, C, rho,
    feature_names=feature_names,
    mosek_time=20.0,   # D-Shor-Co 限时
    mip_time=60.0,     # CoP(K) 限时
    mip_gap=0.03,
    verbose=True
)
print("UB:", res["UB"])
print("best obj:", res["best_obj"])
print("selected:", res.get("selected_features", res["selected_idx"]))
# Out:
# [D-Shor-Co] obj=84.4431  t_min..max=(0, 1)
# [KS] n=33, rho=4  => N=9 groups (each ≤4)
# [KS] iter 1/9  |K_k|=4  |K_bar|=0  |K_it|=7  UB=inf
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 60
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  60
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 222 rows, 789 columns and 109288 nonzeros
# Model fingerprint: 0x4e68f2ba
# Model has 561 quadratic objective terms
# Model has 1089 simple general constraints
#   1089 INDICATOR
# Variable types: 756 continuous, 33 integer (33 binary)
# Coefficient statistics:
#   Matrix range     [5e-08, 7e+01]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# Loaded user MIP start with objective 194
#
# Presolve removed 27 rows and 559 columns
# Presolve time: 0.04s
# Presolved: 195 rows, 230 columns, 5827 nonzeros
# Presolved model has 49 SOS constraint(s)
# Presolved model has 28 quadratic objective terms
# Variable types: 223 continuous, 7 integer (7 binary)
# Root relaxation presolved: 194 rows, 223 columns, 5820 nonzeros
# Root relaxation presolved model has 28 quadratic objective terms
#
#
# Root relaxation: objective 8.724033e+01, 778 iterations, 0.03 seconds (0.03 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   87.24033    0   14  194.00000   87.24033  55.0%     -    0s
# H    0     0                     103.0975345   87.24033  15.4%     -    0s
# H    0     0                      90.9927391   87.24033  4.12%     -    0s
#      0     0   87.24033    0   14   90.99274   87.24033  4.12%     -    0s
#      0     2   87.24033    0   14   90.99274   87.24033  4.12%     -    0s
#
# Explored 37 nodes (2238 simplex iterations) in 0.26 seconds (0.14 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 90.9927 194
#
# Optimal solution found (tolerance 3.00e-02)
# Best objective 9.099273905709e+01, best bound 9.099273905709e+01, gap 0.0000%
#    -> obj=90.9927,  |K^+|=2,  |K^-|=0,  |K_bar|=2
# [KS] iter 2/9  |K_k|=4  |K_bar|=2  |K_it|=7  UB=90.9927
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 60
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  60
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 222 rows, 789 columns and 109288 nonzeros
# Model fingerprint: 0x6e09a0e9
# Model has 561 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 1089 simple general constraints
#   1089 INDICATOR
# Variable types: 756 continuous, 33 integer (33 binary)
# Coefficient statistics:
#   Matrix range     [5e-08, 7e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
#   QRHS range       [9e+01, 9e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 71 rows and 0 columns
# Presolve removed 0 rows and 559 columns
# Presolve time: 0.05s
# Presolved: 294 rows, 258 columns, 6245 nonzeros
# Presolved model has 28 quadratic objective terms
# Presolved model has 28 quadratic constraint(s)
# Variable types: 251 continuous, 7 integer (7 binary)
# Root relaxation presolved: 294 rows, 230 columns, 6217 nonzeros
# Root relaxation presolved model has 28 quadratic objective terms
#
#
# Root relaxation: objective 8.696784e+01, 661 iterations, 0.04 seconds (0.02 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      90.9927400   86.96784  4.42%     -    0s
# H    0     0                      90.9927391   86.96784  4.42%     -    0s
#      0     0   86.96784    0    3   90.99274   86.96784  4.42%     -    0s
#      0     0   86.96784    0    3   90.99274   86.96784  4.42%     -    0s
#      0     0   86.96784    0    3   90.99274   86.96784  4.42%     -    0s
#      0     0   86.96784    0    3   90.99274   86.96784  4.42%     -    0s
#      0     0   86.96784    0    3   90.99274   86.96784  4.42%     -    0s
# H    0     0                      89.8844276   86.96784  3.24%     -    0s
#
# Cutting planes:
#   MIR: 2
#   Relax-and-lift: 1
#
# Explored 1 nodes (741 simplex iterations) in 0.74 seconds (0.21 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 89.8844 90.9927
#
# Optimal solution found (tolerance 3.00e-02)
# Best objective 8.988442758276e+01, best bound 8.988442758276e+01, gap 0.0000%
#    -> obj=89.8844,  |K^+|=3,  |K^-|=0,  |K_bar|=5
# [KS] iter 3/9  |K_k|=4  |K_bar|=5  |K_it|=9  UB=89.8844
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 60
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  60
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 220 rows, 789 columns and 109288 nonzeros
# Model fingerprint: 0x141aa7fa
# Model has 561 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 1089 simple general constraints
#   1089 INDICATOR
# Variable types: 756 continuous, 33 integer (33 binary)
# Coefficient statistics:
#   Matrix range     [5e-08, 7e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
#   QRHS range       [9e+01, 9e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
# User MIP start violates constraint fix_outside_30 by 1.000000000
#
# Presolve added 137 rows and 0 columns
# Presolve removed 0 rows and 540 columns
# Presolve time: 0.09s
# Presolved: 358 rows, 294 columns, 9690 nonzeros
# Presolved model has 45 quadratic objective terms
# Presolved model has 45 quadratic constraint(s)
# Variable types: 285 continuous, 9 integer (9 binary)
# Root relaxation presolved: 358 rows, 249 columns, 9645 nonzeros
# Root relaxation presolved model has 45 quadratic objective terms
#
#
# Root relaxation: objective 7.458350e+01, 556 iterations, 0.07 seconds (0.03 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   74.58350    0    5          -   74.58350      -     -    0s
#      0     0   74.58350    0    5          -   74.58350      -     -    0s
#      0     0   74.58350    0    6          -   74.58350      -     -    0s
#      0     0   74.58350    0    6          -   74.58350      -     -    0s
#      0     0   74.58350    0    6          -   74.58350      -     -    0s
# H    0     0                      89.8782900   77.11700  14.2%     -    1s
# H    0     0                      89.8267641   77.11700  14.1%     -    2s
# H    0     0                      89.8267625   77.11700  14.1%     -    2s
# H    0     0                      88.1192209   77.11700  12.5%     -    2s
#      0     2   77.11700    0    6   88.11922   77.11700  12.5%     -    2s
# H    4     8                      88.1192192   77.11700  12.5%  22.8    2s
# H   53    19                      87.7392463   77.11700  12.1%  77.0    2s
# *   53    19               7      87.7392463   77.11700  12.1%  80.7    2s
# H  103    13                      87.5985294   77.15161  11.9%  72.4    2s
# *  103    13               6      87.5985294   77.15161  11.9%  73.7    2s
# H  108    14                      87.5985291   82.29844  6.05%  74.7    2s
# *  135     6               6      87.5985285   82.66456  5.63%  66.7    2s
#
# Cutting planes:
#   MIR: 1
#   Relax-and-lift: 1
#
# Explored 149 nodes (10442 simplex iterations) in 2.79 seconds (1.45 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 5: 87.5985 87.7392 88.1192 ... 89.8783
#
# Optimal solution found (tolerance 3.00e-02)
# Best objective 8.759852854085e+01, best bound 8.616955607344e+01, gap 1.6313%
#    -> obj=87.5985,  |K^+|=3,  |K^-|=0,  |K_bar|=8
# [KS] iter 4/9  |K_k|=4  |K_bar|=8  |K_it|=12  UB=87.5985
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 60
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  60
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 217 rows, 789 columns and 109288 nonzeros
# Model fingerprint: 0x6c1348de
# Model has 561 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 1089 simple general constraints
#   1089 INDICATOR
# Variable types: 756 continuous, 33 integer (33 binary)
# Coefficient statistics:
#   Matrix range     [5e-08, 7e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
#   QRHS range       [9e+01, 9e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 266 rows and 0 columns
# Presolve removed 0 rows and 504 columns
# Presolve time: 0.10s
# Presolved: 484 rows, 363 columns, 16380 nonzeros
# Presolved model has 78 quadratic objective terms
# Presolved model has 78 quadratic constraint(s)
# Variable types: 351 continuous, 12 integer (12 binary)
# Root relaxation presolved: 484 rows, 285 columns, 16302 nonzeros
# Root relaxation presolved model has 78 quadratic objective terms
#
#
# Root relaxation: objective 6.710236e+01, 514 iterations, 0.09 seconds (0.04 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      87.5985260   67.10236  23.4%     -    0s
#      0     0   67.10236    0    8   87.59853   67.10236  23.4%     -    0s
#      0     0   67.10236    0    8   87.59853   67.10236  23.4%     -    0s
#      0     0   67.10236    0    8   87.59853   67.10236  23.4%     -    0s
#      0     0   67.10236    0    8   87.59853   67.10236  23.4%     -    0s
#      0     0   67.10236    0    8   87.59853   67.10236  23.4%     -    0s
#      0     2   68.56141    0    8   87.59853   68.56141  21.7%     -    2s
#    307    70     cutoff   10        87.59853   77.98806  11.0%   101    5s
#
# Explored 776 nodes (67495 simplex iterations) in 6.27 seconds (5.10 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 87.5985
#
# Optimal solution found (tolerance 3.00e-02)
# Best objective 8.759852401301e+01, best bound 8.561742860817e+01, gap 2.2616%
#    -> obj=87.5985,  |K^+|=0,  |K^-|=3,  |K_bar|=5
# [KS] iter 5/9  |K_k|=4  |K_bar|=5  |K_it|=9  UB=87.5985
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 60
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  60
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 220 rows, 789 columns and 109288 nonzeros
# Model fingerprint: 0xf33eced1
# Model has 561 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 1089 simple general constraints
#   1089 INDICATOR
# Variable types: 756 continuous, 33 integer (33 binary)
# Coefficient statistics:
#   Matrix range     [5e-08, 7e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
#   QRHS range       [9e+01, 9e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 137 rows and 0 columns
# Presolve removed 0 rows and 540 columns
# Presolve time: 0.08s
# Presolved: 358 rows, 294 columns, 9690 nonzeros
# Presolved model has 45 quadratic objective terms
# Presolved model has 45 quadratic constraint(s)
# Variable types: 285 continuous, 9 integer (9 binary)
# Root relaxation presolved: 358 rows, 249 columns, 9645 nonzeros
# Root relaxation presolved model has 45 quadratic objective terms
#
#
# Root relaxation: objective 6.651239e+01, 440 iterations, 0.06 seconds (0.02 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   66.51239    0    5          -   66.51239      -     -    0s
#      0     0   66.51239    0    5          -   66.51239      -     -    0s
#      0     0   66.51239    0    6          -   66.51239      -     -    0s
#      0     0   66.51239    0    6          -   66.51239      -     -    0s
#      0     0   66.51239    0    6          -   66.51239      -     -    0s
# H    0     0                      87.5792553   75.35350  14.0%     -    2s
# H    0     0                      86.9349835   75.35350  13.3%     -    2s
#      0     2   75.35350    0    6   86.93498   75.35350  13.3%     -    2s
# H   12    18                      86.8576532   75.35350  13.2%  46.0    2s
# *   12    18               5      86.8576532   75.35350  13.2%  72.7    2s
# H   34    19                      86.7907806   75.35350  13.2%  75.6    2s
# *   34    19               8      86.7907806   75.35350  13.2%  79.6    2s
# H   49    23                      86.5873115   75.35350  13.0%  72.9    2s
# *   49    23               7      86.5873115   75.35350  13.0%  76.7    2s
# H   62    24                      86.2531363   75.35350  12.6%  81.7    2s
# *   62    24               8      86.2531363   75.35350  12.6%  82.6    2s
# H  116     9                      85.5924550   81.40169  4.90%  71.4    2s
# *  116     9               7      85.5924550   81.40169  4.90%  71.5    2s
#
# Cutting planes:
#   MIR: 1
#   Relax-and-lift: 1
#
# Explored 129 nodes (8996 simplex iterations) in 2.63 seconds (1.56 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 6: 85.5925 86.2531 86.5873 ... 86.935
#
# Optimal solution found (tolerance 3.00e-02)
# Best objective 8.559245479235e+01, best bound 8.559245072605e+01, gap 0.0000%
#    -> obj=85.5925,  |K^+|=2,  |K^-|=0,  |K_bar|=7
# [KS] iter 6/9  |K_k|=4  |K_bar|=7  |K_it|=11  UB=85.5925
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 60
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  60
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 218 rows, 789 columns and 109288 nonzeros
# Model fingerprint: 0xc597c184
# Model has 561 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 1089 simple general constraints
#   1089 INDICATOR
# Variable types: 756 continuous, 33 integer (33 binary)
# Coefficient statistics:
#   Matrix range     [5e-08, 7e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
#   QRHS range       [9e+01, 9e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 219 rows and 0 columns
# Presolve removed 0 rows and 517 columns
# Presolve time: 0.12s
# Presolved: 438 rows, 338 columns, 13947 nonzeros
# Presolved model has 66 quadratic objective terms
# Presolved model has 66 quadratic constraint(s)
# Variable types: 327 continuous, 11 integer (11 binary)
# Root relaxation presolved: 438 rows, 272 columns, 13881 nonzeros
# Root relaxation presolved model has 66 quadratic objective terms
#
#
# Root relaxation: objective 6.241771e+01, 451 iterations, 0.07 seconds (0.03 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      85.5924507   62.41771  27.1%     -    0s
#      0     0   62.41771    0    7   85.59245   62.41771  27.1%     -    0s
#      0     0   62.41771    0    7   85.59245   62.41771  27.1%     -    0s
#      0     0   62.41771    0    7   85.59245   62.41771  27.1%     -    0s
#      0     0   62.41771    0    7   85.59245   62.41771  27.1%     -    0s
#      0     0   62.41771    0    7   85.59245   62.41771  27.1%     -    0s
# H    0     0                      84.9285222   64.38700  24.2%     -    2s
# H    0     0                      84.9285154   64.38700  24.2%     -    2s
#      0     2   64.38700    0    7   84.92852   64.38700  24.2%     -    2s
#
# Cutting planes:
#   MIR: 2
#
# Explored 292 nodes (22335 simplex iterations) in 3.59 seconds (2.24 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 84.9285 85.5925
#
# Optimal solution found (tolerance 3.00e-02)
# Best objective 8.492851538296e+01, best bound 8.409766257116e+01, gap 0.9783%
#    -> obj=84.9285,  |K^+|=1,  |K^-|=2,  |K_bar|=6
# [KS] iter 7/9  |K_k|=4  |K_bar|=6  |K_it|=10  UB=84.9285
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 60
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  60
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 219 rows, 789 columns and 109288 nonzeros
# Model fingerprint: 0x5edfd90b
# Model has 561 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 1089 simple general constraints
#   1089 INDICATOR
# Variable types: 756 continuous, 33 integer (33 binary)
# Coefficient statistics:
#   Matrix range     [5e-08, 7e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
#   QRHS range       [8e+01, 8e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 176 rows and 0 columns
# Presolve removed 0 rows and 529 columns
# Presolve time: 0.08s
# Presolved: 396 rows, 315 columns, 11717 nonzeros
# Presolved model has 55 quadratic objective terms
# Presolved model has 55 quadratic constraint(s)
# Variable types: 305 continuous, 10 integer (10 binary)
# Root relaxation presolved: 396 rows, 260 columns, 11662 nonzeros
# Root relaxation presolved model has 55 quadratic objective terms
#
#
# Root relaxation: objective 7.176277e+01, 470 iterations, 0.06 seconds (0.03 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      84.9285154   71.76277  15.5%     -    0s
#      0     0   71.76277    0    6   84.92852   71.76277  15.5%     -    0s
#      0     0   71.76277    0    6   84.92852   71.76277  15.5%     -    0s
#      0     0   71.76277    0    6   84.92852   71.76277  15.5%     -    0s
#      0     0   71.76277    0    6   84.92852   71.76277  15.5%     -    0s
#      0     0   71.76277    0    6   84.92852   71.76277  15.5%     -    0s
#      0     2   72.72767    0    6   84.92852   72.72767  14.4%     -    1s
# H   64    19                      84.6767544   72.80191  14.0%  76.2    2s
# *   64    19               8      84.6767544   72.80191  14.0%  79.0    2s
#
# Cutting planes:
#   MIR: 2
#
# Explored 146 nodes (10885 simplex iterations) in 2.22 seconds (1.14 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 84.6768 84.9285
#
# Optimal solution found (tolerance 3.00e-02)
# Warning: max constraint violation (1.0661e-06) exceeds tolerance
# Best objective 8.467674133822e+01, best bound 8.412028016515e+01, gap 0.6572%
#    -> obj=84.6767,  |K^+|=1,  |K^-|=1,  |K_bar|=6
# [KS] iter 8/9  |K_k|=4  |K_bar|=6  |K_it|=10  UB=84.6767
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 60
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  60
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 219 rows, 789 columns and 109288 nonzeros
# Model fingerprint: 0x2eb76739
# Model has 561 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 1089 simple general constraints
#   1089 INDICATOR
# Variable types: 756 continuous, 33 integer (33 binary)
# Coefficient statistics:
#   Matrix range     [5e-08, 7e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
#   QRHS range       [8e+01, 8e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 176 rows and 0 columns
# Presolve removed 0 rows and 529 columns
# Presolve time: 0.07s
# Presolved: 396 rows, 315 columns, 11717 nonzeros
# Presolved model has 55 quadratic objective terms
# Presolved model has 55 quadratic constraint(s)
# Variable types: 305 continuous, 10 integer (10 binary)
# Root relaxation presolved: 396 rows, 260 columns, 11662 nonzeros
# Root relaxation presolved model has 55 quadratic objective terms
#
#
# Root relaxation: objective 7.323233e+01, 442 iterations, 0.03 seconds (0.03 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      84.6766960   73.23233  13.5%     -    0s
#      0     0   73.23233    0    6   84.67670   73.23233  13.5%     -    0s
#      0     0   73.23233    0    6   84.67670   73.23233  13.5%     -    0s
#      0     0   73.23233    0    7   84.67670   73.23233  13.5%     -    0s
#      0     0   73.23233    0    7   84.67670   73.23233  13.5%     -    0s
#      0     0   73.23233    0    7   84.67670   73.23233  13.5%     -    0s
#      0     2   76.02418    0    7   84.67670   76.02418  10.2%     -    2s
# H   42    19                      84.0024183   76.02418  9.50%  53.8    2s
# *   42    19               8      84.0024183   76.02418  9.50%  57.5    2s
#
# Cutting planes:
#   MIR: 3
#
# Explored 116 nodes (7332 simplex iterations) in 2.40 seconds (1.11 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 84.0024 84.6767
#
# Optimal solution found (tolerance 3.00e-02)
# Warning: max constraint violation (1.8920e-06) exceeds tolerance
# Best objective 8.400241568419e+01, best bound 8.245008534298e+01, gap 1.8480%
#    -> obj=84.0024,  |K^+|=1,  |K^-|=0,  |K_bar|=7
# [KS] iter 9/9  |K_k|=1  |K_bar|=7  |K_it|=8  UB=84.0024
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 60
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  60
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 221 rows, 789 columns and 109288 nonzeros
# Model fingerprint: 0xabbb693d
# Model has 561 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 1089 simple general constraints
#   1089 INDICATOR
# Variable types: 756 continuous, 33 integer (33 binary)
# Coefficient statistics:
#   Matrix range     [5e-08, 7e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
#   QRHS range       [8e+01, 8e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 102 rows and 0 columns
# Presolve removed 0 rows and 550 columns
# Presolve time: 0.07s
# Presolved: 324 rows, 275 columns, 7866 nonzeros
# Presolved model has 36 quadratic objective terms
# Presolved model has 36 quadratic constraint(s)
# Variable types: 267 continuous, 8 integer (8 binary)
# Root relaxation presolved: 324 rows, 239 columns, 7830 nonzeros
# Root relaxation presolved model has 36 quadratic objective terms
#
#
# Root relaxation: objective 7.942264e+01, 476 iterations, 0.04 seconds (0.02 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   79.42264    0    4          -   79.42264      -     -    0s
#      0     0   79.42264    0    4          -   79.42264      -     -    0s
#      0     0   79.42264    0    5          -   79.42264      -     -    0s
#      0     0   79.42264    0    5          -   79.42264      -     -    0s
#      0     0   79.42264    0    5          -   79.42264      -     -    0s
#
# Cutting planes:
#   MIR: 2
#   Relax-and-lift: 1
#
# Explored 1 nodes (598 simplex iterations) in 0.90 seconds (0.28 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 0
#
# Model is infeasible or unbounded
# Best objective -, best bound -, gap -
#    -> infeasible or no incumbent under limits.
# [KS] DONE.  best obj= 84.0024   |S|= 5
# UB: 84.00241568418753
# best obj: 84.00241568418753
# selected: ['concavity1', 'symmetry1', 'perimeter2', 'area2', 'fractal_dimension2']

# %%
# =========================================================
# Co-NLSVM (Gurobi) vs Algorithm-3 Heuristic (same time budget)
#   - (13) D-Shor-Co ........... MOSEK Fusion (conic, diag-only)
#   - (19) bounds for w_j ...... MOSEK Fusion (conic, with safe UB)
#   - (1)  l2-NLSVM ............ MOSEK Fusion (conic, explicit quadratic map)
#   - CoP(K) ................... Gurobi (indicator constraints, with feasible MIP start)
# =========================================================
from __future__ import annotations
import time, math, itertools
import numpy as np
import pandas as pd
from typing import List, Dict, Optional, Iterable, Tuple

# -------------------- Helpers --------------------
def _fmt_num(x): 
    try:
        return "inf" if (x is None or not np.isfinite(x)) else f"{float(x):.6g}"
    except Exception:
        return str(x)

def _fusion_set_time_limit(M, seconds: float | None, is_mip: bool = False):
    """MOSEK Fusion time limit with version-agnostic params."""
    if seconds is None:
        return
    try:
        import mosek
        M.setSolverParam(mosek.dparam.optimizer_max_time, float(seconds))
        if is_mip:
            M.setSolverParam(mosek.dparam.mio_max_time, float(seconds))
    except Exception:
        # textual fallbacks
        try:
            M.setSolverParam("optimizerMaxTime", float(seconds))
        except Exception:
            pass
        if is_mip:
            try:
                M.setSolverParam("mioMaxTime", float(seconds))
            except Exception:
                pass

def _fusion_obj_value(M):
    """Read objective value in a version-compatible way."""
    try:
        return float(M.primalObjValue())
    except Exception:
        return float(M.objectiveValue())

def quad_map(X: np.ndarray):
    """
    显式二次映射：
      phi(x) = [ x_1^2, ..., x_n^2, sqrt(2)*x_1 x_2, ..., sqrt(2)*x_{n-1} x_n ]
    返回：Phi_diag (m×n), Phi_cross_list (长度 P 的 m 向量列表), pairs (索引对)
    """
    m, n = X.shape
    Phi_diag = X**2
    pairs = list(itertools.combinations(range(n), 2))
    sqrt2 = np.sqrt(2.0)
    Phi_cross_list = [sqrt2*(X[:, i]*X[:, j]) for (i, j) in pairs]
    return Phi_diag, Phi_cross_list, pairs

def _ensure_kernel_size(order: Iterable[int], K_it: List[int], B: int, extra: int = 0) -> List[int]:
    """确保 |K_it| ≥ B（可加冗余 extra），否则按 D-Shor-Co 排名补足。"""
    want = max(B + extra, len(K_it))
    Kset = set(int(j) for j in K_it)
    for idx in list(order):
        if len(Kset) >= want: break
        if int(idx) not in Kset: Kset.add(int(idx))
    return sorted(Kset)

# -------------------- (13) D-Shor-Co (MOSEK, diag-only) --------------------
def solve_dshor_co_mosek(X: np.ndarray, y: np.ndarray, B: int, C: float,
                         time_limit: float | None = None, verbose=False) -> Dict:
    import mosek.fusion as mf
    m, n = X.shape
    Phi_diag, _, _ = quad_map(X)
    M = mf.Model("DShorCo")
    if not verbose: M.setLogHandler(None)
    _fusion_set_time_limit(M, time_limit, is_mip=False)

    # variables
    w  = M.variable("w",  n, mf.Domain.unbounded())
    Wd = M.variable("Wd", n, mf.Domain.greaterThan(0.0))
    b  = M.variable("b",  1, mf.Domain.unbounded())
    xi = M.variable("xi", m, mf.Domain.greaterThan(0.0))
    t  = M.variable("t",  n, mf.Domain.inRange(0.0, 1.0))

    # sum t = n - B
    M.constraint(mf.Expr.sum(t), mf.Domain.equalsTo(float(n - B)))

    # rotated cone: w_j^2 <= Wd_j
    half = mf.Expr.constTerm(1, 0.5)
    for j in range(n):
        M.constraint(mf.Expr.hstack(Wd.index(j), half, w.index(j)), mf.Domain.inRotatedQCone())

    # margin constraints (diag-only)
    A = mf.Matrix.dense(Phi_diag)
    sAw = mf.Expr.mul(A, w)
    for i in range(m):
        lhs = mf.Expr.mul(float(y[i]), mf.Expr.add(sAw.index(i), b))
        M.constraint(mf.Expr.sub(lhs, mf.Expr.sub(1.0, xi.index(i))), mf.Domain.greaterThan(0.0))

    obj = mf.Expr.add(mf.Expr.mul(0.5, mf.Expr.sum(Wd)), mf.Expr.mul(C, mf.Expr.sum(xi)))
    M.objective(mf.ObjectiveSense.Minimize, obj)
    M.solve()

    val = _fusion_obj_value(M)
    out = {"obj": val, "t_rank": np.array(t.level()).reshape(-1)}
    M.dispose()
    return out

# -------------------- CoP(K) with Gurobi (indicator, feasible start) --------------------
def solve_cop_kernel_gurobi(X: np.ndarray, y: np.ndarray, B: int, C: float,
                            kernel_set: Iterable[int], UB: float | None,
                            time_limit: float, mipgap: float | None,
                            verbose=False, feature_names: List[str] | None = None,
                            start_idx: List[int] | None = None,
                            favor_feasible: bool=True) -> Dict:
    import gurobipy as gp
    from gurobipy import GRB

    m, n = X.shape
    Phi_diag, Phi_cross_list, pairs = quad_map(X)
    P = len(pairs)

    model = gp.Model("CoP_K")
    model.Params.OutputFlag = 1 if verbose else 0
    model.Params.TimeLimit  = time_limit
    if mipgap is not None: model.Params.MIPGap = mipgap
    if favor_feasible:
        model.Params.MIPFocus   = 1
        model.Params.Heuristics = 0.5
        model.Params.Presolve   = 2
        model.Params.Cuts       = 1
    model.Params.Seed = 0

    w_d  = model.addVars(n, lb=-GRB.INFINITY, vtype=GRB.CONTINUOUS, name="w_d")
    w_c  = model.addVars(P, lb=-GRB.INFINITY, vtype=GRB.CONTINUOUS, name="w_c")
    b    = model.addVar(lb=-GRB.INFINITY, vtype=GRB.CONTINUOUS, name="b")
    xi   = model.addVars(m, lb=0.0, vtype=GRB.CONTINUOUS, name="xi")
    t    = model.addVars(n, vtype=GRB.BINARY, name="t")  # 1 = 禁用

    # indicators
    for j in range(n):
        t[j].BranchPriority = 10
        model.addGenConstrIndicator(t[j], 1, w_d[j], GRB.EQUAL, 0.0)
    for k, (i, j) in enumerate(pairs):
        model.addGenConstrIndicator(t[i], 1, w_c[k], GRB.EQUAL, 0.0)
        model.addGenConstrIndicator(t[j], 1, w_c[k], GRB.EQUAL, 0.0)

    # budget: exactly B selected
    model.addConstr(gp.quicksum(t[j] for j in range(n)) == n - B, name="budget")

    # margins
    for i in range(m):
        expr = b
        for j in range(n): expr += w_d[j]*float(Phi_diag[i, j])
        for k in range(P): expr += w_c[k]*float(Phi_cross_list[k][i])
        model.addConstr(float(y[i])*expr >= 1.0 - xi[i], name=f"margin_{i}")

    # kernel constraints
    K = sorted(set(int(j) for j in kernel_set))
    if K:
        model.addConstr(gp.quicksum(t[j] for j in K) <= len(K) - 1, name="atleast_one_in_kernel")
    outside = sorted(set(range(n)) - set(K))
    for j in outside: model.addConstr(t[j] == 1, name=f"fix_outside_{j}")

    # objective and optional UB cap (17)
    quad = gp.QuadExpr()
    for j in range(n): quad += w_d[j]*w_d[j]
    for k in range(P): quad += w_c[k]*w_c[k]
    obj = 0.5*quad + C*gp.quicksum(xi[i] for i in range(m))
    model.setObjective(obj, GRB.MINIMIZE)
    if (UB is not None) and np.isfinite(UB): model.addQConstr(obj <= UB + 1e-9, name="obj_ub")

    # feasible MIP Start
    for j in range(n): t[j].Start = 1
    seed = (start_idx if start_idx else K)[:min(B, len(K))]
    for j in seed: t[j].Start = 0
    b.Start = 0.0
    for j in range(n): w_d[j].Start = 0.0
    for k in range(P): w_c[k].Start = 0.0
    for i in range(m): xi[i].Start = 1.0

    t0 = time.time()
    model.optimize()
    rt = time.time() - t0

    sol = {
        "status": model.Status,
        "runtime": rt,
        "objval": model.ObjVal if model.SolCount>0 else np.inf,
        "gap":    model.MIPGap if model.SolCount>0 else np.inf,
        "selected_idx": [],
        "selected_features": [],
    }
    if model.SolCount>0:
        idx = [j for j in range(n) if t[j].X < 0.5]
        sol["selected_idx"] = idx
        if feature_names:
            sol["selected_features"] = [feature_names[j] for j in idx]
    return sol

# -------------------- (1) l2-NLSVM (MOSEK, conic) --------------------
def solve_l2_nlsvm_mosek(X: np.ndarray, y: np.ndarray, C: float,
                         time_limit: float | None, verbose=False) -> Dict:
    """
    用旋转二阶锥线性化 ||w||^2，避免 Expr.dot(Variable,Variable)。
    """
    import mosek.fusion as mf
    m, n = X.shape
    Phi_diag, Phi_cross_list, pairs = quad_map(X); P = len(pairs)
    Phi_cross = np.vstack([pc for pc in Phi_cross_list]).T if P>0 else np.zeros((m,0))

    M = mf.Model("l2-NLSVM")
    if not verbose: M.setLogHandler(None)
    _fusion_set_time_limit(M, time_limit, is_mip=False)

    # variables
    w_d = M.variable("w_d", n, mf.Domain.unbounded())
    w_c = M.variable("w_c", P, mf.Domain.unbounded()) if P>0 else None
    b   = M.variable("b", 1, mf.Domain.unbounded())
    xi  = M.variable("xi", m, mf.Domain.greaterThan(0.0))

    # auxiliaries for rotated cones
    Wd  = M.variable("Wd", n, mf.Domain.greaterThan(0.0))
    Wc  = M.variable("Wc", P, mf.Domain.greaterThan(0.0)) if P>0 else None

    half = mf.Expr.constTerm(1, 0.5)
    for j in range(n):
        M.constraint(mf.Expr.hstack(Wd.index(j), half, w_d.index(j)), mf.Domain.inRotatedQCone())
    if P>0:
        for k in range(P):
            M.constraint(mf.Expr.hstack(Wc.index(k), half, w_c.index(k)), mf.Domain.inRotatedQCone())

    # margins
    A_d = mf.Matrix.dense(Phi_diag); s = mf.Expr.mul(A_d, w_d)
    if P>0:
        A_c = mf.Matrix.dense(Phi_cross); s = mf.Expr.add(s, mf.Expr.mul(A_c, w_c))
    for i in range(m):
        lhs = mf.Expr.mul(float(y[i]), mf.Expr.add(s.index(i), b))
        M.constraint(mf.Expr.sub(lhs, mf.Expr.sub(1.0, xi.index(i))), mf.Domain.greaterThan(0.0))

    # objective: 0.5*(sum Wd + sum Wc) + C*sum xi
    obj = mf.Expr.add(mf.Expr.mul(0.5, mf.Expr.sum(Wd)), mf.Expr.mul(C, mf.Expr.sum(xi)))
    if P>0:
        obj = mf.Expr.add(obj, mf.Expr.mul(0.5, mf.Expr.sum(Wc)))
    M.objective(mf.ObjectiveSense.Minimize, obj)
    M.solve()

    w_diag  = np.array(w_d.level()).reshape(-1)
    w_cross = np.array(w_c.level()).reshape(-1) if P>0 else np.zeros(P)
    bval    = float(b.level()[0])
    xi_v    = np.array(xi.level()).reshape(-1)
    objval  = _fusion_obj_value(M)

    M.dispose()
    return {"obj": objval, "w_diag": w_diag, "w_cross": w_cross, "b": bval, "xi": xi_v}

# -------------------- (19) bounds with safe fallback --------------------
def bound_wj_mosek(X: np.ndarray, y: np.ndarray, B: int, C: float, UB: float,
                   j: int, sense: str, time_limit: float | None) -> Tuple[float, bool]:
    """
    返回 (值, is_optimal)。若不可行/非最优/异常，由外层给兜底界。
    """
    import mosek.fusion as mf
    m, n = X.shape
    Phi_diag, _, _ = quad_map(X)

    M = mf.Model(f"Bound_w{j}_{sense}")
    _fusion_set_time_limit(M, time_limit, is_mip=False)

    w  = M.variable("w",  n, mf.Domain.unbounded())
    Wd = M.variable("Wd", n, mf.Domain.greaterThan(0.0))
    b  = M.variable("b",  1, mf.Domain.unbounded())
    xi = M.variable("xi", m, mf.Domain.greaterThan(0.0))
    t  = M.variable("t",  n, mf.Domain.inRange(0.0, 1.0))

    M.constraint(mf.Expr.sum(t), mf.Domain.equalsTo(float(n - B)))

    half = mf.Expr.constTerm(1, 0.5)
    for jj in range(n):
        M.constraint(mf.Expr.hstack(Wd.index(jj), half, w.index(jj)), mf.Domain.inRotatedQCone())

    A = mf.Matrix.dense(Phi_diag); sAw = mf.Expr.mul(A, w)
    for i in range(m):
        lhs = mf.Expr.mul(float(y[i]), mf.Expr.add(sAw.index(i), b))
        M.constraint(mf.Expr.sub(lhs, mf.Expr.sub(1.0, xi.index(i))), mf.Domain.greaterThan(0.0))

    if not np.isfinite(UB):
        UB = 1e6
    M.constraint(
        mf.Expr.add(mf.Expr.mul(0.5, mf.Expr.sum(Wd)), mf.Expr.mul(C, mf.Expr.sum(xi))),
        mf.Domain.lessThan(UB + 1e-9)
    )

    M.objective(mf.ObjectiveSense.Minimize if sense=="min" else mf.ObjectiveSense.Maximize, w.index(j))
    try:
        M.solve()
        ps = M.getPrimalSolutionStatus()
        import mosek.fusion as mf
        ok = ps in (mf.SolutionStatus.Optimal, mf.SolutionStatus.NearOptimal)
        val = float(w.level()[j]) if ok else np.nan
    except Exception:
        ok, val = False, np.nan
    finally:
        M.dispose()
    return val, ok

def compute_M_by_prop41(X: np.ndarray, y: np.ndarray, B: int, C: float, UB: float,
                        time_per_bound: float | None, verbose=False) -> float:
    n = X.shape[1]
    safe_cap = float(np.sqrt(max(0.0, 2.0 * UB))) if np.isfinite(UB) else 1e6
    Mvals = []
    for j in range(n):
        lo, ok_lo = bound_wj_mosek(X, y, B, C, UB, j, "min", time_per_bound)
        hi, ok_hi = bound_wj_mosek(X, y, B, C, UB, j, "max", time_per_bound)
        if not (ok_lo and np.isfinite(lo)): lo = -safe_cap
        if not (ok_hi and np.isfinite(hi)): hi =  safe_cap
        Mj = max(abs(lo), abs(hi))
        Mvals.append(Mj)
        if verbose:
            print(f"[Prop4.1] j={j} lo={lo:.6g} hi={hi:.6g} |.|max={Mj:.6g} "
                  f"{'' if (ok_lo and ok_hi) else '(fallback)'}")
    M = float(np.max(Mvals))
    if verbose: print(f"[Prop4.1] M = {M:.6g}")
    return M

# -------------------- (14) D-Shor-Co-BigM (MOSEK, diag-only MISOCP) --------------------
def solve_dshor_co_bigm_mosek(X: np.ndarray, y: np.ndarray, B: int, C: float, Mbig: float,
                              time_limit: float | None, verbose=False) -> Dict:
    import mosek.fusion as mf
    m, n = X.shape
    Phi_diag, _, _ = quad_map(X)
    M = mf.Model("DShorCoBigM")
    if not verbose: M.setLogHandler(None)
    _fusion_set_time_limit(M, time_limit, is_mip=True)

    w  = M.variable("w",  n, mf.Domain.unbounded())
    Wd = M.variable("Wd", n, mf.Domain.greaterThan(0.0))
    b  = M.variable("b",  1, mf.Domain.unbounded())
    xi = M.variable("xi", m, mf.Domain.greaterThan(0.0))
    t  = M.variable("t",  n, mf.Domain.binary())

    M.constraint(mf.Expr.sum(t), mf.Domain.equalsTo(float(n - B)))

    one = mf.Expr.ones(n)
    M.constraint(mf.Expr.sub(w, mf.Expr.mul(Mbig, mf.Expr.sub(one, t))), mf.Domain.lessThan(0.0))
    M.constraint(mf.Expr.add(w, mf.Expr.mul(Mbig, mf.Expr.sub(one, t))), mf.Domain.greaterThan(0.0))

    half = mf.Expr.constTerm(1, 0.5)
    for j in range(n):
        M.constraint(mf.Expr.hstack(Wd.index(j), half, w.index(j)), mf.Domain.inRotatedQCone())

    A = mf.Matrix.dense(Phi_diag); sAw = mf.Expr.mul(A, w)
    for i in range(m):
        lhs = mf.Expr.mul(float(y[i]), mf.Expr.add(sAw.index(i), b))
        M.constraint(mf.Expr.sub(lhs, mf.Expr.sub(1.0, xi.index(i))), mf.Domain.greaterThan(0.0))

    obj = mf.Expr.add(mf.Expr.mul(0.5, mf.Expr.sum(Wd)), mf.Expr.mul(C, mf.Expr.sum(xi)))
    M.objective(mf.ObjectiveSense.Minimize, obj)
    M.solve()

    objv = _fusion_obj_value(M)
    tvec = np.array(t.level()).reshape(-1)
    M.dispose()
    return {"obj": objv, "t": tvec}

# -------------------- KS with global budget --------------------
def kernel_search_budgeted(
    X: np.ndarray, y: np.ndarray, B: int, C: float, rho: int,
    feature_names: List[str] | None,
    dshor_time: float, ks_total_time: float, mip_gap: float | None,
    verbose: bool = True
) -> Dict:
    start = time.monotonic()
    rel = solve_dshor_co_mosek(X, y, B, C, time_limit=dshor_time, verbose=verbose)
    order = np.argsort(rel["t_rank"])
    m, n = X.shape
    rho = max(1, min(rho, n))
    groups = [order[i*rho: min((i+1)*rho, n)].tolist() for i in range(math.ceil(n/rho))]

    K_bar: List[int] = []
    UB, best_obj, best_gap = np.inf, np.inf, np.inf
    best_idx: List[int] = []
    logs = []

    for k, K_k in enumerate(groups, start=1):
        elapsed = time.monotonic() - start
        remain  = max(0.0, ks_total_time - elapsed)
        if remain <= 1e-3: break
        per_iter = max(1.0, remain / (len(groups) - (k-1)))

        K_it_raw = sorted(set(K_k) | set(K_bar))
        K_it = _ensure_kernel_size(order, K_it_raw, B, extra=max(1, B//2))
        seed = best_idx if best_idx else K_it[:B]

        sol = solve_cop_kernel_gurobi(
            X, y, B, C,
            kernel_set=K_it, UB=UB,
            time_limit=per_iter, mipgap=mip_gap, verbose=verbose,
            feature_names=feature_names, start_idx=seed, favor_feasible=True
        )
        if np.isfinite(sol["objval"]) and (sol["objval"] < best_obj):
            best_obj, best_gap = sol["objval"], sol["gap"]
            best_idx = sol["selected_idx"]
        if np.isfinite(sol["objval"]) and (sol["objval"] < UB): UB = sol["objval"]

        sel_set = set(sol["selected_idx"])
        K_plus  = [j for j in K_k if j in sel_set]
        K_bar   = sorted(set(K_bar).union(K_plus))

        logs.append({"k":k, "obj":sol["objval"], "gap":sol["gap"], "rt":sol["runtime"], "K_plus":len(K_plus)})

        if verbose:
            print(f"[KS] iter {k}/{len(groups)} -> obj={_fmt_num(sol['objval'])}, gap={_fmt_num(sol['gap'])}, K^+={len(K_plus)}")

    return {"UB": UB, "best_obj": best_obj, "best_gap": best_gap,
            "selected_idx": best_idx, "logs": logs}

# -------------------- Algorithm-3 with budget --------------------
def algorithm3_budgeted(
    X: np.ndarray, y: np.ndarray, B: int, C: float, rho: int,
    total_time: float, feature_names: List[str] | None = None, verbose=True
) -> Dict:
    """
    时间切片（可调整）：
      T = total_time
      KS#1: dshor 10% T + ks 40% T
      bounds+l2+bigM: 30% T
      KS#2: 20% T
    """
    T = float(total_time)
    t_dshor1 = 0.10*T; t_ks1 = 0.40*T
    t_bounds_l2_bigm = 0.30*T
    t_ks2 = 0.20*T

    # KS#1
    ks1 = kernel_search_budgeted(X, y, B, C, rho, feature_names, dshor_time=t_dshor1,
                                 ks_total_time=t_ks1, mip_gap=0.03, verbose=verbose)
    UB_star, idx_star, gap_star = ks1["UB"], ks1["selected_idx"], ks1["best_gap"]
    if verbose: print(f"[Alg3] KS#1: UB={_fmt_num(UB_star)}, gap={_fmt_num(gap_star)}")

    if not np.isfinite(UB_star):
        # 极少情况：直接返回 KS#1 结果
        return {"UB": np.inf, "gap": np.inf, "runtime": t_dshor1 + t_ks1, "selected_idx": []}

    # bounds + l2 + bigM
    start = time.monotonic()

    # l2-NLSVM 作为参考 UB
    l2 = solve_l2_nlsvm_mosek(X, y, C, time_limit=max(1.0, 0.3*t_bounds_l2_bigm), verbose=False)
    l2_obj = float(l2["obj"])

    # D-Shor-Co 的最优值，也用于保证 (19) 可行
    rel_chk = solve_dshor_co_mosek(X, y, B, C, time_limit=max(1.0, 0.2*t_bounds_l2_bigm), verbose=False)
    obj_dshor = float(rel_chk["obj"])

    # (19) 的 UB 取三者的最大值（确保可行）
    UB_for_bounds = max(
        (UB_star if np.isfinite(UB_star) else -np.inf),
        l2_obj, obj_dshor
    ) + 1e-9

    # 分配每个 j 的 min/max 界时间
    remain = max(0.0, t_bounds_l2_bigm - (time.monotonic()-start))
    per_bound = max(0.5, remain / max(1, 2*X.shape[1]))
    Mval = compute_M_by_prop41(X, y, B, C, UB_for_bounds, time_per_bound=per_bound, verbose=False)

    # BigM 触发判断
    l1_over_B = float(np.sum(np.abs(np.r_[l2["w_diag"], l2["w_cross"]]))) / max(1, B)
    if verbose: print(f"[Alg3] M={_fmt_num(Mval)}, ||w||_1/B={_fmt_num(l1_over_B)}")
    do_ks2 = (np.isfinite(Mval) and (Mval < l1_over_B))

    # BigM warm-start → 初始化选择
    if do_ks2:
        remain = max(0.0, t_bounds_l2_bigm - (time.monotonic()-start))
        bigm = solve_dshor_co_bigm_mosek(X, y, B, C, Mbig=Mval, time_limit=max(1.0, 0.5*remain), verbose=False)
        init_sel = [j for j in range(X.shape[1]) if bigm["t"][j] < 0.5]
    else:
        init_sel = idx_star

    # KS#2（使用 init_sel 作种子）
    if t_ks2 > 1.0:
        rel2 = solve_dshor_co_mosek(X, y, B, C, time_limit=0.2*t_ks2, verbose=False)
        order = np.argsort(rel2["t_rank"])
        m, n = X.shape
        rho2 = max(1, min(rho, n))
        groups = [order[i*rho2: min((i+1)*rho2, n)].tolist() for i in range(math.ceil(n/rho2))]
        if groups:
            groups[0] = sorted(set(groups[0]).union(init_sel))

        start2 = time.monotonic()
        UB2, best_obj2, best_gap2 = UB_star, UB_star, gap_star
        best_idx2: List[int] = idx_star
        K_bar: List[int] = list(init_sel)
        for k, K_k in enumerate(groups, start=1):
            elapsed = time.monotonic() - start2
            remain = max(0.0, t_ks2 - elapsed)
            if remain <= 1e-3: break
            per_iter = max(1.0, remain/(len(groups)-(k-1)))

            K_it_raw = sorted(set(K_k) | set(K_bar))
            K_it = _ensure_kernel_size(order, K_it_raw, B, extra=max(1, B//2))
            seed = best_idx2 if best_idx2 else K_it[:B]

            sol = solve_cop_kernel_gurobi(
                X, y, B, C, kernel_set=K_it, UB=UB2,
                time_limit=per_iter, mipgap=0.03, verbose=verbose,
                feature_names=feature_names, start_idx=seed, favor_feasible=True
            )
            if np.isfinite(sol["objval"]) and (sol["objval"] < best_obj2):
                best_obj2, best_gap2, best_idx2 = sol["objval"], sol["gap"], sol["selected_idx"]
            if np.isfinite(sol["objval"]) and (sol["objval"] < UB2): UB2 = sol["objval"]

            K_plus = [j for j in K_k if j in set(sol["selected_idx"])]
            K_bar  = sorted(set(K_bar).union(K_plus))

            if verbose:
                print(f"[KS2] iter {k}/{len(groups)} -> obj={_fmt_num(sol['objval'])}, gap={_fmt_num(sol['gap'])}, K^+={len(K_plus)}")

        if np.isfinite(best_obj2) and (best_obj2 <= UB_star):
            UB_star, gap_star, idx_star = best_obj2, best_gap2, best_idx2
            if verbose: print(f"[Alg3] Accept KS#2: UB={_fmt_num(UB_star)}, gap={_fmt_num(gap_star)}")

    return {"UB": UB_star, "gap": gap_star, "runtime": T, "selected_idx": idx_star}

# -------------------- Full Co-NLSVM (same total time) --------------------
def conlsvm_full_same_budget(X: np.ndarray, y: np.ndarray, B: int, C: float,
                             total_time: float, feature_names: List[str] | None = None,
                             verbose=False) -> Dict:
    # 用 D-Shor-Co 的排序前 B 作为 warm-start 种子
    rel = solve_dshor_co_mosek(X, y, B, C, time_limit=0.1*total_time, verbose=False)
    order = np.argsort(rel["t_rank"]).tolist()
    seed = order[:min(B, len(order))]
    sol = solve_cop_kernel_gurobi(
        X, y, B, C, kernel_set=range(X.shape[1]), UB=None,
        time_limit=0.9*total_time, mipgap=0.03, verbose=verbose,
        feature_names=feature_names, start_idx=seed, favor_feasible=True
    )
    return {"UB": sol["objval"], "gap": sol["gap"], "runtime": 0.1*total_time + sol["runtime"],
            "selected_idx": sol["selected_idx"]}

# -------------------- One-call comparison --------------------
def run_comparison(X: np.ndarray, y: np.ndarray, B: int, C: float,
                   total_time: float, rho: int = 4, feature_names: List[str] | None = None,
                   verbose=True) -> pd.DataFrame:
    # Heuristic Algorithm-3
    res_alg3 = algorithm3_budgeted(X, y, B, C, rho, total_time, feature_names, verbose=verbose)
    # Full Co-NLSVM
    res_full = conlsvm_full_same_budget(X, y, B, C, total_time, feature_names, verbose=verbose)

    rows = [
        {"method":"Algorithm-3 (KS+Bounds+BigM+KS)", "UB":res_alg3["UB"], "MIPGap":res_alg3["gap"], "runtime":res_alg3["runtime"],
         "selected_k":len(res_alg3["selected_idx"])},
        {"method":"Full Co-NLSVM (indicator)",       "UB":res_full["UB"], "MIPGap":res_full["gap"], "runtime":res_full["runtime"],
         "selected_k":len(res_full["selected_idx"])},
    ]
    df = pd.DataFrame(rows)
    print("\n=== Comparison (same total time) ===")
    print(df.to_string(index=False, formatters={"UB":_fmt_num, "MIPGap":_fmt_num, "runtime":lambda x:f"{x:.2f}s"}))
    return df

# %%
breast_cancer_wisconsin_prognostic = fetch_ucirepo(id=16)
X_df = breast_cancer_wisconsin_prognostic.data.features.replace('?', np.nan).dropna()
y_series = breast_cancer_wisconsin_prognostic.data.targets['Outcome'].loc[X_df.index]
feature_names = list(X_df.columns)
X = StandardScaler().fit_transform(X_df.values)

# y_series: 形如包含 'N' / 'R' 的 pandas Series
y_str = y_series.astype(str).str.strip().str.upper().values

# 检查是否真的是二分类且只含 N/R
uniq = np.unique(y_str)
if not set(uniq).issubset({"N", "R"}) or len(uniq) != 2:
    raise ValueError(f"期望标签为 {{'N','R'}}，但实际唯一取值={uniq}")

# 约定：N -> +1，R -> -1  （和你之前的一致）
y = np.where(y_str == "N", 1.0, -1.0)

# 假设你已准备好 X, y（y ∈ {-1,+1}）, 以及 feature_names（可选）
B, C = 5, 1.0
T_total = 120.0   # 两侧统一总时间（秒）
rho = 4

df_cmp = run_comparison(X, y, B, C, total_time=T_total, rho=rho, feature_names=feature_names, verbose=True)
# Out:
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 5.2766272555551650e+00
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  5.2766272555551650e+00
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 222 rows, 789 columns and 109288 nonzeros
# Model fingerprint: 0x4e68f2ba
# Model has 561 quadratic objective terms
# Model has 1089 simple general constraints
#   1089 INDICATOR
# Variable types: 756 continuous, 33 integer (33 binary)
# Coefficient statistics:
#   Matrix range     [5e-08, 7e+01]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# Loaded user MIP start with objective 194
#
# Presolve removed 27 rows and 559 columns
# Presolve time: 0.04s
# Presolved: 195 rows, 230 columns, 5827 nonzeros
# Presolved model has 49 SOS constraint(s)
# Presolved model has 28 quadratic objective terms
# Variable types: 223 continuous, 7 integer (7 binary)
# Root relaxation presolved: 194 rows, 223 columns, 5820 nonzeros
# Root relaxation presolved model has 28 quadratic objective terms
#
#
# Root relaxation: objective 8.724033e+01, 778 iterations, 0.07 seconds (0.03 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   87.24033    0   14  194.00000   87.24033  55.0%     -    0s
# H    0     0                     103.0975345   87.24033  15.4%     -    0s
# H    0     0                      90.9927391   87.24033  4.12%     -    0s
#      0     0   87.24033    0   14   90.99274   87.24033  4.12%     -    0s
#      0     2   87.24033    0   14   90.99274   87.24033  4.12%     -    0s
#
# Explored 37 nodes (2238 simplex iterations) in 0.28 seconds (0.14 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 90.9927 194
#
# Optimal solution found (tolerance 3.00e-02)
# Best objective 9.099273905709e+01, best bound 9.099273905709e+01, gap 0.0000%
# [KS] iter 1/9 -> obj=90.9927, gap=0, K^+=2
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 5.8212552124996364e+00
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  5.8212552124996364e+00
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 222 rows, 789 columns and 109288 nonzeros
# Model fingerprint: 0x6e09a0e9
# Model has 561 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 1089 simple general constraints
#   1089 INDICATOR
# Variable types: 756 continuous, 33 integer (33 binary)
# Coefficient statistics:
#   Matrix range     [5e-08, 7e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
#   QRHS range       [9e+01, 9e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 71 rows and 0 columns
# Presolve removed 0 rows and 559 columns
# Presolve time: 0.07s
# Presolved: 294 rows, 258 columns, 6245 nonzeros
# Presolved model has 28 quadratic objective terms
# Presolved model has 28 quadratic constraint(s)
# Variable types: 251 continuous, 7 integer (7 binary)
# Root relaxation presolved: 294 rows, 230 columns, 6217 nonzeros
# Root relaxation presolved model has 28 quadratic objective terms
#
#
# Root relaxation: objective 8.696784e+01, 661 iterations, 0.04 seconds (0.02 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      90.9927400   86.96784  4.42%     -    0s
# H    0     0                      90.9927391   86.96784  4.42%     -    0s
#      0     0   86.96784    0    3   90.99274   86.96784  4.42%     -    0s
#      0     0   86.96784    0    3   90.99274   86.96784  4.42%     -    0s
#      0     0   86.96784    0    3   90.99274   86.96784  4.42%     -    0s
#      0     0   86.96784    0    3   90.99274   86.96784  4.42%     -    0s
#      0     0   86.96784    0    3   90.99274   86.96784  4.42%     -    0s
# H    0     0                      89.8844276   86.96784  3.24%     -    0s
#
# Cutting planes:
#   MIR: 2
#   Relax-and-lift: 1
#
# Explored 1 nodes (741 simplex iterations) in 0.72 seconds (0.21 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 89.8844 90.9927
#
# Optimal solution found (tolerance 3.00e-02)
# Best objective 8.988442758276e+01, best bound 8.988442758276e+01, gap 0.0000%
# [KS] iter 2/9 -> obj=89.8844, gap=0, K^+=3
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 6.4520933857139813e+00
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  6.4520933857139813e+00
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 220 rows, 789 columns and 109288 nonzeros
# Model fingerprint: 0x141aa7fa
# Model has 561 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 1089 simple general constraints
#   1089 INDICATOR
# Variable types: 756 continuous, 33 integer (33 binary)
# Coefficient statistics:
#   Matrix range     [5e-08, 7e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
#   QRHS range       [9e+01, 9e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
# User MIP start violates constraint fix_outside_30 by 1.000000000
#
# Presolve added 137 rows and 0 columns
# Presolve removed 0 rows and 540 columns
# Presolve time: 0.06s
# Presolved: 358 rows, 294 columns, 9690 nonzeros
# Presolved model has 45 quadratic objective terms
# Presolved model has 45 quadratic constraint(s)
# Variable types: 285 continuous, 9 integer (9 binary)
# Root relaxation presolved: 358 rows, 249 columns, 9645 nonzeros
# Root relaxation presolved model has 45 quadratic objective terms
#
#
# Root relaxation: objective 7.458350e+01, 556 iterations, 0.06 seconds (0.03 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   74.58350    0    5          -   74.58350      -     -    0s
#      0     0   74.58350    0    5          -   74.58350      -     -    0s
#      0     0   74.58350    0    6          -   74.58350      -     -    0s
#      0     0   74.58350    0    6          -   74.58350      -     -    0s
#      0     0   74.58350    0    6          -   74.58350      -     -    0s
# H    0     0                      89.8782900   77.11700  14.2%     -    1s
# H    0     0                      89.8267641   77.11700  14.1%     -    2s
# H    0     0                      89.8267625   77.11700  14.1%     -    2s
# H    0     0                      88.1192209   77.11700  12.5%     -    2s
#      0     2   77.11700    0    6   88.11922   77.11700  12.5%     -    2s
# H    4     8                      88.1192192   77.11700  12.5%  22.8    2s
# H   53    19                      87.7392463   77.11700  12.1%  77.0    2s
# *   53    19               7      87.7392463   77.11700  12.1%  80.7    2s
# H  103    13                      87.5985294   77.15161  11.9%  72.4    2s
# *  103    13               6      87.5985294   77.15161  11.9%  73.7    2s
# H  108    14                      87.5985291   82.29844  6.05%  74.7    2s
# *  135     6               6      87.5985285   82.66456  5.63%  66.7    2s
#
# Cutting planes:
#   MIR: 1
#   Relax-and-lift: 1
#
# Explored 149 nodes (10442 simplex iterations) in 2.89 seconds (1.45 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 5: 87.5985 87.7392 88.1192 ... 89.8783
#
# Optimal solution found (tolerance 3.00e-02)
# Best objective 8.759852854085e+01, best bound 8.616955607344e+01, gap 1.6313%
# [KS] iter 3/9 -> obj=87.5985, gap=0.0163127, K^+=3
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 6.9498780333330314e+00
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  6.9498780333330314e+00
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 217 rows, 789 columns and 109288 nonzeros
# Model fingerprint: 0x6c1348de
# Model has 561 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 1089 simple general constraints
#   1089 INDICATOR
# Variable types: 756 continuous, 33 integer (33 binary)
# Coefficient statistics:
#   Matrix range     [5e-08, 7e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
#   QRHS range       [9e+01, 9e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 266 rows and 0 columns
# Presolve removed 0 rows and 504 columns
# Presolve time: 0.08s
# Presolved: 484 rows, 363 columns, 16380 nonzeros
# Presolved model has 78 quadratic objective terms
# Presolved model has 78 quadratic constraint(s)
# Variable types: 351 continuous, 12 integer (12 binary)
# Root relaxation presolved: 484 rows, 285 columns, 16302 nonzeros
# Root relaxation presolved model has 78 quadratic objective terms
#
#
# Root relaxation: objective 6.710236e+01, 514 iterations, 0.06 seconds (0.04 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      87.5985260   67.10236  23.4%     -    0s
#      0     0   67.10236    0    8   87.59853   67.10236  23.4%     -    0s
#      0     0   67.10236    0    8   87.59853   67.10236  23.4%     -    0s
#      0     0   67.10236    0    8   87.59853   67.10236  23.4%     -    0s
#      0     0   67.10236    0    8   87.59853   67.10236  23.4%     -    0s
#      0     0   67.10236    0    8   87.59853   67.10236  23.4%     -    0s
#      0     2   68.56141    0    8   87.59853   68.56141  21.7%     -    3s
#    307    70     cutoff   10        87.59853   77.98806  11.0%   101    5s
#
# Explored 776 nodes (67495 simplex iterations) in 6.31 seconds (5.10 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 87.5985
#
# Optimal solution found (tolerance 3.00e-02)
# Best objective 8.759852401301e+01, best bound 8.561742860817e+01, gap 2.2616%
# [KS] iter 4/9 -> obj=87.5985, gap=0.0226156, K^+=0
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 6.9473839199999929e+00
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  6.9473839199999929e+00
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 217 rows, 789 columns and 109288 nonzeros
# Model fingerprint: 0x6014e810
# Model has 561 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 1089 simple general constraints
#   1089 INDICATOR
# Variable types: 756 continuous, 33 integer (33 binary)
# Coefficient statistics:
#   Matrix range     [5e-08, 7e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
#   QRHS range       [9e+01, 9e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 266 rows and 0 columns
# Presolve removed 0 rows and 504 columns
# Presolve time: 0.06s
# Presolved: 484 rows, 363 columns, 16380 nonzeros
# Presolved model has 78 quadratic objective terms
# Presolved model has 78 quadratic constraint(s)
# Variable types: 351 continuous, 12 integer (12 binary)
# Root relaxation presolved: 484 rows, 285 columns, 16302 nonzeros
# Root relaxation presolved model has 78 quadratic objective terms
#
#
# Root relaxation: objective 5.696190e+01, 431 iterations, 0.05 seconds (0.04 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   56.96190    0    8          -   56.96190      -     -    0s
#      0     0   56.96190    0    8          -   56.96190      -     -    0s
#      0     0   56.96190    0    8          -   56.96190      -     -    0s
#      0     0   56.96190    0    8          -   56.96190      -     -    0s
#      0     0   56.96190    0    8          -   56.96190      -     -    0s
# H    0     0                      87.5879044   57.87708  33.9%     -    3s
#      0     2   57.87708    0    8   87.58790   57.87708  33.9%     -    4s
# H   28    17                      87.5373287   57.87708  33.9%  92.3    4s
# *   28    17               6      87.5373287   57.87708  33.9%   110    4s
# H   41    20                      87.2866810   57.87708  33.7%   134    4s
# *   41    20               8      87.2866810   57.87708  33.7%   144    4s
# H   88    25                      86.8576319   59.23037  31.8%   139    4s
# *   88    25              10      86.8576319   59.23037  31.8%   142    4s
#    104    31   70.49227    7    5   86.85763   59.41689  31.6%   140    5s
# H  206    50                      86.5482885   66.55403  23.1%   137    5s
# *  206    50               9      86.5482885   66.55403  23.1%   138    5s
# H  277    55                      86.2531419   67.96327  21.2%   133    6s
# *  277    55              11      86.2531419   67.96327  21.2%   133    6s
#
# Explored 452 nodes (56534 simplex iterations) in 6.95 seconds (5.11 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 5: 86.2531 86.5483 86.8576 ... 87.5373
#
# Time limit reached
# Best objective 8.625314190830e+01, best bound 7.541881794520e+01, gap 12.5611%
# [KS] iter 5/9 -> obj=86.2531, gap=0.125611, K^+=2
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 6.7916220499992050e+00
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  6.7916220499992050e+00
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 215 rows, 789 columns and 109288 nonzeros
# Model fingerprint: 0xa7e217d2
# Model has 561 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 1089 simple general constraints
#   1089 INDICATOR
# Variable types: 756 continuous, 33 integer (33 binary)
# Coefficient statistics:
#   Matrix range     [5e-08, 7e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
#   QRHS range       [9e+01, 9e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 372 rows and 0 columns
# Presolve removed 0 rows and 475 columns
# Presolve time: 0.09s
# Presolved: 588 rows, 419 columns, 21855 nonzeros
# Presolved model has 105 quadratic objective terms
# Presolved model has 105 quadratic constraint(s)
# Variable types: 405 continuous, 14 integer (14 binary)
# Root relaxation presolved: 588 rows, 314 columns, 21750 nonzeros
# Root relaxation presolved model has 105 quadratic objective terms
#
#
# Root relaxation: objective 3.731475e+01, 371 iterations, 0.10 seconds (0.04 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      86.2531266   37.31475  56.7%     -    0s
#      0     0   37.31475    0   10   86.25313   37.31475  56.7%     -    0s
#      0     0   37.31475    0   10   86.25313   37.31475  56.7%     -    0s
#      0     0   37.31475    0   10   86.25313   37.31475  56.7%     -    0s
#      0     0   37.31475    0   10   86.25313   37.31475  56.7%     -    0s
#      0     0   37.31475    0   10   86.25313   37.31475  56.7%     -    0s
#      0     2   37.31475    0   10   86.25313   37.31475  56.7%     -    5s
#
# Explored 289 nodes (44346 simplex iterations) in 6.81 seconds (5.48 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 86.2531
#
# Time limit reached
# Warning: max constraint violation (8.5128e-06) exceeds tolerance
# Best objective 8.625312272334e+01, best bound 5.583026504838e+01, gap 35.2716%
# [KS] iter 6/9 -> obj=86.2531, gap=0.352716, K^+=0
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 6.5883292666646112e+00
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  6.5883292666646112e+00
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 215 rows, 789 columns and 109288 nonzeros
# Model fingerprint: 0xc9cb7cf1
# Model has 561 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 1089 simple general constraints
#   1089 INDICATOR
# Variable types: 756 continuous, 33 integer (33 binary)
# Coefficient statistics:
#   Matrix range     [5e-08, 7e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
#   QRHS range       [9e+01, 9e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 372 rows and 0 columns
# Presolve removed 0 rows and 475 columns
# Presolve time: 0.16s
# Presolved: 588 rows, 419 columns, 21855 nonzeros
# Presolved model has 105 quadratic objective terms
# Presolved model has 105 quadratic constraint(s)
# Variable types: 405 continuous, 14 integer (14 binary)
# Root relaxation presolved: 588 rows, 314 columns, 21750 nonzeros
# Root relaxation presolved model has 105 quadratic objective terms
#
#
# Root relaxation: objective 4.794779e+01, 440 iterations, 0.07 seconds (0.05 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   47.94779    0   10          -   47.94779      -     -    0s
#      0     0   47.94779    0   10          -   47.94779      -     -    0s
#      0     0   47.94779    0   10          -   47.94779      -     -    0s
#      0     0   47.94779    0   10          -   47.94779      -     -    0s
#      0     0   47.94779    0   10          -   47.94779      -     -    0s
#
# Explored 1 nodes (736 simplex iterations) in 6.59 seconds (5.51 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 0
#
# Time limit reached
# Best objective -, best bound 4.794778851967e+01, gap -
# [KS] iter 7/9 -> obj=inf, gap=inf, K^+=0
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 6.2809909999996307e+00
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  6.2809909999996307e+00
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 215 rows, 789 columns and 109288 nonzeros
# Model fingerprint: 0x396e4392
# Model has 561 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 1089 simple general constraints
#   1089 INDICATOR
# Variable types: 756 continuous, 33 integer (33 binary)
# Coefficient statistics:
#   Matrix range     [5e-08, 7e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
#   QRHS range       [9e+01, 9e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 372 rows and 0 columns
# Presolve removed 0 rows and 475 columns
# Presolve time: 0.17s
# Presolved: 588 rows, 419 columns, 21855 nonzeros
# Presolved model has 105 quadratic objective terms
# Presolved model has 105 quadratic constraint(s)
# Variable types: 405 continuous, 14 integer (14 binary)
# Root relaxation presolved: 588 rows, 314 columns, 21750 nonzeros
# Root relaxation presolved model has 105 quadratic objective terms
#
#
# Root relaxation: objective 3.800834e+01, 332 iterations, 0.11 seconds (0.04 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   38.00834    0   10          -   38.00834      -     -    0s
#      0     0   38.00834    0   10          -   38.00834      -     -    0s
#      0     0   38.00834    0   10          -   38.00834      -     -    0s
#      0     0   38.00834    0   10          -   38.00834      -     -    0s
#      0     0   38.00834    0   10          -   38.00834      -     -    1s
#
# Explored 1 nodes (624 simplex iterations) in 6.28 seconds (5.82 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 0
#
# Time limit reached
# Best objective -, best bound 4.253742352358e+01, gap -
# [KS] iter 8/9 -> obj=inf, gap=inf, K^+=0
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 5.6437808999980916e+00
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  5.6437808999980916e+00
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 218 rows, 789 columns and 109288 nonzeros
# Model fingerprint: 0x1e02a1b3
# Model has 561 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 1089 simple general constraints
#   1089 INDICATOR
# Variable types: 756 continuous, 33 integer (33 binary)
# Coefficient statistics:
#   Matrix range     [5e-08, 7e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
#   QRHS range       [9e+01, 9e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 219 rows and 0 columns
# Presolve removed 0 rows and 517 columns
# Presolve time: 0.10s
# Presolved: 438 rows, 338 columns, 13947 nonzeros
# Presolved model has 66 quadratic objective terms
# Presolved model has 66 quadratic constraint(s)
# Variable types: 327 continuous, 11 integer (11 binary)
# Root relaxation presolved: 438 rows, 272 columns, 13881 nonzeros
# Root relaxation presolved model has 66 quadratic objective terms
#
#
# Root relaxation: objective 6.007038e+01, 514 iterations, 0.06 seconds (0.04 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   60.07038    0    7          -   60.07038      -     -    0s
#      0     0   60.07038    0    7          -   60.07038      -     -    0s
#      0     0   60.07038    0    8          -   60.07038      -     -    0s
#      0     0   60.07038    0    8          -   60.07038      -     -    0s
#      0     0   60.07038    0    8          -   60.07038      -     -    0s
# H    0     0                      86.2184148   65.71688  23.8%     -    4s
# H    0     0                      84.4676256   65.71688  22.2%     -    5s
# H    0     0                      84.4676253   65.71688  22.2%     -    5s
#      0     2   65.71688    0    8   84.46763   65.71688  22.2%     -    5s
#
# Cutting planes:
#   MIR: 2
#
# Explored 188 nodes (19833 simplex iterations) in 5.65 seconds (5.78 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 84.4676
#
# Time limit reached
# Best objective 8.446762533318e+01, best bound 6.860396682430e+01, gap 18.7808%
# [KS] iter 9/9 -> obj=84.4676, gap=0.187808, K^+=1
# [Alg3] KS#1: UB=84.4676, gap=0.187808
# [Alg3] M=12.9975, ||w||_1/B=7.14083
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 2.6666663000004416e+00
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  2.6666663000004416e+00
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 220 rows, 789 columns and 109288 nonzeros
# Model fingerprint: 0xab6093d3
# Model has 561 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 1089 simple general constraints
#   1089 INDICATOR
# Variable types: 756 continuous, 33 integer (33 binary)
# Coefficient statistics:
#   Matrix range     [5e-08, 7e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
#   QRHS range       [8e+01, 8e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 137 rows and 0 columns
# Presolve removed 0 rows and 540 columns
# Presolve time: 0.06s
# Presolved: 358 rows, 294 columns, 9690 nonzeros
# Presolved model has 45 quadratic objective terms
# Presolved model has 45 quadratic constraint(s)
# Variable types: 285 continuous, 9 integer (9 binary)
# Root relaxation presolved: 358 rows, 249 columns, 9645 nonzeros
# Root relaxation presolved model has 45 quadratic objective terms
#
#
# Root relaxation: objective 6.528031e+01, 474 iterations, 0.04 seconds (0.02 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      84.4676248   65.28031  22.7%     -    0s
#      0     0   65.28031    0    5   84.46762   65.28031  22.7%     -    0s
#      0     0   65.28031    0    5   84.46762   65.28031  22.7%     -    0s
#      0     0   65.28031    0    6   84.46762   65.28031  22.7%     -    0s
#      0     0   65.28031    0    6   84.46762   65.28031  22.7%     -    0s
#      0     0   65.28031    0    6   84.46762   65.28031  22.7%     -    0s
#      0     2   77.74334    0    6   84.46762   77.74334  7.96%     -    1s
#
# Cutting planes:
#   MIR: 2
#
# Explored 79 nodes (5967 simplex iterations) in 1.59 seconds (0.77 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 84.4676
#
# Optimal solution found (tolerance 3.00e-02)
# Best objective 8.446762482074e+01, best bound 8.379140998378e+01, gap 0.8006%
# [KS2] iter 1/9 -> obj=84.4676, gap=0.00800561, K^+=5
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 2.7549179375000676e+00
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  2.7549179375000676e+00
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 220 rows, 789 columns and 109288 nonzeros
# Model fingerprint: 0xa384905b
# Model has 561 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 1089 simple general constraints
#   1089 INDICATOR
# Variable types: 756 continuous, 33 integer (33 binary)
# Coefficient statistics:
#   Matrix range     [5e-08, 7e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
#   QRHS range       [8e+01, 8e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 137 rows and 0 columns
# Presolve removed 0 rows and 540 columns
# Presolve time: 0.08s
# Presolved: 358 rows, 294 columns, 9690 nonzeros
# Presolved model has 45 quadratic objective terms
# Presolved model has 45 quadratic constraint(s)
# Variable types: 285 continuous, 9 integer (9 binary)
# Root relaxation presolved: 358 rows, 249 columns, 9645 nonzeros
# Root relaxation presolved model has 45 quadratic objective terms
#
#
# Root relaxation: objective 7.631708e+01, 555 iterations, 0.07 seconds (0.03 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      84.4676248   76.31708  9.65%     -    0s
#      0     0   76.31708    0    5   84.46762   76.31708  9.65%     -    0s
#      0     0   76.31708    0    5   84.46762   76.31708  9.65%     -    0s
#      0     0   76.31708    0    6   84.46762   76.31708  9.65%     -    0s
#      0     0   76.31708    0    6   84.46762   76.31708  9.65%     -    0s
#      0     0   76.31708    0    6   84.46762   76.31708  9.65%     -    0s
#
# Cutting planes:
#   MIR: 1
#
# Explored 1 nodes (693 simplex iterations) in 1.18 seconds (0.39 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 84.4676
#
# Optimal solution found (tolerance 3.00e-02)
# Best objective 8.446762482074e+01, best bound 8.446762482074e+01, gap 0.0000%
# [KS2] iter 2/9 -> obj=84.4676, gap=0, K^+=0
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 2.9145658428574928e+00
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  2.9145658428574928e+00
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 222 rows, 789 columns and 109288 nonzeros
# Model fingerprint: 0x273c1222
# Model has 561 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 1089 simple general constraints
#   1089 INDICATOR
# Variable types: 756 continuous, 33 integer (33 binary)
# Coefficient statistics:
#   Matrix range     [5e-08, 7e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
#   QRHS range       [8e+01, 8e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 71 rows and 0 columns
# Presolve removed 0 rows and 559 columns
# Presolve time: 0.09s
# Presolved: 294 rows, 258 columns, 6245 nonzeros
# Presolved model has 28 quadratic objective terms
# Presolved model has 28 quadratic constraint(s)
# Variable types: 251 continuous, 7 integer (7 binary)
# Root relaxation presolved: 294 rows, 230 columns, 6217 nonzeros
# Root relaxation presolved model has 28 quadratic objective terms
#
#
# Root relaxation: objective 7.965607e+01, 526 iterations, 0.04 seconds (0.02 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      84.4676248   79.65607  5.70%     -    0s
#      0     0   79.65607    0    3   84.46762   79.65607  5.70%     -    0s
#      0     0   79.65607    0    3   84.46762   79.65607  5.70%     -    0s
#      0     0   79.65607    0    4   84.46762   79.65607  5.70%     -    0s
#      0     0   79.65607    0    4   84.46762   79.65607  5.70%     -    0s
#      0     0   79.65607    0    4   84.46762   79.65607  5.70%     -    0s
#
# Cutting planes:
#   MIR: 2
#
# Explored 1 nodes (648 simplex iterations) in 0.71 seconds (0.21 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 84.4676
#
# Optimal solution found (tolerance 3.00e-02)
# Best objective 8.446762482074e+01, best bound 8.446762482074e+01, gap 0.0000%
# [KS2] iter 3/9 -> obj=84.4676, gap=0, K^+=2
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 3.1813702000011594e+00
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  3.1813702000011594e+00
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 220 rows, 789 columns and 109288 nonzeros
# Model fingerprint: 0x6d4e1af0
# Model has 561 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 1089 simple general constraints
#   1089 INDICATOR
# Variable types: 756 continuous, 33 integer (33 binary)
# Coefficient statistics:
#   Matrix range     [5e-08, 7e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
#   QRHS range       [8e+01, 8e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 137 rows and 0 columns
# Presolve removed 0 rows and 540 columns
# Presolve time: 0.08s
# Presolved: 358 rows, 294 columns, 9690 nonzeros
# Presolved model has 45 quadratic objective terms
# Presolved model has 45 quadratic constraint(s)
# Variable types: 285 continuous, 9 integer (9 binary)
# Root relaxation presolved: 358 rows, 249 columns, 9645 nonzeros
# Root relaxation presolved model has 45 quadratic objective terms
#
#
# Root relaxation: objective 6.826414e+01, 462 iterations, 0.05 seconds (0.02 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      84.4676248   68.26414  19.2%     -    0s
#      0     0   68.26414    0    5   84.46762   68.26414  19.2%     -    0s
#      0     0   68.26414    0    5   84.46762   68.26414  19.2%     -    0s
#      0     0   68.26414    0    6   84.46762   68.26414  19.2%     -    0s
#      0     0   68.26414    0    6   84.46762   68.26414  19.2%     -    0s
#      0     0   68.26414    0    6   84.46762   68.26414  19.2%     -    0s
#      0     2   77.19966    0    6   84.46762   77.19966  8.60%     -    1s
#
# Cutting planes:
#   MIR: 1
#
# Explored 118 nodes (5905 simplex iterations) in 1.82 seconds (0.81 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 84.4676
#
# Optimal solution found (tolerance 3.00e-02)
# Best objective 8.446762482074e+01, best bound 8.317383467246e+01, gap 1.5317%
# [KS2] iter 4/9 -> obj=84.4676, gap=0.015317, K^+=0
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 3.3298931000012089e+00
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  3.3298931000012089e+00
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 222 rows, 789 columns and 109288 nonzeros
# Model fingerprint: 0xf58a1710
# Model has 561 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 1089 simple general constraints
#   1089 INDICATOR
# Variable types: 756 continuous, 33 integer (33 binary)
# Coefficient statistics:
#   Matrix range     [5e-08, 7e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
#   QRHS range       [8e+01, 8e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 71 rows and 0 columns
# Presolve removed 0 rows and 559 columns
# Presolve time: 0.04s
# Presolved: 294 rows, 258 columns, 6245 nonzeros
# Presolved model has 28 quadratic objective terms
# Presolved model has 28 quadratic constraint(s)
# Variable types: 251 continuous, 7 integer (7 binary)
# Root relaxation presolved: 294 rows, 230 columns, 6217 nonzeros
# Root relaxation presolved model has 28 quadratic objective terms
#
#
# Root relaxation: objective 8.100659e+01, 537 iterations, 0.03 seconds (0.02 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      84.4676248   81.00659  4.10%     -    0s
#      0     0   81.00659    0    3   84.46762   81.00659  4.10%     -    0s
#      0     0   81.00659    0    3   84.46762   81.00659  4.10%     -    0s
#      0     0   81.00659    0    4   84.46762   81.00659  4.10%     -    0s
#      0     0   81.00659    0    4   84.46762   81.00659  4.10%     -    0s
#      0     0   81.00659    0    4   84.46762   81.00659  4.10%     -    0s
#
# Cutting planes:
#   MIR: 5
#
# Explored 1 nodes (631 simplex iterations) in 0.63 seconds (0.21 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 84.4676
#
# Optimal solution found (tolerance 3.00e-02)
# Best objective 8.446762482074e+01, best bound 8.446762482074e+01, gap 0.0000%
# [KS2] iter 5/9 -> obj=84.4676, gap=0, K^+=2
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 3.8481095750012173e+00
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  3.8481095750012173e+00
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 220 rows, 789 columns and 109288 nonzeros
# Model fingerprint: 0x58f7aca7
# Model has 561 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 1089 simple general constraints
#   1089 INDICATOR
# Variable types: 756 continuous, 33 integer (33 binary)
# Coefficient statistics:
#   Matrix range     [5e-08, 7e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
#   QRHS range       [8e+01, 8e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 137 rows and 0 columns
# Presolve removed 0 rows and 540 columns
# Presolve time: 0.09s
# Presolved: 358 rows, 294 columns, 9690 nonzeros
# Presolved model has 45 quadratic objective terms
# Presolved model has 45 quadratic constraint(s)
# Variable types: 285 continuous, 9 integer (9 binary)
# Root relaxation presolved: 358 rows, 249 columns, 9645 nonzeros
# Root relaxation presolved model has 45 quadratic objective terms
#
#
# Root relaxation: objective 7.354673e+01, 467 iterations, 0.06 seconds (0.02 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      84.4676248   73.54673  12.9%     -    0s
#      0     0   73.54673    0    5   84.46762   73.54673  12.9%     -    0s
#      0     0   73.54673    0    5   84.46762   73.54673  12.9%     -    0s
#      0     0   73.54673    0    6   84.46762   73.54673  12.9%     -    0s
#      0     0   73.54673    0    6   84.46762   73.54673  12.9%     -    0s
#      0     0   73.54673    0    6   84.46762   73.54673  12.9%     -    0s
#
# Cutting planes:
#   MIR: 3
#
# Explored 1 nodes (631 simplex iterations) in 1.22 seconds (0.41 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 84.4676
#
# Optimal solution found (tolerance 3.00e-02)
# Best objective 8.446762482074e+01, best bound 8.446762482074e+01, gap 0.0000%
# [KS2] iter 6/9 -> obj=84.4676, gap=0, K^+=0
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 4.5231976333355606e+00
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  4.5231976333355606e+00
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 220 rows, 789 columns and 109288 nonzeros
# Model fingerprint: 0xeff36784
# Model has 561 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 1089 simple general constraints
#   1089 INDICATOR
# Variable types: 756 continuous, 33 integer (33 binary)
# Coefficient statistics:
#   Matrix range     [5e-08, 7e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
#   QRHS range       [8e+01, 8e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 137 rows and 0 columns
# Presolve removed 0 rows and 540 columns
# Presolve time: 0.05s
# Presolved: 358 rows, 294 columns, 9690 nonzeros
# Presolved model has 45 quadratic objective terms
# Presolved model has 45 quadratic constraint(s)
# Variable types: 285 continuous, 9 integer (9 binary)
# Root relaxation presolved: 358 rows, 249 columns, 9645 nonzeros
# Root relaxation presolved model has 45 quadratic objective terms
#
#
# Root relaxation: objective 7.609860e+01, 565 iterations, 0.05 seconds (0.03 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      84.4676248   76.09860  9.91%     -    0s
#      0     0   76.09860    0    5   84.46762   76.09860  9.91%     -    0s
#      0     0   76.09860    0    5   84.46762   76.09860  9.91%     -    0s
#      0     0   76.09860    0    5   84.46762   76.09860  9.91%     -    0s
#      0     0   76.09860    0    5   84.46762   76.09860  9.91%     -    0s
#      0     0   76.09860    0    5   84.46762   76.09860  9.91%     -    0s
#
# Cutting planes:
#   Relax-and-lift: 1
#
# Explored 1 nodes (711 simplex iterations) in 1.22 seconds (0.39 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 84.4676
#
# Optimal solution found (tolerance 3.00e-02)
# Best objective 8.446762482074e+01, best bound 8.446762482074e+01, gap 0.0000%
# [KS2] iter 7/9 -> obj=84.4676, gap=0, K^+=0
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 5.90974615000232
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  5.90974615000232
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 220 rows, 789 columns and 109288 nonzeros
# Model fingerprint: 0x7329907c
# Model has 561 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 1089 simple general constraints
#   1089 INDICATOR
# Variable types: 756 continuous, 33 integer (33 binary)
# Coefficient statistics:
#   Matrix range     [5e-08, 7e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
#   QRHS range       [8e+01, 8e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 137 rows and 0 columns
# Presolve removed 0 rows and 540 columns
# Presolve time: 0.05s
# Presolved: 358 rows, 294 columns, 9690 nonzeros
# Presolved model has 45 quadratic objective terms
# Presolved model has 45 quadratic constraint(s)
# Variable types: 285 continuous, 9 integer (9 binary)
# Root relaxation presolved: 358 rows, 249 columns, 9645 nonzeros
# Root relaxation presolved model has 45 quadratic objective terms
#
#
# Root relaxation: objective 7.218150e+01, 468 iterations, 0.03 seconds (0.02 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      84.4676248   72.18150  14.5%     -    0s
#      0     0   72.18150    0    5   84.46762   72.18150  14.5%     -    0s
#      0     0   72.18150    0    5   84.46762   72.18150  14.5%     -    0s
#      0     0   72.18150    0    6   84.46762   72.18150  14.5%     -    0s
#      0     0   72.18150    0    6   84.46762   72.18150  14.5%     -    0s
#      0     0   72.18150    0    6   84.46762   72.18150  14.5%     -    0s
#      0     0   72.18150    0    6   84.46762   72.18150  14.5%     -    0s
#
# Cutting planes:
#   MIR: 3
#   Relax-and-lift: 1
#
# Explored 1 nodes (627 simplex iterations) in 1.04 seconds (0.40 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 84.4676
#
# Optimal solution found (tolerance 3.00e-02)
# Best objective 8.446762482074e+01, best bound 8.378687611013e+01, gap 0.8059%
# [KS2] iter 8/9 -> obj=84.4676, gap=0.00805929, K^+=0
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 1.0164491200004704e+01
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  1.0164491200004704e+01
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 222 rows, 789 columns and 109288 nonzeros
# Model fingerprint: 0x251c4495
# Model has 561 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 1089 simple general constraints
#   1089 INDICATOR
# Variable types: 756 continuous, 33 integer (33 binary)
# Coefficient statistics:
#   Matrix range     [5e-08, 7e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
#   QRHS range       [8e+01, 8e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 71 rows and 0 columns
# Presolve removed 0 rows and 559 columns
# Presolve time: 0.05s
# Presolved: 294 rows, 258 columns, 6245 nonzeros
# Presolved model has 28 quadratic objective terms
# Presolved model has 28 quadratic constraint(s)
# Variable types: 251 continuous, 7 integer (7 binary)
# Root relaxation presolved: 294 rows, 230 columns, 6217 nonzeros
# Root relaxation presolved model has 28 quadratic objective terms
#
#
# Root relaxation: objective 7.636870e+01, 600 iterations, 0.05 seconds (0.02 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      84.4676263   76.36870  9.59%     -    0s
# H    0     0                      84.4676248   76.36870  9.59%     -    0s
#      0     0   76.36870    0    3   84.46762   76.36870  9.59%     -    0s
#      0     0   76.36870    0    3   84.46762   76.36870  9.59%     -    0s
#      0     0   84.46762    0    4   84.46762   84.46762  0.00%     -    0s
#
# Cutting planes:
#   MIR: 4
#
# Explored 1 nodes (694 simplex iterations) in 0.35 seconds (0.10 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 84.4676
#
# Optimal solution found (tolerance 3.00e-02)
# Best objective 8.446762482074e+01, best bound 8.446762482074e+01, gap 0.0000%
# [KS2] iter 9/9 -> obj=84.4676, gap=0, K^+=1
# [Alg3] Accept KS#2: UB=84.4676, gap=0.00800561
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 108
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  108
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 196 rows, 789 columns and 109288 nonzeros
# Model fingerprint: 0x93d1803c
# Model has 561 quadratic objective terms
# Model has 1089 simple general constraints
#   1089 INDICATOR
# Variable types: 756 continuous, 33 integer (33 binary)
# Coefficient statistics:
#   Matrix range     [5e-08, 7e+01]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# Loaded user MIP start with objective 194
#
# Presolve removed 1 rows and 0 columns
# Presolve time: 0.15s
# Presolved: 195 rows, 789 columns, 109255 nonzeros
# Presolved model has 1089 SOS constraint(s)
# Presolved model has 561 quadratic objective terms
# Variable types: 756 continuous, 33 integer (33 binary)
# Root relaxation presolved: 194 rows, 756 columns, 109222 nonzeros
# Root relaxation presolved model has 561 quadratic objective terms
#
#
# Root relaxation: objective 1.887502e+00, 155 iterations, 0.52 seconds (0.14 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    1.88750    0  924  194.00000    1.88750  99.0%     -    0s
# H    0     0                     152.0858391    1.88750  98.8%     -    0s
# H    0     0                      92.0000000    1.88750  97.9%     -    1s
#      0     0    1.88750    0  924   92.00000    1.88750  97.9%     -    2s
#      0     2    1.88750    0  924   92.00000    1.88750  97.9%     -    2s
# *   29    24               6      90.0224239    1.88750  97.9%   137    4s
#     31    24     cutoff    7        90.02242    1.88750  97.9%   152    5s
# *   34    24               7      88.8291838    1.88750  97.9%   166    5s
# *   58    22              10      87.1189186    1.88750  97.8%   269    7s
#     87    23     cutoff   14        87.11892    1.88750  97.8%   276   10s
# *  111    26              17      84.2976770    1.88750  97.8%   275   10s
# *  196    25              29      83.9576789    1.88750  97.8%   228   12s
#    250    30    3.69817    9  644   83.95768    2.10748  97.5%   213   15s
#    360    33     cutoff   22        83.95768    2.15023  97.4%   227   20s
#    483    42     cutoff    9        83.95768    2.33313  97.2%   213   25s
#    634    60     cutoff   20        83.95768    2.33313  97.2%   209   30s
#    771    66    9.39770   16  336   83.95768    2.97338  96.5%   210   35s
#    971    66    2.97338    8  696   83.95768    2.97338  96.5%   204   40s
#   1008   100     cutoff   14        83.95768    2.97338  96.5%   203   46s
#   1129   117    4.13853    8  696   83.95768    2.97338  96.5%   195   50s
#   1310   116    4.54319   10  594   83.95768    3.19173  96.2%   194   55s
#   1553   116     cutoff   21        83.95768    3.19173  96.2%   193   62s
#   1690   120   20.67533   19  234   83.95768    3.19173  96.2%   194   65s
#   1814   119    3.87093    8  696   83.95768    3.19173  96.2%   192   70s
#   2011   137    7.84542    9  594   83.95768    3.61091  95.7%   191   77s
# H 2072   137                      83.6364724    3.61091  95.7%   192   77s
#   2193   143    8.39978   10  594   83.63647    3.68630  95.6%   190   82s
#   2296   143     cutoff   19        83.63647    3.68630  95.6%   191   85s
#   2543   146    6.48272    8  696   83.63647    3.93326  95.3%   189   92s
#   2567   150   11.54681   10  594   83.63647    3.93326  95.3%   190   97s
#   2705   151   46.21602   23  126   83.63647    3.99214  95.2%   189  101s
#   2814   189   15.28475   15  374   83.63647    3.99214  95.2%   189  107s
#
# Explored 2961 nodes (554235 simplex iterations) in 108.04 seconds (93.77 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 9: 83.6365 83.9577 84.2977 ... 194
#
# Time limit reached
# Best objective 8.363647235206e+01, best bound 3.992141362120e+00, gap 95.2268%
#
# === Comparison (same total time) ===
#                          method      UB     MIPGap runtime  selected_k
# Algorithm-3 (KS+Bounds+BigM+KS) 84.4676 0.00800561 120.00s           5
#       Full Co-NLSVM (indicator) 83.6365   0.952268 120.08s           5

# %%
breast_cancer_wisconsin_prognostic = fetch_ucirepo(id=16)
X_df = breast_cancer_wisconsin_prognostic.data.features.replace('?', np.nan).dropna()
y_series = breast_cancer_wisconsin_prognostic.data.targets['Outcome'].loc[X_df.index]
feature_names = list(X_df.columns)
X = StandardScaler().fit_transform(X_df.values)

# y_series: 形如包含 'N' / 'R' 的 pandas Series
y_str = y_series.astype(str).str.strip().str.upper().values

# 检查是否真的是二分类且只含 N/R
uniq = np.unique(y_str)
if not set(uniq).issubset({"N", "R"}) or len(uniq) != 2:
    raise ValueError(f"期望标签为 {{'N','R'}}，但实际唯一取值={uniq}")

# 约定：N -> +1，R -> -1  （和你之前的一致）
y = np.where(y_str == "N", 1.0, -1.0)

# 假设你已准备好 X, y（y ∈ {-1,+1}）, 以及 feature_names（可选）
B, C = 10, 1.0
T_total = 120.0   # 两侧统一总时间（秒）
rho = 4

df_cmp = run_comparison(X, y, B, C, total_time=T_total, rho=rho, feature_names=feature_names, verbose=True)
# Out:
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 5.2963070000001204e+00
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  5.2963070000001204e+00
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 214 rows, 789 columns and 109288 nonzeros
# Model fingerprint: 0x2c27b0ac
# Model has 561 quadratic objective terms
# Model has 1089 simple general constraints
#   1089 INDICATOR
# Variable types: 756 continuous, 33 integer (33 binary)
# Coefficient statistics:
#   Matrix range     [5e-08, 7e+01]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# Loaded user MIP start with objective 194
#
# Presolve removed 19 rows and 459 columns
# Presolve time: 0.05s
# Presolved: 195 rows, 330 columns, 23683 nonzeros
# Presolved model has 225 SOS constraint(s)
# Presolved model has 120 quadratic objective terms
# Variable types: 315 continuous, 15 integer (15 binary)
# Root relaxation presolved: 194 rows, 315 columns, 23668 nonzeros
# Root relaxation presolved model has 120 quadratic objective terms
#
#
# Root relaxation: objective 3.982439e+01, 261 iterations, 0.08 seconds (0.04 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   39.82439    0   75  194.00000   39.82439  79.5%     -    0s
# H    0     0                     188.6582819   39.82439  78.9%     -    0s
# H    0     0                      80.7173834   39.82439  50.7%     -    0s
#      0     0   39.82439    0   75   80.71738   39.82439  50.7%     -    0s
# H    0     0                      75.6802152   39.82439  47.4%     -    0s
#      0     2   39.82439    0   75   75.68022   39.82439  47.4%     -    0s
# H   24    29                      69.7319856   39.82439  42.9%  35.6    0s
# *   60    63              10      66.9210309   39.82439  40.5%  46.4    1s
# *   88    63              13      62.9364073   39.82439  36.7%  57.5    1s
# H  206   113                      61.7761598   46.18190  25.2%  53.7    2s
# H  424   153                      60.1213084   48.45589  19.4%  44.9    3s
#    965   109     cutoff   13        60.12131   55.29945  8.02%  34.2    5s
#
# Explored 1074 nodes (35406 simplex iterations) in 5.30 seconds (4.76 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 8: 60.1213 61.7762 62.9364 ... 194
#
# Time limit reached
# Best objective 6.012130838406e+01, best bound 5.573240070023e+01, gap 7.3001%
# [KS] iter 1/9 -> obj=60.1213, gap=0.0730009, K^+=2
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 5.25872525000068
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  5.25872525000068
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 214 rows, 789 columns and 109288 nonzeros
# Model fingerprint: 0x4c96161c
# Model has 561 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 1089 simple general constraints
#   1089 INDICATOR
# Variable types: 756 continuous, 33 integer (33 binary)
# Coefficient statistics:
#   Matrix range     [5e-08, 7e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
#   QRHS range       [6e+01, 6e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 431 rows and 0 columns
# Presolve removed 0 rows and 459 columns
# Presolve time: 0.08s
# Presolved: 646 rows, 450 columns, 24897 nonzeros
# Presolved model has 120 quadratic objective terms
# Presolved model has 120 quadratic constraint(s)
# Variable types: 435 continuous, 15 integer (15 binary)
# Root relaxation presolved: 646 rows, 330 columns, 24777 nonzeros
# Root relaxation presolved model has 120 quadratic objective terms
#
#
# Root relaxation: objective 3.982439e+01, 313 iterations, 0.05 seconds (0.05 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      60.1213068   39.82439  33.8%     -    0s
#      0     0   39.82439    0    6   60.12131   39.82439  33.8%     -    0s
#      0     0   39.82439    0    6   60.12131   39.82439  33.8%     -    0s
#      0     0   39.82439    0    7   60.12131   39.82439  33.8%     -    0s
#      0     0   39.82439    0    7   60.12131   39.82439  33.8%     -    0s
#      0     0   39.82439    0    7   60.12131   39.82439  33.8%     -    0s
#      0     2   39.82439    0    7   60.12131   39.82439  33.8%     -    3s
#    264    68     cutoff   13        60.12131   46.02954  23.4%  74.5    5s
#
# Cutting planes:
#   MIR: 1
#
# Explored 326 nodes (24955 simplex iterations) in 5.27 seconds (4.64 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 60.1213
#
# Time limit reached
# Warning: max constraint violation (5.9917e-06) exceeds tolerance
# Best objective 6.012130680730e+01, best bound 4.709998097866e+01, gap 21.6584%
# [KS] iter 2/9 -> obj=60.1213, gap=0.216584, K^+=4
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 5.2143110571435374e+00
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  5.2143110571435374e+00
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 214 rows, 789 columns and 109288 nonzeros
# Model fingerprint: 0xc9537479
# Model has 561 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 1089 simple general constraints
#   1089 INDICATOR
# Variable types: 756 continuous, 33 integer (33 binary)
# Coefficient statistics:
#   Matrix range     [5e-08, 7e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
#   QRHS range       [6e+01, 6e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 431 rows and 0 columns
# Presolve removed 0 rows and 459 columns
# Presolve time: 0.08s
# Presolved: 646 rows, 450 columns, 24897 nonzeros
# Presolved model has 120 quadratic objective terms
# Presolved model has 120 quadratic constraint(s)
# Variable types: 435 continuous, 15 integer (15 binary)
# Root relaxation presolved: 646 rows, 330 columns, 24777 nonzeros
# Root relaxation presolved model has 120 quadratic objective terms
#
#
# Root relaxation: objective 3.982439e+01, 313 iterations, 0.05 seconds (0.05 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   39.82439    0    6          -   39.82439      -     -    0s
#      0     0   39.82439    0    6          -   39.82439      -     -    0s
#      0     0   39.82439    0    7          -   39.82439      -     -    0s
#      0     0   39.82439    0    7          -   39.82439      -     -    0s
#      0     0   39.82439    0    7          -   39.82439      -     -    0s
#
# Cutting planes:
#   MIR: 6
#   Relax-and-lift: 3
#
# Explored 1 nodes (767 simplex iterations) in 5.23 seconds (3.87 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 0
#
# Time limit reached
# Best objective -, best bound 3.982438764713e+01, gap -
# [KS] iter 3/9 -> obj=inf, gap=inf, K^+=0
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 5.1672308666675235e+00
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  5.1672308666675235e+00
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 214 rows, 789 columns and 109288 nonzeros
# Model fingerprint: 0xef42924f
# Model has 561 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 1089 simple general constraints
#   1089 INDICATOR
# Variable types: 756 continuous, 33 integer (33 binary)
# Coefficient statistics:
#   Matrix range     [5e-08, 7e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
#   QRHS range       [6e+01, 6e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
# User MIP start violates constraint fix_outside_1 by 1.000000000
#
# Presolve added 431 rows and 0 columns
# Presolve removed 0 rows and 459 columns
# Presolve time: 0.12s
# Presolved: 646 rows, 450 columns, 24897 nonzeros
# Presolved model has 120 quadratic objective terms
# Presolved model has 120 quadratic constraint(s)
# Variable types: 435 continuous, 15 integer (15 binary)
# Root relaxation presolved: 646 rows, 330 columns, 24777 nonzeros
# Root relaxation presolved model has 120 quadratic objective terms
#
#
# Root relaxation: objective 4.054213e+01, 317 iterations, 0.07 seconds (0.05 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   40.54213    0    6          -   40.54213      -     -    0s
#      0     0   40.54213    0    6          -   40.54213      -     -    0s
#      0     0   40.54213    0    7          -   40.54213      -     -    0s
#      0     0   40.54213    0    7          -   40.54213      -     -    0s
#      0     0   40.54213    0    7          -   40.54213      -     -    0s
#
# Cutting planes:
#   MIR: 3
#
# Explored 1 nodes (777 simplex iterations) in 5.17 seconds (3.51 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 0
#
# Time limit reached
# Best objective -, best bound 4.054212785175e+01, gap -
# [KS] iter 4/9 -> obj=inf, gap=inf, K^+=0
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 5.0784108200008635e+00
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  5.0784108200008635e+00
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 214 rows, 789 columns and 109288 nonzeros
# Model fingerprint: 0xff4a383a
# Model has 561 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 1089 simple general constraints
#   1089 INDICATOR
# Variable types: 756 continuous, 33 integer (33 binary)
# Coefficient statistics:
#   Matrix range     [5e-08, 7e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
#   QRHS range       [6e+01, 6e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
# User MIP start violates constraint fix_outside_1 by 1.000000000
#
# Presolve added 431 rows and 0 columns
# Presolve removed 0 rows and 459 columns
# Presolve time: 0.09s
# Presolved: 646 rows, 450 columns, 24897 nonzeros
# Presolved model has 120 quadratic objective terms
# Presolved model has 120 quadratic constraint(s)
# Variable types: 435 continuous, 15 integer (15 binary)
# Root relaxation presolved: 646 rows, 330 columns, 24777 nonzeros
# Root relaxation presolved model has 120 quadratic objective terms
#
#
# Root relaxation: objective 2.759214e+01, 231 iterations, 0.04 seconds (0.04 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   27.59214    0    6          -   27.59214      -     -    0s
#      0     0   27.59214    0    6          -   27.59214      -     -    0s
#      0     0   27.59214    0    7          -   27.59214      -     -    0s
#      0     0   27.59214    0    7          -   27.59214      -     -    0s
#      0     0   27.59214    0    7          -   27.59214      -     -    0s
# H    0     0                      60.0543432   27.59214  54.1%     -    3s
#      0     2   27.59214    0    7   60.05434   27.59214  54.1%     -    4s
#     11    16   27.59214    4    6   60.05434   27.59214  54.1%  71.8    5s
#
# Cutting planes:
#   MIR: 5
#   Relax-and-lift: 1
#
# Explored 15 nodes (1494 simplex iterations) in 5.09 seconds (2.88 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 60.0543
#
# Time limit reached
# Best objective 6.005434321743e+01, best bound 2.759214097590e+01, gap 54.0547%
# [KS] iter 5/9 -> obj=60.0543, gap=0.540547, K^+=3
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 4.99636880000071
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  4.99636880000071
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 214 rows, 789 columns and 109288 nonzeros
# Model fingerprint: 0xa2df166c
# Model has 561 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 1089 simple general constraints
#   1089 INDICATOR
# Variable types: 756 continuous, 33 integer (33 binary)
# Coefficient statistics:
#   Matrix range     [5e-08, 7e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
#   QRHS range       [6e+01, 6e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
# User MIP start violates constraint fix_outside_24 by 1.000000000
#
# Presolve added 431 rows and 0 columns
# Presolve removed 0 rows and 459 columns
# Presolve time: 0.09s
# Presolved: 646 rows, 450 columns, 24897 nonzeros
# Presolved model has 120 quadratic objective terms
# Presolved model has 120 quadratic constraint(s)
# Variable types: 435 continuous, 15 integer (15 binary)
# Root relaxation presolved: 646 rows, 330 columns, 24777 nonzeros
# Root relaxation presolved model has 120 quadratic objective terms
#
#
# Root relaxation: objective 3.043852e+01, 253 iterations, 0.04 seconds (0.04 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   30.43852    0    6          -   30.43852      -     -    0s
#      0     0   30.43852    0    6          -   30.43852      -     -    0s
#      0     0   30.43852    0    7          -   30.43852      -     -    1s
#      0     0   30.43852    0    7          -   30.43852      -     -    1s
#      0     0   30.43852    0    7          -   30.43852      -     -    1s
# H    0     0                      59.8891322   30.43852  49.2%     -    4s
#
# Cutting planes:
#   MIR: 3
#   Relax-and-lift: 1
#
# Explored 1 nodes (659 simplex iterations) in 5.01 seconds (2.63 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 59.8891
#
# Time limit reached
# Best objective 5.988913219105e+01, best bound 3.043852046525e+01, gap 49.1752%
# [KS] iter 6/9 -> obj=59.8891, gap=0.491752, K^+=4
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 4.8920715333345770e+00
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  4.8920715333345770e+00
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 212 rows, 789 columns and 109288 nonzeros
# Model fingerprint: 0xf4177b37
# Model has 561 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 1089 simple general constraints
#   1089 INDICATOR
# Variable types: 756 continuous, 33 integer (33 binary)
# Coefficient statistics:
#   Matrix range     [5e-08, 7e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
#   QRHS range       [6e+01, 6e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
# User MIP start violates constraint fix_outside_27 by 1.000000000
#
# Presolve added 561 rows and 0 columns
# Presolve removed 0 rows and 424 columns
# Presolve time: 0.10s
# Presolved: 774 rows, 518 columns, 31590 nonzeros
# Presolved model has 153 quadratic objective terms
# Presolved model has 153 quadratic constraint(s)
# Variable types: 501 continuous, 17 integer (17 binary)
# Root relaxation presolved: 774 rows, 365 columns, 31437 nonzeros
# Root relaxation presolved model has 153 quadratic objective terms
#
#
# Root relaxation: objective 1.779570e+01, 217 iterations, 0.04 seconds (0.04 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      56.8789248   17.79570  68.7%     -    0s
# H    0     0                      56.8789190   17.79570  68.7%     -    0s
#      0     0   17.79570    0    8   56.87892   17.79570  68.7%     -    0s
#      0     0   17.79570    0    8   56.87892   17.79570  68.7%     -    0s
#      0     0   17.79570    0    9   56.87892   17.79570  68.7%     -    1s
#      0     0   17.79570    0    9   56.87892   17.79570  68.7%     -    1s
#      0     0   17.79570    0    9   56.87892   17.79570  68.7%     -    1s
# H    0     0                      52.2110291   17.79570  65.9%     -    4s
# H    0     0                      50.5802955   17.79570  64.8%     -    4s
# H    0     0                      50.5802953   17.79570  64.8%     -    4s
#
# Cutting planes:
#   MIR: 11
#   Relax-and-lift: 4
#
# Explored 1 nodes (777 simplex iterations) in 4.90 seconds (2.34 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 50.5803 52.211 56.8789
#
# Time limit reached
# Best objective 5.058029527739e+01, best bound 1.779569915485e+01, gap 64.8169%
# [KS] iter 7/9 -> obj=50.5803, gap=0.648169, K^+=1
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 4.7360550500015961e+00
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  4.7360550500015961e+00
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 211 rows, 789 columns and 109288 nonzeros
# Model fingerprint: 0x881babbc
# Model has 561 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 1089 simple general constraints
#   1089 INDICATOR
# Variable types: 756 continuous, 33 integer (33 binary)
# Coefficient statistics:
#   Matrix range     [5e-08, 7e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
#   QRHS range       [5e+01, 5e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 632 rows and 0 columns
# Presolve removed 0 rows and 405 columns
# Presolve time: 0.11s
# Presolved: 844 rows, 555 columns, 35241 nonzeros
# Presolved model has 171 quadratic objective terms
# Presolved model has 171 quadratic constraint(s)
# Variable types: 537 continuous, 18 integer (18 binary)
# Root relaxation presolved: 844 rows, 384 columns, 35070 nonzeros
# Root relaxation presolved model has 171 quadratic objective terms
#
#
# Root relaxation: objective 1.937309e+01, 225 iterations, 0.06 seconds (0.05 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      50.5802949   19.37309  61.7%     -    0s
# H    0     0                      50.5802786   19.37309  61.7%     -    0s
#      0     0   19.37309    0    9   50.58028   19.37309  61.7%     -    0s
#      0     0   19.37309    0    9   50.58028   19.37309  61.7%     -    0s
#      0     0   19.37309    0    9   50.58028   19.37309  61.7%     -    1s
#      0     0   19.37309    0    9   50.58028   19.37309  61.7%     -    1s
#      0     0   19.37309    0    9   50.58028   19.37309  61.7%     -    1s
#      0     0   19.37309    0    9   50.58028   19.37309  61.7%     -    1s
#
# Cutting planes:
#   MIR: 9
#   Relax-and-lift: 2
#
# Explored 1 nodes (802 simplex iterations) in 4.74 seconds (2.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 50.5803
#
# Time limit reached
# Best objective 5.058027855543e+01, best bound 1.937308613265e+01, gap 61.6983%
# [KS] iter 8/9 -> obj=50.5803, gap=0.616983, K^+=0
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 4.43647740000597
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  4.43647740000597
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 214 rows, 789 columns and 109288 nonzeros
# Model fingerprint: 0xded5c798
# Model has 561 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 1089 simple general constraints
#   1089 INDICATOR
# Variable types: 756 continuous, 33 integer (33 binary)
# Coefficient statistics:
#   Matrix range     [5e-08, 7e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
#   QRHS range       [5e+01, 5e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 431 rows and 0 columns
# Presolve removed 0 rows and 459 columns
# Presolve time: 0.08s
# Presolved: 646 rows, 450 columns, 24897 nonzeros
# Presolved model has 120 quadratic objective terms
# Presolved model has 120 quadratic constraint(s)
# Variable types: 435 continuous, 15 integer (15 binary)
# Root relaxation presolved: 646 rows, 330 columns, 24777 nonzeros
# Root relaxation presolved model has 120 quadratic objective terms
#
#
# Root relaxation: objective 3.019142e+01, 249 iterations, 0.04 seconds (0.04 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      50.5802786   30.19142  40.3%     -    0s
#      0     0   30.19142    0    6   50.58028   30.19142  40.3%     -    0s
#      0     0   30.19142    0    6   50.58028   30.19142  40.3%     -    0s
#      0     0   30.19142    0    7   50.58028   30.19142  40.3%     -    0s
#      0     0   30.19142    0    7   50.58028   30.19142  40.3%     -    0s
#      0     0   30.19142    0    7   50.58028   30.19142  40.3%     -    0s
# H    0     0                      50.3148501   30.19142  40.0%     -    4s
# H    0     0                      50.3148494   30.19142  40.0%     -    4s
#      0     2   30.19142    0    7   50.31485   30.19142  40.0%     -    4s
#
# Cutting planes:
#   MIR: 9
#   Relax-and-lift: 3
#
# Explored 43 nodes (2422 simplex iterations) in 4.45 seconds (2.14 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 50.3148 50.5803
#
# Time limit reached
# Best objective 5.031484937973e+01, best bound 3.019142403437e+01, gap 39.9950%
# [KS] iter 9/9 -> obj=50.3148, gap=0.39995, K^+=0
# [Alg3] KS#1: UB=50.3148, gap=0.39995
# [Alg3] M=12.9956, ||w||_1/B=3.57042
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 2.6666663444444163e+00
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  2.6666663444444163e+00
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 214 rows, 789 columns and 109288 nonzeros
# Model fingerprint: 0x5b50efb9
# Model has 561 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 1089 simple general constraints
#   1089 INDICATOR
# Variable types: 756 continuous, 33 integer (33 binary)
# Coefficient statistics:
#   Matrix range     [5e-08, 7e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
#   QRHS range       [5e+01, 5e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 431 rows and 0 columns
# Presolve removed 0 rows and 459 columns
# Presolve time: 0.08s
# Presolved: 646 rows, 450 columns, 24897 nonzeros
# Presolved model has 120 quadratic objective terms
# Presolved model has 120 quadratic constraint(s)
# Variable types: 435 continuous, 15 integer (15 binary)
# Root relaxation presolved: 646 rows, 330 columns, 24777 nonzeros
# Root relaxation presolved model has 120 quadratic objective terms
#
#
# Root relaxation: objective 2.675786e+01, 231 iterations, 0.09 seconds (0.04 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      50.3148473   26.75786  46.8%     -    0s
#      0     0   26.75786    0    6   50.31485   26.75786  46.8%     -    0s
#      0     0   26.75786    0    6   50.31485   26.75786  46.8%     -    0s
#      0     0   26.75786    0    7   50.31485   26.75786  46.8%     -    0s
#      0     0   26.75786    0    7   50.31485   26.75786  46.8%     -    0s
#      0     0   26.75786    0    7   50.31485   26.75786  46.8%     -    0s
#      0     0   26.75786    0    7   50.31485   26.75786  46.8%     -    1s
#
# Cutting planes:
#   MIR: 12
#   Relax-and-lift: 2
#
# Explored 1 nodes (718 simplex iterations) in 2.69 seconds (0.96 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 50.3148
#
# Time limit reached
# Best objective 5.031484731716e+01, best bound 2.675786030411e+01, gap 46.8192%
# [KS2] iter 1/9 -> obj=50.3148, gap=0.468192, K^+=10
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 2.6319348375000118e+00
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  2.6319348375000118e+00
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 214 rows, 789 columns and 109288 nonzeros
# Model fingerprint: 0xa1b18589
# Model has 561 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 1089 simple general constraints
#   1089 INDICATOR
# Variable types: 756 continuous, 33 integer (33 binary)
# Coefficient statistics:
#   Matrix range     [5e-08, 7e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
#   QRHS range       [5e+01, 5e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 431 rows and 0 columns
# Presolve removed 0 rows and 459 columns
# Presolve time: 0.08s
# Presolved: 646 rows, 450 columns, 24897 nonzeros
# Presolved model has 120 quadratic objective terms
# Presolved model has 120 quadratic constraint(s)
# Variable types: 435 continuous, 15 integer (15 binary)
# Root relaxation presolved: 646 rows, 330 columns, 24777 nonzeros
# Root relaxation presolved model has 120 quadratic objective terms
#
#
# Root relaxation: objective 2.675786e+01, 231 iterations, 0.04 seconds (0.04 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      50.3148473   26.75786  46.8%     -    0s
#      0     0   26.75786    0    6   50.31485   26.75786  46.8%     -    0s
#      0     0   26.75786    0    6   50.31485   26.75786  46.8%     -    0s
#      0     0   26.75786    0    7   50.31485   26.75786  46.8%     -    0s
#      0     0   26.75786    0    7   50.31485   26.75786  46.8%     -    0s
#      0     0   26.75786    0    7   50.31485   26.75786  46.8%     -    0s
#      0     0   26.75786    0    7   50.31485   26.75786  46.8%     -    0s
#
# Cutting planes:
#   MIR: 12
#   Relax-and-lift: 2
#
# Explored 1 nodes (718 simplex iterations) in 2.67 seconds (0.95 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 50.3148
#
# Time limit reached
# Best objective 5.031484731716e+01, best bound 2.675786030411e+01, gap 46.8192%
# [KS2] iter 2/9 -> obj=50.3148, gap=0.468192, K^+=2
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 2.58398805714283
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  2.58398805714283
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 214 rows, 789 columns and 109288 nonzeros
# Model fingerprint: 0x06bc0433
# Model has 561 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 1089 simple general constraints
#   1089 INDICATOR
# Variable types: 756 continuous, 33 integer (33 binary)
# Coefficient statistics:
#   Matrix range     [5e-08, 7e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
#   QRHS range       [5e+01, 5e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 431 rows and 0 columns
# Presolve removed 0 rows and 459 columns
# Presolve time: 0.09s
# Presolved: 646 rows, 450 columns, 24897 nonzeros
# Presolved model has 120 quadratic objective terms
# Presolved model has 120 quadratic constraint(s)
# Variable types: 435 continuous, 15 integer (15 binary)
# Root relaxation presolved: 646 rows, 330 columns, 24777 nonzeros
# Root relaxation presolved model has 120 quadratic objective terms
#
#
# Root relaxation: objective 2.333672e+01, 207 iterations, 0.04 seconds (0.03 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      50.3148473   23.33672  53.6%     -    0s
#      0     0   23.33672    0    6   50.31485   23.33672  53.6%     -    0s
#      0     0   23.33672    0    6   50.31485   23.33672  53.6%     -    0s
#      0     0   23.33672    0    6   50.31485   23.33672  53.6%     -    0s
#      0     0   23.33672    0    7   50.31485   23.33672  53.6%     -    0s
#      0     0   23.33672    0    7   50.31485   23.33672  53.6%     -    0s
#
# Cutting planes:
#   MIR: 7
#   Relax-and-lift: 2
#
# Explored 1 nodes (651 simplex iterations) in 2.61 seconds (0.89 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 50.3148
#
# Time limit reached
# Best objective 5.031484731716e+01, best bound 2.333671942944e+01, gap 53.6186%
# [KS2] iter 3/9 -> obj=50.3148, gap=0.536186, K^+=0
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 2.5296638500003610e+00
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  2.5296638500003610e+00
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 214 rows, 789 columns and 109288 nonzeros
# Model fingerprint: 0x93fb2269
# Model has 561 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 1089 simple general constraints
#   1089 INDICATOR
# Variable types: 756 continuous, 33 integer (33 binary)
# Coefficient statistics:
#   Matrix range     [5e-08, 7e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
#   QRHS range       [5e+01, 5e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 431 rows and 0 columns
# Presolve removed 0 rows and 459 columns
# Presolve time: 0.10s
# Presolved: 646 rows, 450 columns, 24897 nonzeros
# Presolved model has 120 quadratic objective terms
# Presolved model has 120 quadratic constraint(s)
# Variable types: 435 continuous, 15 integer (15 binary)
# Root relaxation presolved: 646 rows, 330 columns, 24777 nonzeros
# Root relaxation presolved model has 120 quadratic objective terms
#
#
# Root relaxation: objective 3.248736e+01, 301 iterations, 0.05 seconds (0.04 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      50.3148473   32.48736  35.4%     -    0s
#      0     0   32.48736    0    6   50.31485   32.48736  35.4%     -    0s
#      0     0   32.48736    0    6   50.31485   32.48736  35.4%     -    0s
#      0     0   32.48736    0    7   50.31485   32.48736  35.4%     -    0s
#      0     0   32.48736    0    7   50.31485   32.48736  35.4%     -    0s
#      0     0   32.48736    0    7   50.31485   32.48736  35.4%     -    0s
#
# Cutting planes:
#   MIR: 6
#
# Explored 1 nodes (739 simplex iterations) in 2.57 seconds (0.91 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 50.3148
#
# Time limit reached
# Best objective 5.031484731716e+01, best bound 3.248736498064e+01, gap 35.4319%
# [KS2] iter 4/9 -> obj=50.3148, gap=0.354319, K^+=0
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 2.4565641200009849e+00
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  2.4565641200009849e+00
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 214 rows, 789 columns and 109288 nonzeros
# Model fingerprint: 0x851d516a
# Model has 561 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 1089 simple general constraints
#   1089 INDICATOR
# Variable types: 756 continuous, 33 integer (33 binary)
# Coefficient statistics:
#   Matrix range     [5e-08, 7e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
#   QRHS range       [5e+01, 5e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 431 rows and 0 columns
# Presolve removed 0 rows and 459 columns
# Presolve time: 0.09s
# Presolved: 646 rows, 450 columns, 24897 nonzeros
# Presolved model has 120 quadratic objective terms
# Presolved model has 120 quadratic constraint(s)
# Variable types: 435 continuous, 15 integer (15 binary)
# Root relaxation presolved: 646 rows, 330 columns, 24777 nonzeros
# Root relaxation presolved model has 120 quadratic objective terms
#
#
# Root relaxation: objective 2.354080e+01, 225 iterations, 0.04 seconds (0.04 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      50.3148473   23.54080  53.2%     -    0s
#      0     0   23.54080    0    6   50.31485   23.54080  53.2%     -    0s
#      0     0   23.54080    0    6   50.31485   23.54080  53.2%     -    0s
#      0     0   23.54080    0    7   50.31485   23.54080  53.2%     -    0s
#      0     0   23.54080    0    7   50.31485   23.54080  53.2%     -    0s
#      0     0   23.54080    0    7   50.31485   23.54080  53.2%     -    0s
#      0     0   23.54080    0    7   50.31485   23.54080  53.2%     -    0s
#
# Cutting planes:
#   MIR: 12
#   Relax-and-lift: 2
#
# Explored 1 nodes (692 simplex iterations) in 2.48 seconds (0.91 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 50.3148
#
# Time limit reached
# Best objective 5.031484731716e+01, best bound 2.354079724327e+01, gap 53.2130%
# [KS2] iter 5/9 -> obj=50.3148, gap=0.53213, K^+=3
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 2.3777210500011279e+00
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  2.3777210500011279e+00
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 214 rows, 789 columns and 109288 nonzeros
# Model fingerprint: 0xa52376dc
# Model has 561 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 1089 simple general constraints
#   1089 INDICATOR
# Variable types: 756 continuous, 33 integer (33 binary)
# Coefficient statistics:
#   Matrix range     [5e-08, 7e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
#   QRHS range       [5e+01, 5e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 431 rows and 0 columns
# Presolve removed 0 rows and 459 columns
# Presolve time: 0.11s
# Presolved: 646 rows, 450 columns, 24897 nonzeros
# Presolved model has 120 quadratic objective terms
# Presolved model has 120 quadratic constraint(s)
# Variable types: 435 continuous, 15 integer (15 binary)
# Root relaxation presolved: 646 rows, 330 columns, 24777 nonzeros
# Root relaxation presolved model has 120 quadratic objective terms
#
#
# Root relaxation: objective 3.298075e+01, 255 iterations, 0.05 seconds (0.04 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      50.3148473   32.98075  34.5%     -    0s
#      0     0   32.98075    0    6   50.31485   32.98075  34.5%     -    0s
#      0     0   32.98075    0    6   50.31485   32.98075  34.5%     -    0s
#      0     0   32.98075    0    7   50.31485   32.98075  34.5%     -    0s
#      0     0   32.98075    0    7   50.31485   32.98075  34.5%     -    0s
#      0     0   32.98075    0    7   50.31485   32.98075  34.5%     -    0s
#
# Cutting planes:
#   MIR: 9
#
# Explored 1 nodes (731 simplex iterations) in 2.39 seconds (0.84 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 50.3148
#
# Time limit reached
# Best objective 5.031484731716e+01, best bound 3.298074960991e+01, gap 34.4513%
# [KS2] iter 6/9 -> obj=50.3148, gap=0.344513, K^+=2
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 2.2741695000004256e+00
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  2.2741695000004256e+00
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 214 rows, 789 columns and 109288 nonzeros
# Model fingerprint: 0xc908ab66
# Model has 561 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 1089 simple general constraints
#   1089 INDICATOR
# Variable types: 756 continuous, 33 integer (33 binary)
# Coefficient statistics:
#   Matrix range     [5e-08, 7e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
#   QRHS range       [5e+01, 5e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 431 rows and 0 columns
# Presolve removed 0 rows and 459 columns
# Presolve time: 0.09s
# Presolved: 646 rows, 450 columns, 24897 nonzeros
# Presolved model has 120 quadratic objective terms
# Presolved model has 120 quadratic constraint(s)
# Variable types: 435 continuous, 15 integer (15 binary)
# Root relaxation presolved: 646 rows, 330 columns, 24777 nonzeros
# Root relaxation presolved model has 120 quadratic objective terms
#
#
# Root relaxation: objective 2.522258e+01, 219 iterations, 0.04 seconds (0.04 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      50.3148473   25.22258  49.9%     -    0s
#      0     0   25.22258    0    6   50.31485   25.22258  49.9%     -    0s
#      0     0   25.22258    0    6   50.31485   25.22258  49.9%     -    0s
#      0     0   25.22258    0    6   50.31485   25.22258  49.9%     -    0s
#      0     0   25.22258    0    6   50.31485   25.22258  49.9%     -    0s
#      0     0   25.22258    0    6   50.31485   25.22258  49.9%     -    0s
#
# Cutting planes:
#   MIR: 6
#
# Explored 1 nodes (717 simplex iterations) in 2.29 seconds (0.84 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 50.3148
#
# Time limit reached
# Best objective 5.031484731716e+01, best bound 2.522257563491e+01, gap 49.8705%
# [KS2] iter 7/9 -> obj=50.3148, gap=0.498705, K^+=1
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 2.1173132500007341e+00
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  2.1173132500007341e+00
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 214 rows, 789 columns and 109288 nonzeros
# Model fingerprint: 0xf3f5f09f
# Model has 561 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 1089 simple general constraints
#   1089 INDICATOR
# Variable types: 756 continuous, 33 integer (33 binary)
# Coefficient statistics:
#   Matrix range     [5e-08, 7e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
#   QRHS range       [5e+01, 5e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 431 rows and 0 columns
# Presolve removed 0 rows and 459 columns
# Presolve time: 0.09s
# Presolved: 646 rows, 450 columns, 24897 nonzeros
# Presolved model has 120 quadratic objective terms
# Presolved model has 120 quadratic constraint(s)
# Variable types: 435 continuous, 15 integer (15 binary)
# Root relaxation presolved: 646 rows, 330 columns, 24777 nonzeros
# Root relaxation presolved model has 120 quadratic objective terms
#
#
# Root relaxation: objective 2.806298e+01, 246 iterations, 0.04 seconds (0.04 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      50.3148473   28.06298  44.2%     -    0s
#      0     0   28.06298    0    6   50.31485   28.06298  44.2%     -    0s
#      0     0   28.06298    0    6   50.31485   28.06298  44.2%     -    0s
#      0     0   28.06298    0    7   50.31485   28.06298  44.2%     -    0s
#      0     0   28.06298    0    7   50.31485   28.06298  44.2%     -    0s
#      0     0   28.06298    0    7   50.31485   28.06298  44.2%     -    0s
#
# Cutting planes:
#   MIR: 6
#
# Explored 1 nodes (730 simplex iterations) in 2.14 seconds (0.75 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 50.3148
#
# Time limit reached
# Best objective 5.031484731716e+01, best bound 2.806297692984e+01, gap 44.2253%
# [KS2] iter 8/9 -> obj=50.3148, gap=0.442253, K^+=0
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 1.7974615999992238e+00
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  1.7974615999992238e+00
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 214 rows, 789 columns and 109288 nonzeros
# Model fingerprint: 0x9f6cdd2a
# Model has 561 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 1089 simple general constraints
#   1089 INDICATOR
# Variable types: 756 continuous, 33 integer (33 binary)
# Coefficient statistics:
#   Matrix range     [5e-08, 7e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
#   QRHS range       [5e+01, 5e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 431 rows and 0 columns
# Presolve removed 0 rows and 459 columns
# Presolve time: 0.08s
# Presolved: 646 rows, 450 columns, 24897 nonzeros
# Presolved model has 120 quadratic objective terms
# Presolved model has 120 quadratic constraint(s)
# Variable types: 435 continuous, 15 integer (15 binary)
# Root relaxation presolved: 646 rows, 330 columns, 24777 nonzeros
# Root relaxation presolved model has 120 quadratic objective terms
#
#
# Root relaxation: objective 3.011116e+01, 254 iterations, 0.04 seconds (0.04 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      50.3148473   30.11116  40.2%     -    0s
#      0     0   30.11116    0    6   50.31485   30.11116  40.2%     -    0s
#      0     0   30.11116    0    6   50.31485   30.11116  40.2%     -    0s
#      0     0   30.11116    0    7   50.31485   30.11116  40.2%     -    0s
#      0     0   30.11116    0    7   50.31485   30.11116  40.2%     -    0s
#      0     0   30.11116    0    7   50.31485   30.11116  40.2%     -    0s
#
# Cutting planes:
#   MIR: 16
#
# Explored 1 nodes (742 simplex iterations) in 1.82 seconds (0.68 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 50.3148
#
# Time limit reached
# Best objective 5.031484731716e+01, best bound 3.011115812458e+01, gap 40.1545%
# [KS2] iter 9/9 -> obj=50.3148, gap=0.401545, K^+=0
# [Alg3] Accept KS#2: UB=50.3148, gap=0.344513
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 108
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  108
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 196 rows, 789 columns and 109288 nonzeros
# Model fingerprint: 0xc11fe417
# Model has 561 quadratic objective terms
# Model has 1089 simple general constraints
#   1089 INDICATOR
# Variable types: 756 continuous, 33 integer (33 binary)
# Coefficient statistics:
#   Matrix range     [5e-08, 7e+01]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# Loaded user MIP start with objective 194
#
# Presolve removed 1 rows and 0 columns
# Presolve time: 0.08s
# Presolved: 195 rows, 789 columns, 109255 nonzeros
# Presolved model has 1089 SOS constraint(s)
# Presolved model has 561 quadratic objective terms
# Variable types: 756 continuous, 33 integer (33 binary)
# Root relaxation presolved: 194 rows, 756 columns, 109222 nonzeros
# Root relaxation presolved model has 561 quadratic objective terms
#
#
# Root relaxation: objective 1.887502e+00, 155 iterations, 0.30 seconds (0.14 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    1.88750    0  759  194.00000    1.88750  99.0%     -    0s
# H    0     0                     193.9858113    1.88750  99.0%     -    0s
# H    0     0                      84.7361493    1.88750  97.8%     -    1s
#      0     0    1.88750    0  759   84.73615    1.88750  97.8%     -    1s
#      0     2    1.88750    0  759   84.73615    1.88750  97.8%     -    2s
# *   59    62              10      48.5952734    1.88750  96.1%  38.6    5s
# *   82    64              13      44.4959892    1.88750  95.8%  97.5    7s
#    109    62    5.27020   18  336   44.49599    1.88750  95.8%   127   10s
#    243    68    3.34451   14  504   44.49599    1.88750  95.8%   133   15s
# H  292    82                      43.7639199    1.88750  95.7%   140   18s
#    299    84     cutoff   21        43.76392    1.88750  95.7%   140   20s
# H  300    84                      42.9502748    1.88750  95.6%   140   20s
#    394    89    4.70078    4  600   42.95027    1.88750  95.6%   140   25s
#    458   127    3.99214   12  600   42.95027    2.21059  94.9%   134   30s
#    516   141     cutoff   16        42.95027    2.21059  94.9%   137   35s
#    606   148    2.44545   11  551   42.95027    2.21059  94.9%   138   40s
#    654   153    2.60079   12  504   42.95027    2.21059  94.9%   140   45s
#    740   182    3.50646   15  416   42.95027    2.21337  94.8%   137   50s
#    867   188    2.65351    8  651   42.95027    2.21337  94.8%   139   55s
#   1009   213   21.81969   26   96   42.95027    2.24146  94.8%   142   60s
# * 1106   222              13      42.5137367    2.24146  94.7%   138   62s
#   1135   230    3.47322   14  504   42.51374    2.31057  94.6%   141   65s
#   1265   262     cutoff   24        42.51374    2.33313  94.5%   140   70s
#   1479   294    3.10123   13  551   42.51374    2.33313  94.5%   136   76s
#   1627   299    2.73597   10  600   42.51374    2.36276  94.4%   136   81s
#   1728   339    8.62631   20  264   42.51374    2.36276  94.4%   138   86s
#   1918   356     cutoff   20        42.51374    2.36381  94.4%   136   92s
#   1931   360     cutoff   21        42.51374    2.36381  94.4%   135   95s
# H 1961   360                      41.6654383    2.36381  94.3%   135   95s
# H 2028   360                      39.3032580    2.36381  94.0%   137   98s
#   2045   363     cutoff   17        39.30326    2.36381  94.0%   137  101s
#   2177   364    2.64063   11  600   39.30326    2.36381  94.0%   136  108s
#
# Explored 2235 nodes (305861 simplex iterations) in 108.02 seconds (83.14 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 8: 39.3033 41.6654 42.5137 ... 194
#
# Time limit reached
# Best objective 3.930325800688e+01, best bound 2.363806522165e+00, gap 93.9857%
#
# === Comparison (same total time) ===
#                          method      UB   MIPGap runtime  selected_k
# Algorithm-3 (KS+Bounds+BigM+KS) 50.3148 0.344513 120.00s          10
#       Full Co-NLSVM (indicator) 39.3033 0.939857 120.04s          10

# %%
# 读取 UCI 数据
ionosphere = fetch_ucirepo(id=52)  
X_df = ionosphere.data.features
y_series = ionosphere.data.targets['Class']

# 清洗与对齐
X_df = X_df.replace('?', np.nan).dropna()
y_series = y_series.loc[X_df.index]

feature_names = list(X_df.columns)
X = StandardScaler().fit_transform(X_df.values)

# y_series: 形如包含 'N' / 'R' 的 pandas Series
y_str = y_series.astype(str).str.strip().str.upper().values

# 检查是否真的是二分类且只含 g/b
uniq = np.unique(y_str)
if not set(uniq).issubset({"G", "B"}) or len(uniq) != 2:
    raise ValueError(f"期望标签为 {{'G','B'}}，但实际唯一取值={uniq}")

# 约定：g -> +1，b -> -1  （和你之前的一致）
y = np.where(y_str == "G", 1.0, -1.0)

# 假设你已准备好 X, y（y ∈ {-1,+1}）, 以及 feature_names（可选）
B, C = 5, 1.0
T_total = 120.0   # 两侧统一总时间（秒）
rho = 4

df_cmp = run_comparison(X, y, B, C, total_time=T_total, rho=rho, feature_names=feature_names, verbose=True)
# Out:
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 5.2520095999999388e+00
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  5.2520095999999388e+00
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 380 rows, 981 columns and 197681 nonzeros
# Model fingerprint: 0xf22b23ae
# Model has 595 quadratic objective terms
# Model has 1156 simple general constraints
#   1156 INDICATOR
# Variable types: 947 continuous, 34 integer (34 binary)
# Coefficient statistics:
#   Matrix range     [6e-08, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# Loaded user MIP start with objective 351
#
# Presolve removed 50 rows and 616 columns
# Presolve time: 0.06s
# Presolved: 330 rows, 365 columns, 9877 nonzeros
# Presolved model has 49 SOS constraint(s)
# Presolved model has 28 quadratic objective terms
# Variable types: 358 continuous, 7 integer (7 binary)
# Root relaxation presolved: 329 rows, 358 columns, 9870 nonzeros
# Root relaxation presolved model has 28 quadratic objective terms
#
#
# Root relaxation: objective 5.424599e+01, 356 iterations, 0.03 seconds (0.02 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   54.24599    0   14  351.00000   54.24599  84.5%     -    0s
# H    0     0                     140.7191385   54.24599  61.5%     -    0s
# H    0     0                      65.9773249   54.24599  17.8%     -    0s
#      0     0   54.24599    0   14   65.97732   54.24599  17.8%     -    0s
#      0     2   54.24599    0   14   65.97732   54.24599  17.8%     -    0s
# *   12     5               5      62.9609593   54.24599  13.8%  45.5    0s
# *   18     5               6      61.7280690   54.24599  12.1%  48.2    0s
#
# Explored 35 nodes (1552 simplex iterations) in 0.29 seconds (0.17 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 61.7281 62.961 65.9773 351
#
# Optimal solution found (tolerance 3.00e-02)
# Best objective 6.172806898836e+01, best bound 6.172806898836e+01, gap 0.0000%
# [KS] iter 1/9 -> obj=61.7281, gap=0, K^+=2
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 5.7543999375002386e+00
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  5.7543999375002386e+00
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 380 rows, 981 columns and 197681 nonzeros
# Model fingerprint: 0x5283cdfc
# Model has 595 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 1156 simple general constraints
#   1156 INDICATOR
# Variable types: 947 continuous, 34 integer (34 binary)
# Coefficient statistics:
#   Matrix range     [6e-08, 1e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
#   QRHS range       [6e+01, 6e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 70 rows and 0 columns
# Presolve removed 0 rows and 594 columns
# Presolve time: 0.11s
# Presolved: 451 rows, 415 columns, 8655 nonzeros
# Presolved model has 28 quadratic objective terms
# Presolved model has 28 quadratic constraint(s)
# Variable types: 408 continuous, 7 integer (7 binary)
# Root relaxation presolved: 451 rows, 387 columns, 8627 nonzeros
# Root relaxation presolved model has 28 quadratic objective terms
#
#
# Root relaxation: objective 6.025356e+01, 431 iterations, 0.03 seconds (0.02 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      61.7280688   60.25356  2.39%     -    0s
#      0     0   60.25356    0    3   61.72807   60.25356  2.39%     -    0s
#
# Explored 1 nodes (431 simplex iterations) in 0.44 seconds (0.10 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 61.7281
#
# Optimal solution found (tolerance 3.00e-02)
# Warning: max constraint violation (3.1719e-06) exceeds tolerance
# Best objective 6.172806879611e+01, best bound 6.025356271895e+01, gap 2.3887%
# [KS] iter 2/9 -> obj=61.7281, gap=0.0238871, K^+=3
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 6.3939365000000441e+00
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  6.3939365000000441e+00
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 378 rows, 981 columns and 197681 nonzeros
# Model fingerprint: 0xace0c35f
# Model has 595 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 1156 simple general constraints
#   1156 INDICATOR
# Variable types: 947 continuous, 34 integer (34 binary)
# Coefficient statistics:
#   Matrix range     [6e-08, 1e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
#   QRHS range       [6e+01, 6e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 136 rows and 0 columns
# Presolve removed 0 rows and 575 columns
# Presolve time: 0.11s
# Presolved: 515 rows, 451 columns, 17226 nonzeros
# Presolved model has 45 quadratic objective terms
# Presolved model has 45 quadratic constraint(s)
# Variable types: 442 continuous, 9 integer (9 binary)
# Root relaxation presolved: 515 rows, 406 columns, 17181 nonzeros
# Root relaxation presolved model has 45 quadratic objective terms
#
#
# Root relaxation: objective 3.468453e+01, 318 iterations, 0.05 seconds (0.03 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      61.7280690   34.68453  43.8%     -    0s
#      0     0   34.68453    0    5   61.72807   34.68453  43.8%     -    0s
#      0     0   34.68453    0    5   61.72807   34.68453  43.8%     -    0s
#      0     0   34.68453    0    6   61.72807   34.68453  43.8%     -    0s
#      0     0   34.68453    0    6   61.72807   34.68453  43.8%     -    0s
#      0     0   34.68453    0    6   61.72807   34.68453  43.8%     -    0s
#      0     2   39.41516    0    6   61.72807   39.41516  36.1%     -    1s
# H   13    15                      55.8385301   39.41516  29.4%  69.3    2s
# *   13    15               5      55.8385301   39.41516  29.4%  90.3    2s
# H   41    11                      52.9239476   42.92177  18.9%  77.2    2s
# *   41    11               8      52.9239476   42.92177  18.9%  79.4    2s
#
# Cutting planes:
#   MIR: 2
#
# Explored 72 nodes (5267 simplex iterations) in 2.45 seconds (1.29 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 52.9239 55.8385 61.7281
#
# Optimal solution found (tolerance 3.00e-02)
# Best objective 5.292394544523e+01, best bound 5.276845002359e+01, gap 0.2938%
# [KS] iter 3/9 -> obj=52.9239, gap=0.00293809, K^+=2
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 6.8944669333335087e+00
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  6.8944669333335087e+00
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 376 rows, 981 columns and 197681 nonzeros
# Model fingerprint: 0x36d2ea76
# Model has 595 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 1156 simple general constraints
#   1156 INDICATOR
# Variable types: 947 continuous, 34 integer (34 binary)
# Coefficient statistics:
#   Matrix range     [6e-08, 1e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
#   QRHS range       [5e+01, 5e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 218 rows and 0 columns
# Presolve removed 0 rows and 552 columns
# Presolve time: 0.11s
# Presolved: 595 rows, 495 columns, 24780 nonzeros
# Presolved model has 66 quadratic objective terms
# Presolved model has 66 quadratic constraint(s)
# Variable types: 484 continuous, 11 integer (11 binary)
# Root relaxation presolved: 595 rows, 429 columns, 24714 nonzeros
# Root relaxation presolved model has 66 quadratic objective terms
#
#
# Root relaxation: objective 2.530938e+01, 287 iterations, 0.05 seconds (0.03 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      52.9239429   25.30938  52.2%     -    0s
#      0     0   25.30938    0    7   52.92394   25.30938  52.2%     -    0s
#      0     0   25.30938    0    7   52.92394   25.30938  52.2%     -    0s
#      0     0   25.30938    0    8   52.92394   25.30938  52.2%     -    0s
#      0     0   25.30938    0    8   52.92394   25.30938  52.2%     -    0s
#      0     0   25.30938    0    8   52.92394   25.30938  52.2%     -    0s
# H    0     0                      50.8469257   27.77974  45.4%     -    3s
# H    0     0                      50.8469251   27.77974  45.4%     -    3s
#      0     2   27.77974    0    8   50.84693   27.77974  45.4%     -    3s
# H   29    20                      50.0925786   27.77974  44.5%  65.1    4s
# *   29    20               6      50.0925786   27.77974  44.5%  77.1    4s
#
# Cutting planes:
#   MIR: 3
#   Relax-and-lift: 1
#
# Explored 296 nodes (23904 simplex iterations) in 5.00 seconds (3.36 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 50.0926 50.8469 52.9239
#
# Optimal solution found (tolerance 3.00e-02)
# Warning: max constraint violation (1.4079e-06) exceeds tolerance
# Best objective 5.009257802235e+01, best bound 5.009257279683e+01, gap 0.0000%
# [KS] iter 4/9 -> obj=50.0926, gap=1.04317e-07, K^+=1
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 7.0530122399999531e+00
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  7.0530122399999531e+00
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 375 rows, 981 columns and 197681 nonzeros
# Model fingerprint: 0x8a7077c9
# Model has 595 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 1156 simple general constraints
#   1156 INDICATOR
# Variable types: 947 continuous, 34 integer (34 binary)
# Coefficient statistics:
#   Matrix range     [6e-08, 1e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
#   QRHS range       [5e+01, 5e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 265 rows and 0 columns
# Presolve removed 0 rows and 539 columns
# Presolve time: 0.19s
# Presolved: 641 rows, 520 columns, 29097 nonzeros
# Presolved model has 78 quadratic objective terms
# Presolved model has 78 quadratic constraint(s)
# Variable types: 508 continuous, 12 integer (12 binary)
# Root relaxation presolved: 641 rows, 442 columns, 29019 nonzeros
# Root relaxation presolved model has 78 quadratic objective terms
#
#
# Root relaxation: objective 1.978467e+01, 273 iterations, 0.09 seconds (0.04 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      50.0925775   19.78467  60.5%     -    0s
# H    0     0                      50.0925728   19.78467  60.5%     -    0s
#      0     0   19.78467    0    8   50.09257   19.78467  60.5%     -    0s
#      0     0   19.78467    0    8   50.09257   19.78467  60.5%     -    0s
#      0     0   19.78467    0    8   50.09257   19.78467  60.5%     -    1s
#      0     0   19.78467    0    8   50.09257   19.78467  60.5%     -    1s
#      0     0   19.78467    0    8   50.09257   19.78467  60.5%     -    1s
#      0     2   21.25746    0    8   50.09257   21.25746  57.6%     -    5s
#
# Explored 468 nodes (41643 simplex iterations) in 6.78 seconds (5.39 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 50.0926
#
# Optimal solution found (tolerance 3.00e-02)
# Best objective 5.009257279683e+01, best bound 5.009257279683e+01, gap 0.0000%
# [KS] iter 5/9 -> obj=50.0926, gap=0, K^+=0
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 6.8835684249988844e+00
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  6.8835684249988844e+00
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 375 rows, 981 columns and 197681 nonzeros
# Model fingerprint: 0x162b1cd0
# Model has 595 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 1156 simple general constraints
#   1156 INDICATOR
# Variable types: 947 continuous, 34 integer (34 binary)
# Coefficient statistics:
#   Matrix range     [6e-08, 1e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
#   QRHS range       [5e+01, 5e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 265 rows and 0 columns
# Presolve removed 0 rows and 539 columns
# Presolve time: 0.12s
# Presolved: 641 rows, 520 columns, 29097 nonzeros
# Presolved model has 78 quadratic objective terms
# Presolved model has 78 quadratic constraint(s)
# Variable types: 508 continuous, 12 integer (12 binary)
# Root relaxation presolved: 641 rows, 442 columns, 29019 nonzeros
# Root relaxation presolved model has 78 quadratic objective terms
#
#
# Root relaxation: objective 2.128752e+01, 323 iterations, 0.09 seconds (0.04 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      50.0925728   21.28752  57.5%     -    0s
#      0     0   21.28752    0    8   50.09257   21.28752  57.5%     -    0s
#      0     0   21.28752    0    8   50.09257   21.28752  57.5%     -    0s
#      0     0   21.28752    0    8   50.09257   21.28752  57.5%     -    0s
#      0     0   21.28752    0    8   50.09257   21.28752  57.5%     -    1s
#      0     0   21.28752    0    8   50.09257   21.28752  57.5%     -    1s
#      0     2   23.02045    0    8   50.09257   23.02045  54.0%     -    4s
#     22    19   24.84123    5    7   50.09257   23.02045  54.0%  66.6    5s
#
# Explored 363 nodes (29998 simplex iterations) in 6.53 seconds (4.93 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 50.0926
#
# Optimal solution found (tolerance 3.00e-02)
# Best objective 5.009257279683e+01, best bound 5.009257279683e+01, gap 0.0000%
# [KS] iter 6/9 -> obj=50.0926, gap=0, K^+=0
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 6.7024572999992715e+00
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  6.7024572999992715e+00
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 375 rows, 981 columns and 197681 nonzeros
# Model fingerprint: 0xbbb6e4d0
# Model has 595 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 1156 simple general constraints
#   1156 INDICATOR
# Variable types: 947 continuous, 34 integer (34 binary)
# Coefficient statistics:
#   Matrix range     [6e-08, 1e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
#   QRHS range       [5e+01, 5e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 265 rows and 0 columns
# Presolve removed 0 rows and 539 columns
# Presolve time: 0.20s
# Presolved: 641 rows, 520 columns, 29097 nonzeros
# Presolved model has 78 quadratic objective terms
# Presolved model has 78 quadratic constraint(s)
# Variable types: 508 continuous, 12 integer (12 binary)
# Root relaxation presolved: 641 rows, 442 columns, 29019 nonzeros
# Root relaxation presolved model has 78 quadratic objective terms
#
#
# Root relaxation: objective 1.865546e+01, 312 iterations, 0.07 seconds (0.04 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      50.0925728   18.65546  62.8%     -    0s
#      0     0   18.65546    0    8   50.09257   18.65546  62.8%     -    0s
#      0     0   18.65546    0    8   50.09257   18.65546  62.8%     -    0s
#      0     0   18.65546    0    8   50.09257   18.65546  62.8%     -    0s
#      0     0   18.65546    0    8   50.09257   18.65546  62.8%     -    1s
#      0     0   18.65546    0    8   50.09257   18.65546  62.8%     -    1s
#      0     2   20.83162    0    8   50.09257   20.83162  58.4%     -    5s
#
# Explored 290 nodes (32814 simplex iterations) in 6.71 seconds (5.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 50.0926
#
# Time limit reached
# Best objective 5.009257279683e+01, best bound 3.092536255918e+01, gap 38.2636%
# [KS] iter 7/9 -> obj=50.0926, gap=0.382636, K^+=0
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 6.18177255000046
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  6.18177255000046
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 375 rows, 981 columns and 197681 nonzeros
# Model fingerprint: 0xd8469583
# Model has 595 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 1156 simple general constraints
#   1156 INDICATOR
# Variable types: 947 continuous, 34 integer (34 binary)
# Coefficient statistics:
#   Matrix range     [6e-08, 1e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
#   QRHS range       [5e+01, 5e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 265 rows and 0 columns
# Presolve removed 0 rows and 539 columns
# Presolve time: 0.11s
# Presolved: 641 rows, 520 columns, 29097 nonzeros
# Presolved model has 78 quadratic objective terms
# Presolved model has 78 quadratic constraint(s)
# Variable types: 508 continuous, 12 integer (12 binary)
# Root relaxation presolved: 641 rows, 442 columns, 29019 nonzeros
# Root relaxation presolved model has 78 quadratic objective terms
#
#
# Root relaxation: objective 2.022823e+01, 268 iterations, 0.05 seconds (0.04 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      50.0925728   20.22823  59.6%     -    0s
#      0     0   20.22823    0    8   50.09257   20.22823  59.6%     -    0s
#      0     0   20.22823    0    8   50.09257   20.22823  59.6%     -    0s
#      0     0   20.22823    0    8   50.09257   20.22823  59.6%     -    0s
#      0     0   20.22823    0    8   50.09257   20.22823  59.6%     -    0s
#      0     0   20.22823    0    8   50.09257   20.22823  59.6%     -    0s
# H    0     0                      47.7142041   21.56096  54.8%     -    4s
# H    0     0                      47.7142041   21.56096  54.8%     -    4s
#      0     2   21.56096    0    8   47.71420   21.56096  54.8%     -    4s
#     85    25     cutoff    7        47.71420   22.16503  53.5%  94.6    5s
# H  117    28                      47.4519212   23.13176  51.3%   102    5s
# *  117    28               7      47.4519212   23.13176  51.3%   105    5s
# H  200    39                      47.4519197   23.13176  51.3%   103    5s
#
# Explored 359 nodes (35502 simplex iterations) in 6.19 seconds (4.78 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 47.4519 47.7142 50.0926
#
# Time limit reached
# Best objective 4.745191973605e+01, best bound 3.536519503115e+01, gap 25.4715%
# [KS] iter 8/9 -> obj=47.4519, gap=0.254715, K^+=2
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 5.2973254999960773e+00
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  5.2973254999960773e+00
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 375 rows, 981 columns and 197681 nonzeros
# Model fingerprint: 0xfc383722
# Model has 595 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 1156 simple general constraints
#   1156 INDICATOR
# Variable types: 947 continuous, 34 integer (34 binary)
# Coefficient statistics:
#   Matrix range     [6e-08, 1e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
#   QRHS range       [5e+01, 5e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 265 rows and 0 columns
# Presolve removed 0 rows and 539 columns
# Presolve time: 0.20s
# Presolved: 641 rows, 520 columns, 29097 nonzeros
# Presolved model has 78 quadratic objective terms
# Presolved model has 78 quadratic constraint(s)
# Variable types: 508 continuous, 12 integer (12 binary)
# Root relaxation presolved: 641 rows, 442 columns, 29019 nonzeros
# Root relaxation presolved model has 78 quadratic objective terms
#
#
# Root relaxation: objective 1.695791e+01, 262 iterations, 0.06 seconds (0.04 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      47.4519190   16.95791  64.3%     -    0s
#      0     0   16.95791    0    8   47.45192   16.95791  64.3%     -    0s
#      0     0   16.95791    0    8   47.45192   16.95791  64.3%     -    0s
#      0     0   16.95791    0    8   47.45192   16.95791  64.3%     -    0s
#      0     0   16.95791    0    8   47.45192   16.95791  64.3%     -    0s
#      0     0   16.95791    0    8   47.45192   16.95791  64.3%     -    0s
# H    0     0                      47.4519162   16.95791  64.3%     -    4s
#      0     2   16.95791    0    8   47.45192   16.95791  64.3%     -    4s
#     31    19   24.21002    6    6   47.45192   17.06814  64.0%  88.6    5s
#
# Explored 99 nodes (10269 simplex iterations) in 5.31 seconds (3.30 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 47.4519
#
# Time limit reached
# Best objective 4.745191620768e+01, best bound 1.706813762047e+01, gap 64.0307%
# [KS] iter 9/9 -> obj=47.4519, gap=0.640307, K^+=0
# [Alg3] KS#1: UB=47.4519, gap=0.640307
# [Alg3] M=9.74186, ||w||_1/B=7.00184
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 2.6666660555549444e+00
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  2.6666660555549444e+00
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 379 rows, 981 columns and 197681 nonzeros
# Model fingerprint: 0x7caaa8de
# Model has 595 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 1156 simple general constraints
#   1156 INDICATOR
# Variable types: 947 continuous, 34 integer (34 binary)
# Coefficient statistics:
#   Matrix range     [6e-08, 1e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
#   QRHS range       [5e+01, 5e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 101 rows and 0 columns
# Presolve removed 0 rows and 585 columns
# Presolve time: 0.14s
# Presolved: 481 rows, 432 columns, 13989 nonzeros
# Presolved model has 36 quadratic objective terms
# Presolved model has 36 quadratic constraint(s)
# Variable types: 424 continuous, 8 integer (8 binary)
# Root relaxation presolved: 481 rows, 396 columns, 13953 nonzeros
# Root relaxation presolved model has 36 quadratic objective terms
#
#
# Root relaxation: objective 3.828401e+01, 304 iterations, 0.04 seconds (0.02 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      47.4519165   38.28401  19.3%     -    0s
# H    0     0                      47.4519162   38.28401  19.3%     -    0s
#      0     0   38.28401    0    4   47.45192   38.28401  19.3%     -    0s
#      0     0   38.28401    0    4   47.45192   38.28401  19.3%     -    0s
#      0     0   38.28401    0    5   47.45192   38.28401  19.3%     -    0s
#      0     0   38.28401    0    5   47.45192   38.28401  19.3%     -    0s
#      0     0   38.28401    0    5   47.45192   38.28401  19.3%     -    0s
#
# Cutting planes:
#   MIR: 3
#
# Explored 1 nodes (430 simplex iterations) in 1.27 seconds (0.43 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 47.4519
#
# Optimal solution found (tolerance 3.00e-02)
# Best objective 4.745191620768e+01, best bound 4.745191620768e+01, gap 0.0000%
# [KS2] iter 1/9 -> obj=47.4519, gap=0, K^+=5
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 2.7625027124995540e+00
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  2.7625027124995540e+00
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 380 rows, 981 columns and 197681 nonzeros
# Model fingerprint: 0x6f348fc6
# Model has 595 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 1156 simple general constraints
#   1156 INDICATOR
# Variable types: 947 continuous, 34 integer (34 binary)
# Coefficient statistics:
#   Matrix range     [6e-08, 1e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
#   QRHS range       [5e+01, 5e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 70 rows and 0 columns
# Presolve removed 0 rows and 594 columns
# Presolve time: 0.09s
# Presolved: 451 rows, 415 columns, 8655 nonzeros
# Presolved model has 28 quadratic objective terms
# Presolved model has 28 quadratic constraint(s)
# Variable types: 408 continuous, 7 integer (7 binary)
# Root relaxation presolved: 451 rows, 387 columns, 8627 nonzeros
# Root relaxation presolved model has 28 quadratic objective terms
#
#
# Root relaxation: objective 4.275086e+01, 344 iterations, 0.03 seconds (0.01 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      47.4519169   42.75086  9.91%     -    0s
#      0     0   42.75086    0    3   47.45192   42.75086  9.91%     -    0s
#      0     0   42.75086    0    3   47.45192   42.75086  9.91%     -    0s
#      0     0   42.75086    0    3   47.45192   42.75086  9.91%     -    0s
#      0     0   42.75086    0    3   47.45192   42.75086  9.91%     -    0s
# H    0     0                      47.4519162   42.75086  9.91%     -    0s
#
# Cutting planes:
#   MIR: 2
#
# Explored 1 nodes (429 simplex iterations) in 0.50 seconds (0.15 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 47.4519
#
# Optimal solution found (tolerance 3.00e-02)
# Best objective 4.745191620768e+01, best bound 4.745191620768e+01, gap 0.0000%
# [KS2] iter 2/9 -> obj=47.4519, gap=0, K^+=2
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 2.9645372571425730e+00
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  2.9645372571425730e+00
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 378 rows, 981 columns and 197681 nonzeros
# Model fingerprint: 0xbab01813
# Model has 595 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 1156 simple general constraints
#   1156 INDICATOR
# Variable types: 947 continuous, 34 integer (34 binary)
# Coefficient statistics:
#   Matrix range     [6e-08, 1e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
#   QRHS range       [5e+01, 5e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 136 rows and 0 columns
# Presolve removed 0 rows and 575 columns
# Presolve time: 0.10s
# Presolved: 515 rows, 451 columns, 17226 nonzeros
# Presolved model has 45 quadratic objective terms
# Presolved model has 45 quadratic constraint(s)
# Variable types: 442 continuous, 9 integer (9 binary)
# Root relaxation presolved: 515 rows, 406 columns, 17181 nonzeros
# Root relaxation presolved model has 45 quadratic objective terms
#
#
# Root relaxation: objective 3.087233e+01, 313 iterations, 0.03 seconds (0.03 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      47.4519162   30.87233  34.9%     -    0s
#      0     0   30.87233    0    5   47.45192   30.87233  34.9%     -    0s
#      0     0   30.87233    0    5   47.45192   30.87233  34.9%     -    0s
#      0     0   30.87233    0    6   47.45192   30.87233  34.9%     -    0s
#      0     0   30.87233    0    6   47.45192   30.87233  34.9%     -    0s
#      0     0   30.87233    0    6   47.45192   30.87233  34.9%     -    0s
#
# Cutting planes:
#   MIR: 3
#
# Explored 1 nodes (467 simplex iterations) in 2.15 seconds (0.76 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 47.4519
#
# Optimal solution found (tolerance 3.00e-02)
# Best objective 4.745191620768e+01, best bound 4.745191620768e+01, gap 0.0000%
# [KS2] iter 3/9 -> obj=47.4519, gap=0, K^+=0
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 2.9433913666665226e+00
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  2.9433913666665226e+00
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 378 rows, 981 columns and 197681 nonzeros
# Model fingerprint: 0xebf610a2
# Model has 595 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 1156 simple general constraints
#   1156 INDICATOR
# Variable types: 947 continuous, 34 integer (34 binary)
# Coefficient statistics:
#   Matrix range     [6e-08, 1e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
#   QRHS range       [5e+01, 5e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 136 rows and 0 columns
# Presolve removed 0 rows and 575 columns
# Presolve time: 0.14s
# Presolved: 515 rows, 451 columns, 17226 nonzeros
# Presolved model has 45 quadratic objective terms
# Presolved model has 45 quadratic constraint(s)
# Variable types: 442 continuous, 9 integer (9 binary)
# Root relaxation presolved: 515 rows, 406 columns, 17181 nonzeros
# Root relaxation presolved model has 45 quadratic objective terms
#
#
# Root relaxation: objective 2.365447e+01, 281 iterations, 0.05 seconds (0.02 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      47.4519162   23.65447  50.2%     -    0s
#      0     0   23.65447    0    5   47.45192   23.65447  50.2%     -    0s
#      0     0   23.65447    0    5   47.45192   23.65447  50.2%     -    0s
#      0     0   23.65447    0    6   47.45192   23.65447  50.2%     -    0s
#      0     0   23.65447    0    6   47.45192   23.65447  50.2%     -    0s
#      0     0   23.65447    0    6   47.45192   23.65447  50.2%     -    0s
#      0     2   28.82311    0    6   47.45192   28.82311  39.3%     -    2s
#
# Cutting planes:
#   MIR: 5
#   Relax-and-lift: 1
#
# Explored 188 nodes (10209 simplex iterations) in 2.77 seconds (1.48 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 47.4519
#
# Optimal solution found (tolerance 3.00e-02)
# Best objective 4.745191620768e+01, best bound 4.745191620768e+01, gap 0.0000%
# [KS2] iter 4/9 -> obj=47.4519, gap=0, K^+=0
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 2.80236317999952
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  2.80236317999952
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 378 rows, 981 columns and 197681 nonzeros
# Model fingerprint: 0x0460d1cc
# Model has 595 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 1156 simple general constraints
#   1156 INDICATOR
# Variable types: 947 continuous, 34 integer (34 binary)
# Coefficient statistics:
#   Matrix range     [6e-08, 1e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
#   QRHS range       [5e+01, 5e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 136 rows and 0 columns
# Presolve removed 0 rows and 575 columns
# Presolve time: 0.13s
# Presolved: 515 rows, 451 columns, 17226 nonzeros
# Presolved model has 45 quadratic objective terms
# Presolved model has 45 quadratic constraint(s)
# Variable types: 442 continuous, 9 integer (9 binary)
# Root relaxation presolved: 515 rows, 406 columns, 17181 nonzeros
# Root relaxation presolved model has 45 quadratic objective terms
#
#
# Root relaxation: objective 3.112475e+01, 237 iterations, 0.04 seconds (0.02 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      47.4519162   31.12475  34.4%     -    0s
#      0     0   31.12475    0    5   47.45192   31.12475  34.4%     -    0s
#      0     0   31.12475    0    5   47.45192   31.12475  34.4%     -    0s
#      0     0   31.12475    0    6   47.45192   31.12475  34.4%     -    0s
#      0     0   31.12475    0    6   47.45192   31.12475  34.4%     -    0s
#      0     0   31.12475    0    6   47.45192   31.12475  34.4%     -    0s
#      0     2   40.30171    0    6   47.45192   40.30171  15.1%     -    2s
#
# Cutting planes:
#   MIR: 4
#
# Explored 54 nodes (3263 simplex iterations) in 2.47 seconds (0.99 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 47.4519
#
# Optimal solution found (tolerance 3.00e-02)
# Best objective 4.745191620768e+01, best bound 4.655228806610e+01, gap 1.8959%
# [KS2] iter 5/9 -> obj=47.4519, gap=0.0189587, K^+=0
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 2.6852344999988418e+00
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  2.6852344999988418e+00
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 378 rows, 981 columns and 197681 nonzeros
# Model fingerprint: 0xb6f80a10
# Model has 595 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 1156 simple general constraints
#   1156 INDICATOR
# Variable types: 947 continuous, 34 integer (34 binary)
# Coefficient statistics:
#   Matrix range     [6e-08, 1e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
#   QRHS range       [5e+01, 5e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 136 rows and 0 columns
# Presolve removed 0 rows and 575 columns
# Presolve time: 0.10s
# Presolved: 515 rows, 451 columns, 17226 nonzeros
# Presolved model has 45 quadratic objective terms
# Presolved model has 45 quadratic constraint(s)
# Variable types: 442 continuous, 9 integer (9 binary)
# Root relaxation presolved: 515 rows, 406 columns, 17181 nonzeros
# Root relaxation presolved model has 45 quadratic objective terms
#
#
# Root relaxation: objective 2.992463e+01, 255 iterations, 0.02 seconds (0.02 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      47.4519157   29.92463  36.9%     -    0s
#      0     0   29.92463    0    5   47.45192   29.92463  36.9%     -    0s
#      0     0   29.92463    0    5   47.45192   29.92463  36.9%     -    0s
#      0     0   29.92463    0    6   47.45192   29.92463  36.9%     -    0s
#      0     0   29.92463    0    6   47.45192   29.92463  36.9%     -    0s
#      0     0   29.92463    0    6   47.45192   29.92463  36.9%     -    0s
#      0     2   33.16255    0    6   47.45192   33.16255  30.1%     -    2s
#
# Cutting planes:
#   MIR: 1
#
# Explored 61 nodes (3662 simplex iterations) in 2.35 seconds (1.02 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 47.4519
# No other solutions better than 47.4519
#
# Optimal solution found (tolerance 3.00e-02)
# Best objective 4.745191517347e+01, best bound 4.745191568371e+01, gap 0.0000%
# [KS2] iter 6/9 -> obj=47.4519, gap=0, K^+=0
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 2.4452952666664109e+00
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  2.4452952666664109e+00
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 378 rows, 981 columns and 197681 nonzeros
# Model fingerprint: 0x12c6976e
# Model has 595 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 1156 simple general constraints
#   1156 INDICATOR
# Variable types: 947 continuous, 34 integer (34 binary)
# Coefficient statistics:
#   Matrix range     [6e-08, 1e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
#   QRHS range       [5e+01, 5e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 136 rows and 0 columns
# Presolve removed 0 rows and 575 columns
# Presolve time: 0.11s
# Presolved: 515 rows, 451 columns, 17226 nonzeros
# Presolved model has 45 quadratic objective terms
# Presolved model has 45 quadratic constraint(s)
# Variable types: 442 continuous, 9 integer (9 binary)
# Root relaxation presolved: 515 rows, 406 columns, 17181 nonzeros
# Root relaxation presolved model has 45 quadratic objective terms
#
#
# Root relaxation: objective 2.688841e+01, 264 iterations, 0.02 seconds (0.02 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      47.4519162   26.88841  43.3%     -    0s
#      0     0   26.88841    0    5   47.45192   26.88841  43.3%     -    0s
#      0     0   26.88841    0    5   47.45192   26.88841  43.3%     -    0s
#      0     0   26.88841    0    6   47.45192   26.88841  43.3%     -    0s
#      0     0   26.88841    0    6   47.45192   26.88841  43.3%     -    0s
#      0     0   26.88841    0    6   47.45192   26.88841  43.3%     -    0s
#      0     2   31.94753    0    6   47.45192   31.94753  32.7%     -    2s
#
# Cutting planes:
#   MIR: 5
#
# Explored 87 nodes (5682 simplex iterations) in 2.32 seconds (1.19 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 47.4519
#
# Optimal solution found (tolerance 3.00e-02)
# Warning: max constraint violation (1.0332e-06) exceeds tolerance
# Best objective 4.745191620768e+01, best bound 4.745191620768e+01, gap 0.0000%
# [KS2] iter 7/9 -> obj=47.4519, gap=0, K^+=0
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 2.0836987999973644e+00
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  2.0836987999973644e+00
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 380 rows, 981 columns and 197681 nonzeros
# Model fingerprint: 0x80a61689
# Model has 595 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 1156 simple general constraints
#   1156 INDICATOR
# Variable types: 947 continuous, 34 integer (34 binary)
# Coefficient statistics:
#   Matrix range     [6e-08, 1e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
#   QRHS range       [5e+01, 5e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 70 rows and 0 columns
# Presolve removed 0 rows and 594 columns
# Presolve time: 0.11s
# Presolved: 451 rows, 415 columns, 11112 nonzeros
# Presolved model has 28 quadratic objective terms
# Presolved model has 28 quadratic constraint(s)
# Variable types: 408 continuous, 7 integer (7 binary)
# Root relaxation presolved: 451 rows, 387 columns, 11084 nonzeros
# Root relaxation presolved model has 28 quadratic objective terms
#
#
# Root relaxation: objective 4.492367e+01, 322 iterations, 0.03 seconds (0.02 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      47.4519162   44.92367  5.33%     -    0s
#      0     0   44.92367    0    3   47.45192   44.92367  5.33%     -    0s
#      0     0   44.92367    0    3   47.45192   44.92367  5.33%     -    0s
#
# Cutting planes:
#   MIR: 5
#   Relax-and-lift: 1
#
# Explored 1 nodes (365 simplex iterations) in 0.49 seconds (0.17 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 47.4519
#
# Optimal solution found (tolerance 3.00e-02)
# Warning: max constraint violation (1.0332e-06) exceeds tolerance
# Best objective 4.745191620768e+01, best bound 4.745191620768e+01, gap 0.0000%
# [KS2] iter 8/9 -> obj=47.4519, gap=0, K^+=2
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 2.5302608999991207e+00
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  2.5302608999991207e+00
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 380 rows, 981 columns and 197681 nonzeros
# Model fingerprint: 0x5487e272
# Model has 595 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 1156 simple general constraints
#   1156 INDICATOR
# Variable types: 947 continuous, 34 integer (34 binary)
# Coefficient statistics:
#   Matrix range     [6e-08, 1e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
#   QRHS range       [5e+01, 5e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 70 rows and 0 columns
# Presolve removed 0 rows and 594 columns
# Presolve time: 0.13s
# Presolved: 451 rows, 415 columns, 11112 nonzeros
# Presolved model has 28 quadratic objective terms
# Presolved model has 28 quadratic constraint(s)
# Variable types: 408 continuous, 7 integer (7 binary)
# Root relaxation presolved: 451 rows, 387 columns, 11084 nonzeros
# Root relaxation presolved model has 28 quadratic objective terms
#
#
# Root relaxation: objective 4.050652e+01, 303 iterations, 0.05 seconds (0.02 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      47.4519154   40.50652  14.6%     -    0s
#      0     0   40.50652    0    3   47.45192   40.50652  14.6%     -    0s
#      0     0   40.50652    0    3   47.45192   40.50652  14.6%     -    0s
#      0     0   40.50652    0    4   47.45192   40.50652  14.6%     -    0s
#      0     0   40.50652    0    4   47.45192   40.50652  14.6%     -    0s
#
# Cutting planes:
#   MIR: 1
#
# Explored 1 nodes (408 simplex iterations) in 0.58 seconds (0.19 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 47.4519
# No other solutions better than 47.4519
#
# Optimal solution found (tolerance 3.00e-02)
# Best objective 4.745191478975e+01, best bound 4.745191542968e+01, gap 0.0000%
# [KS2] iter 9/9 -> obj=47.4519, gap=0, K^+=0
# [Alg3] Accept KS#2: UB=47.4519, gap=0
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 108
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  108
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 353 rows, 981 columns and 197681 nonzeros
# Model fingerprint: 0xabb7c558
# Model has 595 quadratic objective terms
# Model has 1156 simple general constraints
#   1156 INDICATOR
# Variable types: 947 continuous, 34 integer (34 binary)
# Coefficient statistics:
#   Matrix range     [6e-08, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# Loaded user MIP start with objective 351
#
# Presolve removed 2 rows and 35 columns
# Presolve time: 0.21s
# Presolved: 351 rows, 946 columns, 197084 nonzeros
# Presolved model has 1089 SOS constraint(s)
# Presolved model has 561 quadratic objective terms
# Variable types: 912 continuous, 34 integer (34 binary)
# Root relaxation presolved: 350 rows, 912 columns, 197050 nonzeros
# Root relaxation presolved model has 561 quadratic objective terms
#
#
# Root relaxation: objective 2.838499e+00, 109 iterations, 0.29 seconds (0.17 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    2.83850    0  957  351.00000    2.83850  99.2%     -    0s
# H    0     0                     224.4868450    2.83850  98.7%     -    0s
# H    0     0                      84.6806671    2.83850  96.6%     -    1s
#      0     0    2.83850    0  957   84.68067    2.83850  96.6%     -    2s
#      0     2    2.83850    0  957   84.68067    2.83850  96.6%     -    2s
# *   12    18               5      63.5809987    2.83850  95.5%   104    3s
# *   28    24               6      60.5097951    2.83850  95.3%   132    4s
# *   29    24               6      55.4447619    2.83850  94.9%   162    4s
#     31    24     cutoff    7        55.44476    2.83850  94.9%   158    5s
#     85    22    5.81730   13  456   55.44476    2.83850  94.9%   272   10s
# *  141    25              20      54.3142332    2.83850  94.8%   265   12s
#    254    37    3.54098    7  750   54.31423    3.01275  94.5%   199   15s
# *  259    37               7      54.2623294    3.01275  94.4%   207   15s
# *  275    37               9      52.0147291    3.01275  94.2%   216   16s
#    340    41     cutoff   18        52.01473    3.01275  94.2%   228   20s
# *  383    40              22      50.1042431    3.01275  94.0%   224   21s
#    474    46    4.33874    6  696   50.10424    3.26942  93.5%   205   25s
#    569    51    6.26536   14  414   50.10424    3.39101  93.2%   212   30s
#    705    57    3.98800    8  696   50.10424    3.50341  93.0%   208   35s
# H  728    57                      48.7710741    3.50341  92.8%   211   36s
# H  749    59                      47.4519162    3.50341  92.6%   211   37s
#    843    62     cutoff   19        47.45192    3.50341  92.6%   206   40s
#    928    60     cutoff   10        47.45192    3.50341  92.6%   205   45s
#   1053    65    4.78746    9  644   47.45192    3.64519  92.3%   199   50s
#   1091    72    8.95858   17  300   47.45192    3.64519  92.3%   198   55s
#   1201    73    6.77793   16  336   47.45192    3.64519  92.3%   199   60s
#   1363    83    6.97539   16  336   47.45192    3.83361  91.9%   195   65s
#   1578    94    9.61914   17  300   47.45192    3.86581  91.9%   192   72s
#   1736    97    7.10468   16  336   47.45192    3.93942  91.7%   191   76s
#   1900   101    6.64041   16  336   47.45192    3.93942  91.7%   190   81s
#   2049   101     cutoff   15        47.45192    3.95524  91.7%   188   86s
#   2209   115    4.88596   10  594   47.45192    3.95524  91.7%   187   93s
#   2340   162     cutoff   24        47.45192    4.02205  91.5%   185   96s
#   2597   171    8.79345   16  336   47.45192    4.09707  91.4%   180  102s
#   2712   171    4.97289   10  594   47.45192    4.09707  91.4%   179  105s
#
# Explored 2807 nodes (504630 simplex iterations) in 108.07 seconds (127.25 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 47.4519 50.1042 52.0147 ... 351
#
# Time limit reached
# Best objective 4.745191620768e+01, best bound 4.106742491718e+00, gap 91.3455%
#
# === Comparison (same total time) ===
#                          method      UB   MIPGap runtime  selected_k
# Algorithm-3 (KS+Bounds+BigM+KS) 47.4519        0 120.00s           5
#       Full Co-NLSVM (indicator) 47.4519 0.913455 120.12s           5

# %%
# 读取 UCI 数据
ionosphere = fetch_ucirepo(id=52)  
X_df = ionosphere.data.features
y_series = ionosphere.data.targets['Class']

# 清洗与对齐
X_df = X_df.replace('?', np.nan).dropna()
y_series = y_series.loc[X_df.index]

feature_names = list(X_df.columns)
X = StandardScaler().fit_transform(X_df.values)

# y_series: 形如包含 'N' / 'R' 的 pandas Series
y_str = y_series.astype(str).str.strip().str.upper().values

# 检查是否真的是二分类且只含 g/b
uniq = np.unique(y_str)
if not set(uniq).issubset({"G", "B"}) or len(uniq) != 2:
    raise ValueError(f"期望标签为 {{'G','B'}}，但实际唯一取值={uniq}")

# 约定：g -> +1，b -> -1  （和你之前的一致）
y = np.where(y_str == "G", 1.0, -1.0)

# 假设你已准备好 X, y（y ∈ {-1,+1}）, 以及 feature_names（可选）
B, C = 10, 1.0
T_total = 120.0   # 两侧统一总时间（秒）
rho = 4

df_cmp = run_comparison(X, y, B, C, total_time=T_total, rho=rho, feature_names=feature_names, verbose=True)
# Out:
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 5.2753340222221192e+00
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  5.2753340222221192e+00
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 372 rows, 981 columns and 197681 nonzeros
# Model fingerprint: 0xdfcdb61a
# Model has 595 quadratic objective terms
# Model has 1156 simple general constraints
#   1156 INDICATOR
# Variable types: 947 continuous, 34 integer (34 binary)
# Coefficient statistics:
#   Matrix range     [6e-08, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# Loaded user MIP start with objective 351
#
# Presolve removed 21 rows and 510 columns
# Presolve time: 0.10s
# Presolved: 351 rows, 471 columns, 37465 nonzeros
# Presolved model has 196 SOS constraint(s)
# Presolved model has 105 quadratic objective terms
# Variable types: 456 continuous, 15 integer (15 binary)
# Root relaxation presolved: 350 rows, 456 columns, 37450 nonzeros
# Root relaxation presolved model has 105 quadratic objective terms
#
#
# Root relaxation: objective 1.529220e+01, 139 iterations, 0.05 seconds (0.03 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   15.29220    0   70  351.00000   15.29220  95.6%     -    0s
# H    0     0                     173.3299402   15.29220  91.2%     -    0s
# H    0     0                      32.1987219   15.29220  52.5%     -    0s
#      0     0   15.29220    0   70   32.19872   15.29220  52.5%     -    0s
#      0     2   15.29220    0   70   32.19872   15.29220  52.5%     -    0s
# *   64    60              12      31.7316459   15.29220  51.8%  39.0    0s
# *   68    61              13      30.0684573   15.29220  49.1%  41.7    0s
# *   70    62              11      27.6634809   15.29220  44.7%  44.4    0s
# *   98    68              12      26.5040570   16.63309  37.2%  47.6    1s
# H  109    69                      22.9790767   16.63309  27.6%  44.3    1s
# H  224    82                      21.5523252   18.44529  14.4%  35.5    1s
#
# Explored 489 nodes (10486 simplex iterations) in 2.49 seconds (2.28 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 8: 21.5523 22.9791 26.5041 ... 351
#
# Optimal solution found (tolerance 3.00e-02)
# Best objective 2.155232515035e+01, best bound 2.155232515035e+01, gap 0.0000%
# [KS] iter 1/9 -> obj=21.5523, gap=0, K^+=2
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 5.4834210250000979e+00
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  5.4834210250000979e+00
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 372 rows, 981 columns and 197681 nonzeros
# Model fingerprint: 0x3dc2602d
# Model has 595 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 1156 simple general constraints
#   1156 INDICATOR
# Variable types: 947 continuous, 34 integer (34 binary)
# Coefficient statistics:
#   Matrix range     [6e-08, 1e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
#   QRHS range       [2e+01, 2e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 430 rows and 0 columns
# Presolve removed 0 rows and 494 columns
# Presolve time: 0.15s
# Presolved: 803 rows, 607 columns, 38943 nonzeros
# Presolved model has 120 quadratic objective terms
# Presolved model has 120 quadratic constraint(s)
# Variable types: 592 continuous, 15 integer (15 binary)
# Root relaxation presolved: 803 rows, 487 columns, 38823 nonzeros
# Root relaxation presolved model has 120 quadratic objective terms
#
#
# Root relaxation: objective 1.529220e+01, 275 iterations, 0.07 seconds (0.05 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      21.5523252   15.29220  29.0%     -    0s
#      0     0   15.29220    0    5   21.55233   15.29220  29.0%     -    0s
#      0     0   15.29220    0    5   21.55233   15.29220  29.0%     -    0s
#      0     0   15.29220    0    6   21.55233   15.29220  29.0%     -    1s
#      0     0   15.29220    0    6   21.55233   15.29220  29.0%     -    1s
#      0     0   15.29220    0    6   21.55233   15.29220  29.0%     -    1s
#      0     2   15.29220    0    6   21.55233   15.29220  29.0%     -    4s
#    130    41   19.45246   11    3   21.55233   17.17634  20.3%  45.0    5s
#
# Cutting planes:
#   MIR: 8
#   Relax-and-lift: 1
#
# Explored 268 nodes (10663 simplex iterations) in 5.42 seconds (3.34 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 21.5523
#
# Optimal solution found (tolerance 3.00e-02)
# Best objective 2.155232515035e+01, best bound 2.117934427485e+01, gap 1.7306%
# [KS] iter 2/9 -> obj=21.5523, gap=0.0173058, K^+=4
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 5.3341273428574949e+00
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  5.3341273428574949e+00
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 372 rows, 981 columns and 197681 nonzeros
# Model fingerprint: 0x3dc2602d
# Model has 595 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 1156 simple general constraints
#   1156 INDICATOR
# Variable types: 947 continuous, 34 integer (34 binary)
# Coefficient statistics:
#   Matrix range     [6e-08, 1e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
#   QRHS range       [2e+01, 2e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 430 rows and 0 columns
# Presolve removed 0 rows and 494 columns
# Presolve time: 0.14s
# Presolved: 803 rows, 607 columns, 38943 nonzeros
# Presolved model has 120 quadratic objective terms
# Presolved model has 120 quadratic constraint(s)
# Variable types: 592 continuous, 15 integer (15 binary)
# Root relaxation presolved: 803 rows, 487 columns, 38823 nonzeros
# Root relaxation presolved model has 120 quadratic objective terms
#
#
# Root relaxation: objective 1.529220e+01, 275 iterations, 0.06 seconds (0.05 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      21.5523252   15.29220  29.0%     -    0s
#      0     0   15.29220    0    5   21.55233   15.29220  29.0%     -    0s
#      0     0   15.29220    0    5   21.55233   15.29220  29.0%     -    0s
#      0     0   15.29220    0    6   21.55233   15.29220  29.0%     -    1s
#      0     0   15.29220    0    6   21.55233   15.29220  29.0%     -    1s
#      0     0   15.29220    0    6   21.55233   15.29220  29.0%     -    1s
#      0     2   15.29220    0    6   21.55233   15.29220  29.0%     -    4s
#     71    33     cutoff   11        21.55233   15.31613  28.9%  38.1    5s
#
# Cutting planes:
#   MIR: 8
#   Relax-and-lift: 1
#
# Explored 115 nodes (5237 simplex iterations) in 5.34 seconds (2.69 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 21.5523
#
# Time limit reached
# Best objective 2.155232515035e+01, best bound 1.668931968776e+01, gap 22.5637%
# [KS] iter 3/9 -> obj=21.5523, gap=0.225637, K^+=1
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 5.1395301166667196e+00
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  5.1395301166667196e+00
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 372 rows, 981 columns and 197681 nonzeros
# Model fingerprint: 0xb1ba0a23
# Model has 595 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 1156 simple general constraints
#   1156 INDICATOR
# Variable types: 947 continuous, 34 integer (34 binary)
# Coefficient statistics:
#   Matrix range     [6e-08, 1e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
#   QRHS range       [2e+01, 2e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 430 rows and 0 columns
# Presolve removed 0 rows and 494 columns
# Presolve time: 0.14s
# Presolved: 803 rows, 607 columns, 44208 nonzeros
# Presolved model has 120 quadratic objective terms
# Presolved model has 120 quadratic constraint(s)
# Variable types: 592 continuous, 15 integer (15 binary)
# Root relaxation presolved: 803 rows, 487 columns, 44088 nonzeros
# Root relaxation presolved model has 120 quadratic objective terms
#
#
# Root relaxation: objective 1.396400e+01, 275 iterations, 0.06 seconds (0.06 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      21.5523245   13.96400  35.2%     -    0s
#      0     0   13.96400    0    6   21.55232   13.96400  35.2%     -    0s
#      0     0   13.96400    0    6   21.55232   13.96400  35.2%     -    0s
#      0     0   13.96400    0    7   21.55232   13.96400  35.2%     -    0s
#      0     0   13.96400    0    7   21.55232   13.96400  35.2%     -    0s
#      0     0   13.96400    0    7   21.55232   13.96400  35.2%     -    0s
#      0     2   13.96400    0    7   21.55232   13.96400  35.2%     -    4s
#    107    49   20.82769   11    4   21.55232   14.08799  34.6%  40.1    5s
#
# Cutting planes:
#   MIR: 2
#   Relax-and-lift: 1
#
# Explored 120 nodes (5513 simplex iterations) in 5.15 seconds (2.87 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 21.5523
#
# Time limit reached
# Best objective 2.155232447948e+01, best bound 1.408798594051e+01, gap 34.6336%
# [KS] iter 4/9 -> obj=21.5523, gap=0.346336, K^+=3
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 4.9849391399999146e+00
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  4.9849391399999146e+00
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 372 rows, 981 columns and 197681 nonzeros
# Model fingerprint: 0x022349d9
# Model has 595 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 1156 simple general constraints
#   1156 INDICATOR
# Variable types: 947 continuous, 34 integer (34 binary)
# Coefficient statistics:
#   Matrix range     [6e-08, 1e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
#   QRHS range       [2e+01, 2e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 430 rows and 0 columns
# Presolve removed 0 rows and 494 columns
# Presolve time: 0.14s
# Presolved: 803 rows, 607 columns, 44208 nonzeros
# Presolved model has 120 quadratic objective terms
# Presolved model has 120 quadratic constraint(s)
# Variable types: 592 continuous, 15 integer (15 binary)
# Root relaxation presolved: 803 rows, 487 columns, 44088 nonzeros
# Root relaxation presolved model has 120 quadratic objective terms
#
#
# Root relaxation: objective 1.287572e+01, 241 iterations, 0.06 seconds (0.05 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      21.5523252   12.87572  40.3%     -    0s
#      0     0   12.87572    0    6   21.55233   12.87572  40.3%     -    0s
#      0     0   12.87572    0    6   21.55233   12.87572  40.3%     -    0s
#      0     0   12.87572    0    7   21.55233   12.87572  40.3%     -    1s
#      0     0   12.87572    0    7   21.55233   12.87572  40.3%     -    1s
#      0     0   12.87572    0    7   21.55233   12.87572  40.3%     -    1s
#      0     0   12.87572    0    7   21.55233   12.87572  40.3%     -    1s
#      0     0   12.87572    0    7   21.55233   12.87572  40.3%     -    1s
#      0     2   12.87572    0    7   21.55233   12.87572  40.3%     -    4s
#
# Cutting planes:
#   MIR: 9
#
# Explored 36 nodes (1608 simplex iterations) in 5.00 seconds (2.45 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 21.5523
#
# Time limit reached
# Best objective 2.155232515035e+01, best bound 1.287572300223e+01, gap 40.2583%
# [KS] iter 5/9 -> obj=21.5523, gap=0.402583, K^+=0
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 4.7932089750011073e+00
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  4.7932089750011073e+00
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 372 rows, 981 columns and 197681 nonzeros
# Model fingerprint: 0x6f3bca87
# Model has 595 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 1156 simple general constraints
#   1156 INDICATOR
# Variable types: 947 continuous, 34 integer (34 binary)
# Coefficient statistics:
#   Matrix range     [6e-08, 1e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
#   QRHS range       [2e+01, 2e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 430 rows and 0 columns
# Presolve removed 0 rows and 494 columns
# Presolve time: 0.17s
# Presolved: 803 rows, 607 columns, 44208 nonzeros
# Presolved model has 120 quadratic objective terms
# Presolved model has 120 quadratic constraint(s)
# Variable types: 592 continuous, 15 integer (15 binary)
# Root relaxation presolved: 803 rows, 487 columns, 44088 nonzeros
# Root relaxation presolved model has 120 quadratic objective terms
#
#
# Root relaxation: objective 1.136812e+01, 271 iterations, 0.06 seconds (0.06 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      21.5523252   11.36812  47.3%     -    0s
#      0     0   11.36812    0    6   21.55233   11.36812  47.3%     -    0s
#      0     0   11.36812    0    6   21.55233   11.36812  47.3%     -    0s
#      0     0   11.36812    0    7   21.55233   11.36812  47.3%     -    1s
#      0     0   11.36812    0    7   21.55233   11.36812  47.3%     -    1s
#      0     0   11.36812    0    7   21.55233   11.36812  47.3%     -    1s
#
# Cutting planes:
#   MIR: 6
#   Relax-and-lift: 1
#
# Explored 1 nodes (717 simplex iterations) in 4.81 seconds (1.84 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 21.5523
#
# Time limit reached
# Best objective 2.155232515035e+01, best bound 1.136811622230e+01, gap 47.2534%
# [KS] iter 6/9 -> obj=21.5523, gap=0.472534, K^+=0
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 4.5051247666682075e+00
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  4.5051247666682075e+00
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 372 rows, 981 columns and 197681 nonzeros
# Model fingerprint: 0x480d6a43
# Model has 595 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 1156 simple general constraints
#   1156 INDICATOR
# Variable types: 947 continuous, 34 integer (34 binary)
# Coefficient statistics:
#   Matrix range     [6e-08, 1e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
#   QRHS range       [2e+01, 2e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 430 rows and 0 columns
# Presolve removed 0 rows and 494 columns
# Presolve time: 0.26s
# Presolved: 803 rows, 607 columns, 44208 nonzeros
# Presolved model has 120 quadratic objective terms
# Presolved model has 120 quadratic constraint(s)
# Variable types: 592 continuous, 15 integer (15 binary)
# Root relaxation presolved: 803 rows, 487 columns, 44088 nonzeros
# Root relaxation presolved model has 120 quadratic objective terms
#
#
# Root relaxation: objective 1.144530e+01, 231 iterations, 0.08 seconds (0.05 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      21.5523242   11.44530  46.9%     -    0s
#      0     0   11.44530    0    6   21.55232   11.44530  46.9%     -    0s
#      0     0   11.44530    0    6   21.55232   11.44530  46.9%     -    0s
#      0     0   11.44530    0    7   21.55232   11.44530  46.9%     -    0s
#      0     0   11.44530    0    7   21.55232   11.44530  46.9%     -    1s
#      0     0   11.44530    0    7   21.55232   11.44530  46.9%     -    1s
# H    0     0                      20.9838536   11.44530  45.5%     -    4s
# H    0     0                      20.9838534   11.44530  45.5%     -    4s
#      0     2   11.44530    0    7   20.98385   11.44530  45.5%     -    4s
#
# Cutting planes:
#   MIR: 4
#
# Explored 15 nodes (1263 simplex iterations) in 4.52 seconds (2.21 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 20.9839 21.5523
#
# Time limit reached
# Best objective 2.098385344426e+01, best bound 1.144530414239e+01, gap 45.4566%
# [KS] iter 7/9 -> obj=20.9839, gap=0.454566, K^+=1
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 3.97265200000038
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  3.97265200000038
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 372 rows, 981 columns and 197681 nonzeros
# Model fingerprint: 0x20dca6a6
# Model has 595 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 1156 simple general constraints
#   1156 INDICATOR
# Variable types: 947 continuous, 34 integer (34 binary)
# Coefficient statistics:
#   Matrix range     [6e-08, 1e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
#   QRHS range       [2e+01, 2e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 430 rows and 0 columns
# Presolve removed 0 rows and 494 columns
# Presolve time: 0.13s
# Presolved: 803 rows, 607 columns, 44208 nonzeros
# Presolved model has 120 quadratic objective terms
# Presolved model has 120 quadratic constraint(s)
# Variable types: 592 continuous, 15 integer (15 binary)
# Root relaxation presolved: 803 rows, 487 columns, 44088 nonzeros
# Root relaxation presolved model has 120 quadratic objective terms
#
#
# Root relaxation: objective 1.130000e+01, 282 iterations, 0.05 seconds (0.06 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      20.9838516   11.30000  46.1%     -    0s
#      0     0   11.30000    0    6   20.98385   11.30000  46.1%     -    0s
#      0     0   11.30000    0    6   20.98385   11.30000  46.1%     -    0s
#      0     0   11.30000    0    7   20.98385   11.30000  46.1%     -    0s
#      0     0   11.30000    0    7   20.98385   11.30000  46.1%     -    0s
#      0     0   11.30000    0    7   20.98385   11.30000  46.1%     -    0s
#
# Cutting planes:
#   MIR: 7
#   Relax-and-lift: 1
#
# Explored 1 nodes (692 simplex iterations) in 3.98 seconds (1.57 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 20.9839
#
# Time limit reached
# Warning: max constraint violation (1.0546e-06) exceeds tolerance
# Best objective 2.098385164396e+01, best bound 1.129999581090e+01, gap 46.1491%
# [KS] iter 8/9 -> obj=20.9839, gap=0.461491, K^+=0
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 3.1432539000015822e+00
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  3.1432539000015822e+00
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 372 rows, 981 columns and 197681 nonzeros
# Model fingerprint: 0x93980fff
# Model has 595 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 1156 simple general constraints
#   1156 INDICATOR
# Variable types: 947 continuous, 34 integer (34 binary)
# Coefficient statistics:
#   Matrix range     [6e-08, 1e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
#   QRHS range       [2e+01, 2e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 430 rows and 0 columns
# Presolve removed 0 rows and 494 columns
# Presolve time: 0.28s
# Presolved: 803 rows, 607 columns, 44208 nonzeros
# Presolved model has 120 quadratic objective terms
# Presolved model has 120 quadratic constraint(s)
# Variable types: 592 continuous, 15 integer (15 binary)
# Root relaxation presolved: 803 rows, 487 columns, 44088 nonzeros
# Root relaxation presolved model has 120 quadratic objective terms
#
#
# Root relaxation: objective 1.308438e+01, 277 iterations, 0.12 seconds (0.06 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      20.9838500   13.08438  37.6%     -    0s
#      0     0   13.08438    0    6   20.98385   13.08438  37.6%     -    0s
#      0     0   13.08438    0    6   20.98385   13.08438  37.6%     -    0s
#      0     0   13.08438    0    7   20.98385   13.08438  37.6%     -    0s
#      0     0   13.08438    0    7   20.98385   13.08438  37.6%     -    1s
#      0     0   13.08438    0    7   20.98385   13.08438  37.6%     -    1s
#
# Cutting planes:
#   MIR: 5
#
# Explored 1 nodes (681 simplex iterations) in 3.18 seconds (1.08 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 20.9839
#
# Time limit reached
# Warning: max constraint violation (1.9949e-06) exceeds tolerance
# Best objective 2.098384966046e+01, best bound 1.308437994554e+01, gap 37.6455%
# [KS] iter 9/9 -> obj=20.9838, gap=0.376455, K^+=0
# [Alg3] KS#1: UB=20.9838, gap=0.376455
# [Alg3] M=8.8854, ||w||_1/B=3.50092
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 2.6666662777772419e+00
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  2.6666662777772419e+00
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 372 rows, 981 columns and 197681 nonzeros
# Model fingerprint: 0xc785ccce
# Model has 595 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 1156 simple general constraints
#   1156 INDICATOR
# Variable types: 947 continuous, 34 integer (34 binary)
# Coefficient statistics:
#   Matrix range     [6e-08, 1e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
#   QRHS range       [2e+01, 2e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 430 rows and 0 columns
# Presolve removed 0 rows and 494 columns
# Presolve time: 0.28s
# Presolved: 803 rows, 607 columns, 44208 nonzeros
# Presolved model has 120 quadratic objective terms
# Presolved model has 120 quadratic constraint(s)
# Variable types: 592 continuous, 15 integer (15 binary)
# Root relaxation presolved: 803 rows, 487 columns, 44088 nonzeros
# Root relaxation presolved model has 120 quadratic objective terms
#
#
# Root relaxation: objective 1.245688e+01, 249 iterations, 0.11 seconds (0.05 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   12.45688    0    6          -   12.45688      -     -    0s
#      0     0   12.45688    0    6          -   12.45688      -     -    0s
#      0     0   12.45688    0    7          -   12.45688      -     -    1s
#      0     0   12.45688    0    7          -   12.45688      -     -    1s
#      0     0   12.45688    0    7          -   12.45688      -     -    1s
#
# Cutting planes:
#   MIR: 8
#
# Explored 1 nodes (677 simplex iterations) in 2.73 seconds (0.92 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 0
#
# Time limit reached
# Best objective -, best bound 1.245687540171e+01, gap -
# [KS2] iter 1/9 -> obj=inf, gap=inf, K^+=0
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 2.5676877124997191e+00
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  2.5676877124997191e+00
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 372 rows, 981 columns and 197681 nonzeros
# Model fingerprint: 0xc785ccce
# Model has 595 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 1156 simple general constraints
#   1156 INDICATOR
# Variable types: 947 continuous, 34 integer (34 binary)
# Coefficient statistics:
#   Matrix range     [6e-08, 1e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
#   QRHS range       [2e+01, 2e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 430 rows and 0 columns
# Presolve removed 0 rows and 494 columns
# Presolve time: 0.26s
# Presolved: 803 rows, 607 columns, 44208 nonzeros
# Presolved model has 120 quadratic objective terms
# Presolved model has 120 quadratic constraint(s)
# Variable types: 592 continuous, 15 integer (15 binary)
# Root relaxation presolved: 803 rows, 487 columns, 44088 nonzeros
# Root relaxation presolved model has 120 quadratic objective terms
#
#
# Root relaxation: objective 1.245688e+01, 249 iterations, 0.08 seconds (0.05 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   12.45688    0    6          -   12.45688      -     -    0s
#      0     0   12.45688    0    6          -   12.45688      -     -    0s
#      0     0   12.45688    0    7          -   12.45688      -     -    1s
#      0     0   12.45688    0    7          -   12.45688      -     -    1s
#      0     0   12.45688    0    7          -   12.45688      -     -    1s
#
# Cutting planes:
#   MIR: 8
#
# Explored 1 nodes (677 simplex iterations) in 2.59 seconds (0.94 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 0
#
# Time limit reached
# Best objective -, best bound 1.245687540171e+01, gap -
# [KS2] iter 2/9 -> obj=inf, gap=inf, K^+=0
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 2.3914048428570305e+00
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  2.3914048428570305e+00
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 372 rows, 981 columns and 197681 nonzeros
# Model fingerprint: 0x55206fb7
# Model has 595 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 1156 simple general constraints
#   1156 INDICATOR
# Variable types: 947 continuous, 34 integer (34 binary)
# Coefficient statistics:
#   Matrix range     [6e-08, 1e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
#   QRHS range       [2e+01, 2e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 430 rows and 0 columns
# Presolve removed 0 rows and 494 columns
# Presolve time: 0.13s
# Presolved: 803 rows, 607 columns, 38943 nonzeros
# Presolved model has 120 quadratic objective terms
# Presolved model has 120 quadratic constraint(s)
# Variable types: 592 continuous, 15 integer (15 binary)
# Root relaxation presolved: 803 rows, 487 columns, 38823 nonzeros
# Root relaxation presolved model has 120 quadratic objective terms
#
#
# Root relaxation: objective 1.394843e+01, 227 iterations, 0.05 seconds (0.05 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   13.94843    0    5          -   13.94843      -     -    0s
#      0     0   13.94843    0    5          -   13.94843      -     -    0s
#      0     0   13.94843    0    6          -   13.94843      -     -    0s
#      0     0   13.94843    0    6          -   13.94843      -     -    0s
#      0     0   13.94843    0    6          -   13.94843      -     -    1s
#
# Cutting planes:
#   MIR: 13
#   Relax-and-lift: 3
#
# Explored 1 nodes (621 simplex iterations) in 2.47 seconds (1.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 0
#
# Time limit reached
# Best objective -, best bound 1.394843287998e+01, gap -
# [KS2] iter 3/9 -> obj=inf, gap=inf, K^+=0
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 2.2778220000000147e+00
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  2.2778220000000147e+00
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 372 rows, 981 columns and 197681 nonzeros
# Model fingerprint: 0x7d9ee366
# Model has 595 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 1156 simple general constraints
#   1156 INDICATOR
# Variable types: 947 continuous, 34 integer (34 binary)
# Coefficient statistics:
#   Matrix range     [6e-08, 1e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
#   QRHS range       [2e+01, 2e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 430 rows and 0 columns
# Presolve removed 0 rows and 494 columns
# Presolve time: 0.15s
# Presolved: 803 rows, 607 columns, 44208 nonzeros
# Presolved model has 120 quadratic objective terms
# Presolved model has 120 quadratic constraint(s)
# Variable types: 592 continuous, 15 integer (15 binary)
# Root relaxation presolved: 803 rows, 487 columns, 44088 nonzeros
# Root relaxation presolved model has 120 quadratic objective terms
#
#
# Root relaxation: objective 1.266088e+01, 278 iterations, 0.07 seconds (0.06 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   12.66088    0    6          -   12.66088      -     -    0s
#      0     0   12.66088    0    6          -   12.66088      -     -    0s
#      0     0   12.66088    0    7          -   12.66088      -     -    1s
#      0     0   12.66088    0    7          -   12.66088      -     -    1s
#      0     0   12.66088    0    7          -   12.66088      -     -    1s
#
# Cutting planes:
#   MIR: 6
#
# Explored 1 nodes (696 simplex iterations) in 2.35 seconds (0.93 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 0
#
# Time limit reached
# Best objective -, best bound 1.266087580655e+01, gap -
# [KS2] iter 4/9 -> obj=inf, gap=inf, K^+=0
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 2.0394388000000618e+00
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  2.0394388000000618e+00
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 372 rows, 981 columns and 197681 nonzeros
# Model fingerprint: 0x7edb0374
# Model has 595 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 1156 simple general constraints
#   1156 INDICATOR
# Variable types: 947 continuous, 34 integer (34 binary)
# Coefficient statistics:
#   Matrix range     [6e-08, 1e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
#   QRHS range       [2e+01, 2e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 430 rows and 0 columns
# Presolve removed 0 rows and 494 columns
# Presolve time: 0.15s
# Presolved: 803 rows, 607 columns, 44208 nonzeros
# Presolved model has 120 quadratic objective terms
# Presolved model has 120 quadratic constraint(s)
# Variable types: 592 continuous, 15 integer (15 binary)
# Root relaxation presolved: 803 rows, 487 columns, 44088 nonzeros
# Root relaxation presolved model has 120 quadratic objective terms
#
#
# Root relaxation: objective 1.247047e+01, 256 iterations, 0.07 seconds (0.06 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      20.9838499   12.47047  40.6%     -    0s
#      0     0   12.47047    0    6   20.98385   12.47047  40.6%     -    0s
#      0     0   12.47047    0    6   20.98385   12.47047  40.6%     -    0s
#      0     0   12.47047    0    7   20.98385   12.47047  40.6%     -    0s
#      0     0   12.47047    0    7   20.98385   12.47047  40.6%     -    0s
#      0     0   12.47047    0    7   20.98385   12.47047  40.6%     -    0s
#
# Cutting planes:
#   MIR: 7
#
# Explored 1 nodes (654 simplex iterations) in 2.09 seconds (0.74 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 20.9838
#
# Time limit reached
# Warning: max constraint violation (3.2640e-06) exceeds tolerance
# Best objective 2.098384990778e+01, best bound 1.247047251548e+01, gap 40.5711%
# [KS2] iter 5/9 -> obj=20.9838, gap=0.405711, K^+=0
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 1.8754331499985710e+00
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  1.8754331499985710e+00
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 372 rows, 981 columns and 197681 nonzeros
# Model fingerprint: 0xaaa01027
# Model has 595 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 1156 simple general constraints
#   1156 INDICATOR
# Variable types: 947 continuous, 34 integer (34 binary)
# Coefficient statistics:
#   Matrix range     [6e-08, 1e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
#   QRHS range       [2e+01, 2e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 430 rows and 0 columns
# Presolve removed 0 rows and 494 columns
# Presolve time: 0.15s
# Presolved: 803 rows, 607 columns, 44208 nonzeros
# Presolved model has 120 quadratic objective terms
# Presolved model has 120 quadratic constraint(s)
# Variable types: 592 continuous, 15 integer (15 binary)
# Root relaxation presolved: 803 rows, 487 columns, 44088 nonzeros
# Root relaxation presolved model has 120 quadratic objective terms
#
#
# Root relaxation: objective 1.061202e+01, 242 iterations, 0.06 seconds (0.06 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      20.9838484   10.61202  49.4%     -    0s
#      0     0   10.61202    0    6   20.98385   10.61202  49.4%     -    0s
#      0     0   10.61202    0    6   20.98385   10.61202  49.4%     -    0s
#      0     0   10.61202    0    7   20.98385   10.61202  49.4%     -    0s
#      0     0   10.61202    0    7   20.98385   10.61202  49.4%     -    0s
#      0     0   10.61202    0    7   20.98385   10.61202  49.4%     -    1s
#
# Cutting planes:
#   MIR: 4
#
# Explored 1 nodes (672 simplex iterations) in 1.91 seconds (0.67 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 20.9838
#
# Time limit reached
# Warning: max constraint violation (4.9231e-06) exceeds tolerance
# Best objective 2.098384835207e+01, best bound 1.061202359445e+01, gap 49.4277%
# [KS2] iter 6/9 -> obj=20.9838, gap=0.494277, K^+=0
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 1.6195955999986229e+00
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  1.6195955999986229e+00
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 372 rows, 981 columns and 197681 nonzeros
# Model fingerprint: 0xc377bfbb
# Model has 595 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 1156 simple general constraints
#   1156 INDICATOR
# Variable types: 947 continuous, 34 integer (34 binary)
# Coefficient statistics:
#   Matrix range     [6e-08, 1e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
#   QRHS range       [2e+01, 2e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 430 rows and 0 columns
# Presolve removed 0 rows and 494 columns
# Presolve time: 0.14s
# Presolved: 803 rows, 607 columns, 44208 nonzeros
# Presolved model has 120 quadratic objective terms
# Presolved model has 120 quadratic constraint(s)
# Variable types: 592 continuous, 15 integer (15 binary)
# Root relaxation presolved: 803 rows, 487 columns, 44088 nonzeros
# Root relaxation presolved model has 120 quadratic objective terms
#
#
# Root relaxation: objective 1.188230e+01, 237 iterations, 0.06 seconds (0.05 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      20.9838475   11.88230  43.4%     -    0s
#      0     0   11.88230    0    6   20.98385   11.88230  43.4%     -    0s
#      0     0   11.88230    0    6   20.98385   11.88230  43.4%     -    0s
#      0     0   11.88230    0    7   20.98385   11.88230  43.4%     -    0s
#      0     0   11.88230    0    7   20.98385   11.88230  43.4%     -    0s
#      0     0   11.88230    0    7   20.98385   11.88230  43.4%     -    0s
#
# Cutting planes:
#   MIR: 2
#
# Explored 1 nodes (659 simplex iterations) in 1.65 seconds (0.66 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 20.9838
#
# Time limit reached
# Warning: max constraint violation (4.7715e-06) exceeds tolerance
# Best objective 2.098384703341e+01, best bound 1.188230247190e+01, gap 43.3741%
# [KS2] iter 7/9 -> obj=20.9838, gap=0.433741, K^+=1
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 1.1513166000004276e+00
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  1.1513166000004276e+00
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 372 rows, 981 columns and 197681 nonzeros
# Model fingerprint: 0xe5a0f6fd
# Model has 595 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 1156 simple general constraints
#   1156 INDICATOR
# Variable types: 947 continuous, 34 integer (34 binary)
# Coefficient statistics:
#   Matrix range     [6e-08, 1e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
#   QRHS range       [2e+01, 2e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 430 rows and 0 columns
# Presolve removed 0 rows and 494 columns
# Presolve time: 0.20s
# Presolved: 803 rows, 607 columns, 44208 nonzeros
# Presolved model has 120 quadratic objective terms
# Presolved model has 120 quadratic constraint(s)
# Variable types: 592 continuous, 15 integer (15 binary)
# Root relaxation presolved: 803 rows, 487 columns, 44088 nonzeros
# Root relaxation presolved model has 120 quadratic objective terms
#
#
# Root relaxation: objective 1.131742e+01, 260 iterations, 0.13 seconds (0.06 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      20.9838448   11.31742  46.1%     -    0s
#      0     0   11.31742    0    6   20.98384   11.31742  46.1%     -    0s
#      0     0   11.31742    0    6   20.98384   11.31742  46.1%     -    0s
#      0     0   11.31742    0    7   20.98384   11.31742  46.1%     -    1s
#      0     0   11.31742    0    7   20.98384   11.31742  46.1%     -    1s
#
# Cutting planes:
#   MIR: 5
#   Relax-and-lift: 2
#
# Explored 1 nodes (633 simplex iterations) in 1.21 seconds (0.44 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 20.9838
#
# Time limit reached
# Warning: max constraint violation (9.5074e-06) exceeds tolerance
# Best objective 2.098384480261e+01, best bound 1.131741665723e+01, gap 46.0660%
# [KS2] iter 8/9 -> obj=20.9838, gap=0.46066, K^+=0
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 1
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  1
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 372 rows, 981 columns and 197681 nonzeros
# Model fingerprint: 0xcb28b96f
# Model has 595 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 1156 simple general constraints
#   1156 INDICATOR
# Variable types: 947 continuous, 34 integer (34 binary)
# Coefficient statistics:
#   Matrix range     [6e-08, 1e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
#   QRHS range       [2e+01, 2e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 430 rows and 0 columns
# Presolve removed 0 rows and 494 columns
# Presolve time: 0.14s
# Presolved: 803 rows, 607 columns, 44208 nonzeros
# Presolved model has 120 quadratic objective terms
# Presolved model has 120 quadratic constraint(s)
# Variable types: 592 continuous, 15 integer (15 binary)
# Root relaxation presolved: 803 rows, 487 columns, 44088 nonzeros
# Root relaxation presolved model has 120 quadratic objective terms
#
#
# Root relaxation: objective 1.308438e+01, 277 iterations, 0.06 seconds (0.06 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   13.08438    0    6          -   13.08438      -     -    0s
#      0     0   13.08438    0    6          -   13.08438      -     -    0s
#      0     0          -    0               -   13.08438      -     -    1s
#
# Cutting planes:
#   MIR: 11
#
# Explored 1 nodes (394 simplex iterations) in 1.04 seconds (0.56 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 0
#
# Time limit reached
# Best objective -, best bound 1.308437994554e+01, gap -
# [KS2] iter 9/9 -> obj=inf, gap=inf, K^+=0
# [Alg3] Accept KS#2: UB=20.9838, gap=0.46066
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 108
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  108
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 353 rows, 981 columns and 197681 nonzeros
# Model fingerprint: 0xa19fdcf7
# Model has 595 quadratic objective terms
# Model has 1156 simple general constraints
#   1156 INDICATOR
# Variable types: 947 continuous, 34 integer (34 binary)
# Coefficient statistics:
#   Matrix range     [6e-08, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# Loaded user MIP start with objective 351
#
# Presolve removed 2 rows and 35 columns
# Presolve time: 0.18s
# Presolved: 351 rows, 946 columns, 197084 nonzeros
# Presolved model has 1089 SOS constraint(s)
# Presolved model has 561 quadratic objective terms
# Variable types: 912 continuous, 34 integer (34 binary)
# Root relaxation presolved: 350 rows, 912 columns, 197050 nonzeros
# Root relaxation presolved model has 561 quadratic objective terms
#
#
# Root relaxation: objective 2.838499e+00, 109 iterations, 0.33 seconds (0.17 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    2.83850    0  792  351.00000    2.83850  99.2%     -    0s
# H    0     0                     164.9680704    2.83850  98.3%     -    0s
# H    0     0                      28.1074819    2.83850  89.9%     -    1s
#      0     0    2.83850    0  792   28.10748    2.83850  89.9%     -    1s
#      0     2    2.83850    0  792   28.10748    2.83850  89.9%     -    2s
#     63    66    3.20962   11  651   28.10748    2.83850  89.9%  39.3    5s
# *   70    62              12      27.0914208    2.83850  89.5%  78.4    5s
# *   78    62              13      21.7909486    2.83850  87.0%   104    6s
#    130    62    5.14534   19  299   21.79095    2.83850  87.0%   157   10s
# H  240    74                      20.3173567    2.83850  86.0%   136   13s
#    256    95    4.03204    8  600   20.31736    3.03323  85.1%   130   15s
# H  336   116                      19.7596492    3.03323  84.6%   139   19s
#    337   118    5.95975   20  264   19.75965    3.03323  84.6%   139   20s
# H  344   117                      18.7382929    3.03323  83.8%   140   20s
# H  471   131                      17.8198180    3.03323  83.0%   135   24s
#    476   133    3.18635   11  651   17.81982    3.07871  82.7%   135   25s
# H  485   137                      17.0024335    3.07871  81.9%   137   26s
#    575   142     cutoff   21        17.00243    3.07871  81.9%   142   30s
# H  615   145                      15.6051761    3.07871  80.3%   139   31s
#    669   152    3.51100   12  600   15.60518    3.12221  80.0%   139   35s
#    746   154     cutoff   18        15.60518    3.12552  80.0%   142   41s
#    859   170    3.69384   14  504   15.60518    3.22381  79.3%   136   45s
#    985   207     cutoff   13        15.60518    3.22381  79.3%   134   50s
#   1129   241    4.60358   13  459   15.60518    3.22381  79.3%   132   56s
#   1284   282    4.01638   14  459   15.60518    3.23049  79.3%   127   60s
#   1483   295     cutoff   18        15.60518    3.24569  79.2%   125   66s
#   1627   311    4.01101   12  551   15.60518    3.24569  79.2%   124   71s
# H 1706   314                      15.2637430    3.26209  78.6%   124   76s
# H 1761   317                      14.1615682    3.26209  77.0%   126   78s
#   1800   323     cutoff   28        14.16157    3.26209  77.0%   125   81s
#   1953   334    4.63068   16  375   14.16157    3.26942  76.9%   125   86s
#   2041   382    3.55389    5  600   14.16157    3.26942  76.9%   125   90s
#   2184   411   14.03894   23   56   14.16157    3.26942  76.9%   121   96s
#   2288   416    4.93269   18  336   14.16157    3.30180  76.7%   120  100s
#   2424   434    3.71531   12  600   14.16157    3.31820  76.6%   119  108s
#
# Explored 2441 nodes (290539 simplex iterations) in 108.02 seconds (114.24 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 14.1616 15.6052 17.0024 ... 28.1075
#
# Time limit reached
# Best objective 1.416156824879e+01, best bound 3.318200515519e+00, gap 76.5690%
#
# === Comparison (same total time) ===
#                          method      UB  MIPGap runtime  selected_k
# Algorithm-3 (KS+Bounds+BigM+KS) 20.9838 0.46066 120.00s          10
#       Full Co-NLSVM (indicator) 14.1616 0.76569 120.04s          10

# %%
# 读取 UCI 数据
parkinsons = fetch_ucirepo(id=174) 

X_df = parkinsons.data.features
y_series = parkinsons.data.targets['status']

# 清洗与对齐
X_df = X_df.replace('?', np.nan).dropna()
y_series = y_series.loc[X_df.index]

feature_names = list(X_df.columns)
X = StandardScaler().fit_transform(X_df.values)

# 正确的标签编码（0/1 是整数）
y_int = pd.to_numeric(y_series, errors='raise').values
uniq = np.unique(y_int)
assert set(uniq) == {0, 1}, f"意外的类别：{uniq}"
y = np.where(y_int == 0, 1.0, -1.0)  # 0=+1, 1=-1

# 假设你已准备好 X, y（y ∈ {-1,+1}）, 以及 feature_names（可选）
B, C = 5, 1.0
T_total = 120.0   # 两侧统一总时间（秒）
rho = 4

df_cmp = run_comparison(X, y, B, C, total_time=T_total, rho=rho, feature_names=feature_names, verbose=True)
# Out:
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 7.9267643166664739e+00
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  7.9267643166664739e+00
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 212 rows, 471 columns and 49769 nonzeros
# Model fingerprint: 0xa69c3314
# Model has 253 quadratic objective terms
# Model has 484 simple general constraints
#   484 INDICATOR
# Variable types: 449 continuous, 22 integer (22 binary)
# Coefficient statistics:
#   Matrix range     [5e-09, 6e+01]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# Loaded user MIP start with objective 195
#
# Presolve removed 16 rows and 240 columns
# Presolve time: 0.03s
# Presolved: 196 rows, 231 columns, 5857 nonzeros
# Presolved model has 49 SOS constraint(s)
# Presolved model has 28 quadratic objective terms
# Variable types: 224 continuous, 7 integer (7 binary)
# Root relaxation presolved: 195 rows, 224 columns, 5850 nonzeros
# Root relaxation presolved model has 28 quadratic objective terms
#
#
# Root relaxation: objective 5.722712e+01, 390 iterations, 0.02 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   57.22712    0   14  195.00000   57.22712  70.7%     -    0s
# H    0     0                      87.0695877   57.22712  34.3%     -    0s
# H    0     0                      68.4016516   57.22712  16.3%     -    0s
#      0     0   57.22712    0   14   68.40165   57.22712  16.3%     -    0s
#      0     2   57.22712    0   14   68.40165   57.22712  16.3%     -    0s
# H    3     6                      65.7382623   57.22712  12.9%  56.3    0s
# H   11     3                      64.7281608   57.22712  11.6%  39.7    0s
# *   12     3               5      64.6545376   57.22712  11.5%  45.4    0s
# *   14     3               6      60.1689659   57.22712  4.89%  47.3    0s
#
# Explored 31 nodes (1521 simplex iterations) in 0.22 seconds (0.11 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 6: 60.169 64.6545 64.7282 ... 195
#
# Optimal solution found (tolerance 3.00e-02)
# Best objective 6.016896593525e+01, best bound 5.980097532069e+01, gap 0.6116%
# [KS] iter 1/6 -> obj=60.169, gap=0.00611595, K^+=2
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 9.4038845000002773e+00
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  9.4038845000002773e+00
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 212 rows, 471 columns and 49769 nonzeros
# Model fingerprint: 0x421b9a9e
# Model has 253 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 484 simple general constraints
#   484 INDICATOR
# Variable types: 449 continuous, 22 integer (22 binary)
# Coefficient statistics:
#   Matrix range     [5e-09, 6e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
#   QRHS range       [6e+01, 6e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 82 rows and 0 columns
# Presolve removed 0 rows and 240 columns
# Presolve time: 0.03s
# Presolved: 295 rows, 259 columns, 6276 nonzeros
# Presolved model has 28 quadratic objective terms
# Presolved model has 28 quadratic constraint(s)
# Variable types: 252 continuous, 7 integer (7 binary)
# Root relaxation presolved: 295 rows, 231 columns, 6248 nonzeros
# Root relaxation presolved model has 28 quadratic objective terms
#
#
# Root relaxation: objective 4.527220e+01, 286 iterations, 0.04 seconds (0.01 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      60.1689584   45.27220  24.8%     -    0s
#      0     0   45.27220    0    3   60.16896   45.27220  24.8%     -    0s
#      0     0   45.27220    0    3   60.16896   45.27220  24.8%     -    0s
#      0     0   45.27220    0    4   60.16896   45.27220  24.8%     -    0s
#      0     0   45.27220    0    4   60.16896   45.27220  24.8%     -    0s
#      0     0   45.27220    0    4   60.16896   45.27220  24.8%     -    0s
# H    0     0                      54.2071304   45.27220  16.5%     -    0s
#
# Cutting planes:
#   MIR: 1
#
# Explored 1 nodes (402 simplex iterations) in 0.55 seconds (0.18 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 54.2071 60.169
#
# Optimal solution found (tolerance 3.00e-02)
# Best objective 5.420713035090e+01, best bound 5.420713035090e+01, gap 0.0000%
# [KS] iter 2/6 -> obj=54.2071, gap=0, K^+=2
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 1.1559544300000198e+01
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  1.1559544300000198e+01
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 211 rows, 471 columns and 49769 nonzeros
# Model fingerprint: 0x82c2cb45
# Model has 253 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 484 simple general constraints
#   484 INDICATOR
# Variable types: 449 continuous, 22 integer (22 binary)
# Coefficient statistics:
#   Matrix range     [5e-09, 6e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
#   QRHS range       [5e+01, 5e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
# User MIP start violates constraint fix_outside_21 by 1.000000000
#
# Presolve added 113 rows and 0 columns
# Presolve removed 0 rows and 231 columns
# Presolve time: 0.04s
# Presolved: 325 rows, 276 columns, 7905 nonzeros
# Presolved model has 36 quadratic objective terms
# Presolved model has 36 quadratic constraint(s)
# Variable types: 268 continuous, 8 integer (8 binary)
# Root relaxation presolved: 325 rows, 240 columns, 7869 nonzeros
# Root relaxation presolved model has 36 quadratic objective terms
#
#
# Root relaxation: objective 5.672914e+01, 359 iterations, 0.02 seconds (0.01 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   56.72914    0    4          -   56.72914      -     -    0s
#      0     0   56.76220    0    4          -   56.76220      -     -    0s
#      0     0 infeasible    0               - infeasible      -     -    0s
#
# Cutting planes:
#   MIR: 1
#   Relax-and-lift: 2
#
# Explored 1 nodes (1304 simplex iterations) in 0.34 seconds (0.13 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 0
#
# Model is infeasible or unbounded
# Best objective -, best bound -, gap -
# [KS] iter 3/6 -> obj=inf, gap=inf, K^+=0
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 1.5217664066665748e+01
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  1.5217664066665748e+01
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 211 rows, 471 columns and 49769 nonzeros
# Model fingerprint: 0xc3e782a6
# Model has 253 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 484 simple general constraints
#   484 INDICATOR
# Variable types: 449 continuous, 22 integer (22 binary)
# Coefficient statistics:
#   Matrix range     [5e-09, 6e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
#   QRHS range       [5e+01, 5e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
# User MIP start violates constraint fix_outside_21 by 1.000000000
#
# Presolve added 113 rows and 0 columns
# Presolve removed 0 rows and 231 columns
# Presolve time: 0.05s
# Presolved: 325 rows, 276 columns, 7905 nonzeros
# Presolved model has 36 quadratic objective terms
# Presolved model has 36 quadratic constraint(s)
# Variable types: 268 continuous, 8 integer (8 binary)
# Root relaxation presolved: 325 rows, 240 columns, 7869 nonzeros
# Root relaxation presolved model has 36 quadratic objective terms
#
#
# Root relaxation: objective 5.426659e+01, 305 iterations, 0.02 seconds (0.01 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   54.26659    0    4          -   54.26659      -     -    0s
#      0     0   54.26659    0    4          -   54.26659      -     -    0s
#      0     0   54.26659    0    5          -   54.26659      -     -    0s
#      0     0   55.13742    0    4          -   55.13742      -     -    0s
#      0     0 infeasible    0               - infeasible      -     -    0s
#
# Cutting planes:
#   MIR: 8
#   Relax-and-lift: 2
#
# Explored 1 nodes (1242 simplex iterations) in 0.41 seconds (0.14 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 0
#
# Model is infeasible or unbounded
# Best objective -, best bound -, gap -
# [KS] iter 4/6 -> obj=inf, gap=inf, K^+=0
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 2.2483892699998250e+01
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  2.2483892699998250e+01
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 211 rows, 471 columns and 49769 nonzeros
# Model fingerprint: 0x6e499688
# Model has 253 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 484 simple general constraints
#   484 INDICATOR
# Variable types: 449 continuous, 22 integer (22 binary)
# Coefficient statistics:
#   Matrix range     [5e-09, 6e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
#   QRHS range       [5e+01, 5e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
# User MIP start violates constraint fix_outside_21 by 1.000000000
#
# Presolve added 113 rows and 0 columns
# Presolve removed 0 rows and 231 columns
# Presolve time: 0.04s
# Presolved: 325 rows, 276 columns, 7905 nonzeros
# Presolved model has 36 quadratic objective terms
# Presolved model has 36 quadratic constraint(s)
# Variable types: 268 continuous, 8 integer (8 binary)
# Root relaxation presolved: 325 rows, 240 columns, 7869 nonzeros
# Root relaxation presolved model has 36 quadratic objective terms
#
#
# Root relaxation: objective 4.625451e+01, 259 iterations, 0.02 seconds (0.01 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   46.25451    0    4          -   46.25451      -     -    0s
#      0     0   46.25451    0    4          -   46.25451      -     -    0s
#      0     0   46.25451    0    5          -   46.25451      -     -    0s
#      0     0   46.25451    0    5          -   46.25451      -     -    0s
#      0     0   46.25451    0    5          -   46.25451      -     -    0s
#
# Cutting planes:
#   MIR: 2
#
# Explored 1 nodes (383 simplex iterations) in 0.85 seconds (0.32 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 0
#
# Model is infeasible or unbounded
# Best objective -, best bound -, gap -
# [KS] iter 5/6 -> obj=inf, gap=inf, K^+=0
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 4.3921609400000307e+01
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  4.3921609400000307e+01
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 212 rows, 471 columns and 49769 nonzeros
# Model fingerprint: 0x6a4178c5
# Model has 253 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 484 simple general constraints
#   484 INDICATOR
# Variable types: 449 continuous, 22 integer (22 binary)
# Coefficient statistics:
#   Matrix range     [5e-09, 6e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
#   QRHS range       [5e+01, 5e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 82 rows and 0 columns
# Presolve removed 0 rows and 240 columns
# Presolve time: 0.04s
# Presolved: 295 rows, 259 columns, 6276 nonzeros
# Presolved model has 28 quadratic objective terms
# Presolved model has 28 quadratic constraint(s)
# Variable types: 252 continuous, 7 integer (7 binary)
# Root relaxation presolved: 295 rows, 231 columns, 6248 nonzeros
# Root relaxation presolved model has 28 quadratic objective terms
#
#
# Root relaxation: objective 4.234880e+01, 245 iterations, 0.02 seconds (0.01 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      54.2071068   42.34880  21.9%     -    0s
#      0     0   42.34880    0    3   54.20711   42.34880  21.9%     -    0s
#      0     0   42.34880    0    3   54.20711   42.34880  21.9%     -    0s
#      0     0   42.34880    0    4   54.20711   42.34880  21.9%     -    0s
#      0     0   42.34880    0    4   54.20711   42.34880  21.9%     -    0s
#      0     0   42.34880    0    4   54.20711   42.34880  21.9%     -    0s
#
# Cutting planes:
#   MIR: 2
#   Relax-and-lift: 1
#
# Explored 1 nodes (363 simplex iterations) in 0.59 seconds (0.20 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 54.2071
# No other solutions better than 54.2071
#
# Optimal solution found (tolerance 3.00e-02)
# Warning: max constraint violation (6.5155e-06) exceeds tolerance
# Best objective 5.420709290250e+01, best bound 5.420710676086e+01, gap 0.0000%
# [KS] iter 6/6 -> obj=54.2071, gap=0, K^+=0
# [Alg3] KS#1: UB=54.2071, gap=0
# [Alg3] M=11.629, ||w||_1/B=8.8373
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 3.9999989333337
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  3.9999989333337
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 212 rows, 471 columns and 49769 nonzeros
# Model fingerprint: 0xb9b71f50
# Model has 253 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 484 simple general constraints
#   484 INDICATOR
# Variable types: 449 continuous, 22 integer (22 binary)
# Coefficient statistics:
#   Matrix range     [5e-09, 6e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
#   QRHS range       [5e+01, 5e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 82 rows and 0 columns
# Presolve removed 0 rows and 240 columns
# Presolve time: 0.04s
# Presolved: 295 rows, 259 columns, 6276 nonzeros
# Presolved model has 28 quadratic objective terms
# Presolved model has 28 quadratic constraint(s)
# Variable types: 252 continuous, 7 integer (7 binary)
# Root relaxation presolved: 295 rows, 231 columns, 6248 nonzeros
# Root relaxation presolved model has 28 quadratic objective terms
#
#
# Root relaxation: objective 4.605067e+01, 324 iterations, 0.01 seconds (0.01 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   46.05067    0    3          -   46.05067      -     -    0s
#      0     0   46.05067    0    3          -   46.05067      -     -    0s
#      0     0   46.05067    0    4          -   46.05067      -     -    0s
#      0     0   46.05067    0    4          -   46.05067      -     -    0s
#      0     0   46.05067    0    4          -   46.05067      -     -    0s
#
# Cutting planes:
#   MIR: 4
#   Relax-and-lift: 1
#
# Explored 1 nodes (446 simplex iterations) in 0.70 seconds (0.24 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 0
#
# Model is infeasible or unbounded
# Best objective -, best bound -, gap -
# [KS2] iter 1/6 -> obj=inf, gap=inf, K^+=0
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 4.5833727999997791e+00
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  4.5833727999997791e+00
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 212 rows, 471 columns and 49769 nonzeros
# Model fingerprint: 0x65734e04
# Model has 253 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 484 simple general constraints
#   484 INDICATOR
# Variable types: 449 continuous, 22 integer (22 binary)
# Coefficient statistics:
#   Matrix range     [5e-09, 6e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
#   QRHS range       [5e+01, 5e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 82 rows and 0 columns
# Presolve removed 0 rows and 240 columns
# Presolve time: 0.04s
# Presolved: 295 rows, 259 columns, 6276 nonzeros
# Presolved model has 28 quadratic objective terms
# Presolved model has 28 quadratic constraint(s)
# Variable types: 252 continuous, 7 integer (7 binary)
# Root relaxation presolved: 295 rows, 231 columns, 6248 nonzeros
# Root relaxation presolved model has 28 quadratic objective terms
#
#
# Root relaxation: objective 4.527220e+01, 286 iterations, 0.02 seconds (0.01 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   45.27220    0    3          -   45.27220      -     -    0s
#      0     0   45.27220    0    3          -   45.27220      -     -    0s
#      0     0   45.27220    0    4          -   45.27220      -     -    0s
#      0     0   45.27220    0    4          -   45.27220      -     -    0s
#      0     0   45.27220    0    4          -   45.27220      -     -    0s
#
# Cutting planes:
#   MIR: 5
#   Relax-and-lift: 1
#
# Explored 1 nodes (406 simplex iterations) in 0.75 seconds (0.26 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 0
#
# Model is infeasible or unbounded
# Best objective -, best bound -, gap -
# [KS2] iter 2/6 -> obj=inf, gap=inf, K^+=0
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 5.4628881000007823e+00
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  5.4628881000007823e+00
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 210 rows, 471 columns and 49769 nonzeros
# Model fingerprint: 0x13efce9b
# Model has 253 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 484 simple general constraints
#   484 INDICATOR
# Variable types: 449 continuous, 22 integer (22 binary)
# Coefficient statistics:
#   Matrix range     [5e-09, 6e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
#   QRHS range       [5e+01, 5e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 148 rows and 0 columns
# Presolve removed 0 rows and 221 columns
# Presolve time: 0.07s
# Presolved: 359 rows, 295 columns, 9738 nonzeros
# Presolved model has 45 quadratic objective terms
# Presolved model has 45 quadratic constraint(s)
# Variable types: 286 continuous, 9 integer (9 binary)
# Root relaxation presolved: 359 rows, 250 columns, 9693 nonzeros
# Root relaxation presolved model has 45 quadratic objective terms
#
#
# Root relaxation: objective 4.601151e+01, 301 iterations, 0.03 seconds (0.01 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   46.01151    0    5          -   46.01151      -     -    0s
#      0     0   46.01151    0    5          -   46.01151      -     -    0s
#      0     0   46.01151    0    6          -   46.01151      -     -    0s
#      0     0   46.01151    0    6          -   46.01151      -     -    0s
#      0     0   46.01151    0    6          -   46.01151      -     -    0s
# Model proven infeasible by zero objective heuristic
#
# Cutting planes:
#   MIR: 3
#
# Explored 1 nodes (435 simplex iterations) in 1.72 seconds (0.71 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 0
#
# Model is infeasible or unbounded
# Best objective -, best bound 5.817471620473e+01, gap -
# [KS2] iter 3/6 -> obj=inf, gap=inf, K^+=0
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 6.6272802666668822e+00
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  6.6272802666668822e+00
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 210 rows, 471 columns and 49769 nonzeros
# Model fingerprint: 0x9ce9c06f
# Model has 253 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 484 simple general constraints
#   484 INDICATOR
# Variable types: 449 continuous, 22 integer (22 binary)
# Coefficient statistics:
#   Matrix range     [5e-09, 6e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
#   QRHS range       [5e+01, 5e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 148 rows and 0 columns
# Presolve removed 0 rows and 221 columns
# Presolve time: 0.04s
# Presolved: 359 rows, 295 columns, 9738 nonzeros
# Presolved model has 45 quadratic objective terms
# Presolved model has 45 quadratic constraint(s)
# Variable types: 286 continuous, 9 integer (9 binary)
# Root relaxation presolved: 359 rows, 250 columns, 9693 nonzeros
# Root relaxation presolved model has 45 quadratic objective terms
#
#
# Root relaxation: objective 4.677980e+01, 296 iterations, 0.02 seconds (0.01 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   46.77980    0    5          -   46.77980      -     -    0s
#      0     0   46.77980    0    5          -   46.77980      -     -    0s
#      0     0   46.77980    0    6          -   46.77980      -     -    0s
#      0     0   46.77980    0    6          -   46.77980      -     -    0s
#      0     0   46.77980    0    6          -   46.77980      -     -    0s
# Model proven infeasible by zero objective heuristic
#
# Cutting planes:
#   MIR: 2
#
# Explored 1 nodes (426 simplex iterations) in 1.63 seconds (0.78 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 0
#
# Model is infeasible or unbounded
# Best objective -, best bound 4.920392822030e+01, gap -
# [KS2] iter 4/6 -> obj=inf, gap=inf, K^+=0
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 8.9432917500016629e+00
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  8.9432917500016629e+00
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 210 rows, 471 columns and 49769 nonzeros
# Model fingerprint: 0xe32f5368
# Model has 253 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 484 simple general constraints
#   484 INDICATOR
# Variable types: 449 continuous, 22 integer (22 binary)
# Coefficient statistics:
#   Matrix range     [5e-09, 6e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
#   QRHS range       [5e+01, 5e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 148 rows and 0 columns
# Presolve removed 0 rows and 221 columns
# Presolve time: 0.04s
# Presolved: 359 rows, 295 columns, 9738 nonzeros
# Presolved model has 45 quadratic objective terms
# Presolved model has 45 quadratic constraint(s)
# Variable types: 286 continuous, 9 integer (9 binary)
# Root relaxation presolved: 359 rows, 250 columns, 9693 nonzeros
# Root relaxation presolved model has 45 quadratic objective terms
#
#
# Root relaxation: objective 3.787487e+01, 290 iterations, 0.03 seconds (0.01 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   37.87487    0    5          -   37.87487      -     -    0s
#      0     0   37.87487    0    5          -   37.87487      -     -    0s
#      0     0   37.87487    0    6          -   37.87487      -     -    0s
#      0     0   37.87487    0    6          -   37.87487      -     -    0s
#      0     0   37.87487    0    6          -   37.87487      -     -    0s
# Model proven infeasible by zero objective heuristic
#
# Cutting planes:
#   MIR: 3
#
# Explored 1 nodes (444 simplex iterations) in 1.77 seconds (0.90 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 0
#
# Model is infeasible or unbounded
# Best objective -, best bound 4.417505436952e+01, gap -
# [KS2] iter 5/6 -> obj=inf, gap=inf, K^+=0
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 1.5747617599998193e+01
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  1.5747617599998193e+01
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 212 rows, 471 columns and 49769 nonzeros
# Model fingerprint: 0xd93d879e
# Model has 253 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 484 simple general constraints
#   484 INDICATOR
# Variable types: 449 continuous, 22 integer (22 binary)
# Coefficient statistics:
#   Matrix range     [5e-09, 6e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
#   QRHS range       [5e+01, 5e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 82 rows and 0 columns
# Presolve removed 0 rows and 240 columns
# Presolve time: 0.04s
# Presolved: 295 rows, 259 columns, 6276 nonzeros
# Presolved model has 28 quadratic objective terms
# Presolved model has 28 quadratic constraint(s)
# Variable types: 252 continuous, 7 integer (7 binary)
# Root relaxation presolved: 295 rows, 231 columns, 6248 nonzeros
# Root relaxation presolved model has 28 quadratic objective terms
#
#
# Root relaxation: objective 4.234880e+01, 245 iterations, 0.02 seconds (0.01 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   42.34880    0    3          -   42.34880      -     -    0s
#      0     0   42.34880    0    3          -   42.34880      -     -    0s
#      0     0   42.34880    0    4          -   42.34880      -     -    0s
#      0     0   42.34880    0    4          -   42.34880      -     -    0s
#      0     0   42.34880    0    4          -   42.34880      -     -    0s
#
# Cutting planes:
#   MIR: 4
#   Relax-and-lift: 1
#
# Explored 1 nodes (375 simplex iterations) in 0.78 seconds (0.25 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 0
#
# Model is infeasible or unbounded
# Best objective -, best bound -, gap -
# [KS2] iter 6/6 -> obj=inf, gap=inf, K^+=0
# [Alg3] Accept KS#2: UB=54.2071, gap=0
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 108
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  108
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 197 rows, 471 columns and 49769 nonzeros
# Model fingerprint: 0x81d43f90
# Model has 253 quadratic objective terms
# Model has 484 simple general constraints
#   484 INDICATOR
# Variable types: 449 continuous, 22 integer (22 binary)
# Coefficient statistics:
#   Matrix range     [5e-09, 6e+01]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# Loaded user MIP start with objective 195
#
# Presolve removed 1 rows and 0 columns
# Presolve time: 0.03s
# Presolved: 196 rows, 471 columns, 49747 nonzeros
# Presolved model has 484 SOS constraint(s)
# Presolved model has 253 quadratic objective terms
# Variable types: 449 continuous, 22 integer (22 binary)
# Root relaxation presolved: 195 rows, 449 columns, 49725 nonzeros
# Root relaxation presolved model has 253 quadratic objective terms
#
#
# Root relaxation: objective 6.931611e+00, 125 iterations, 0.08 seconds (0.04 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    6.93161    0  374  195.00000    6.93161  96.4%     -    0s
# H    0     0                     115.5813339    6.93161  94.0%     -    0s
# H    0     0                      64.4527868    6.93161  89.2%     -    0s
#      0     0    6.93161    0  374   64.45279    6.93161  89.2%     -    0s
#      0     2    6.93161    0  374   64.45279    6.93161  89.2%     -    0s
# *   34    23               7      57.9362744    6.93161  88.0%  91.2    0s
# H  139    30                      54.2071304    7.34412  86.5%  95.2    1s
#    733    93     cutoff   13        54.20713   16.82114  69.0%  88.0    5s
#   2020   149   44.61506   16   50   54.20713   26.32644  51.4%  77.7   10s
#   2892   176   32.79072   10  176   54.20713   29.69417  45.2%  73.6   15s
#   3677   247     cutoff   15        54.20713   32.52759  40.0%  69.4   20s
#   4780   305   44.39718   13  104   54.20713   36.75678  32.2%  64.4   25s
#   7058   273     cutoff   18        54.20713   42.69692  21.2%  56.2   31s
#
# Explored 9181 nodes (450625 simplex iterations) in 34.79 seconds (46.94 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 54.2071 57.9363 64.4528 195
#
# Optimal solution found (tolerance 3.00e-02)
# Best objective 5.420713035090e+01, best bound 5.420713035090e+01, gap 0.0000%
#
# === Comparison (same total time) ===
#                          method      UB MIPGap runtime  selected_k
# Algorithm-3 (KS+Bounds+BigM+KS) 54.2071      0 120.00s           5
#       Full Co-NLSVM (indicator) 54.2071      0  46.81s           5

# %%
# 读取 UCI 数据
parkinsons = fetch_ucirepo(id=174) 

X_df = parkinsons.data.features
y_series = parkinsons.data.targets['status']

# 清洗与对齐
X_df = X_df.replace('?', np.nan).dropna()
y_series = y_series.loc[X_df.index]

feature_names = list(X_df.columns)
X = StandardScaler().fit_transform(X_df.values)

# 正确的标签编码（0/1 是整数）
y_int = pd.to_numeric(y_series, errors='raise').values
uniq = np.unique(y_int)
assert set(uniq) == {0, 1}, f"意外的类别：{uniq}"
y = np.where(y_int == 0, 1.0, -1.0)  # 0=+1, 1=-1

# 假设你已准备好 X, y（y ∈ {-1,+1}）, 以及 feature_names（可选）
B, C = 10, 1.0
T_total = 120.0   # 两侧统一总时间（秒）
rho = 4

df_cmp = run_comparison(X, y, B, C, total_time=T_total, rho=rho, feature_names=feature_names, verbose=True)
# Out:
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 7.9609018999993468e+00
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  7.9609018999993468e+00
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 204 rows, 471 columns and 49769 nonzeros
# Model fingerprint: 0xc9908bca
# Model has 253 quadratic objective terms
# Model has 484 simple general constraints
#   484 INDICATOR
# Variable types: 449 continuous, 22 integer (22 binary)
# Coefficient statistics:
#   Matrix range     [5e-09, 6e+01]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# Loaded user MIP start with objective 195
#
# Presolve removed 8 rows and 140 columns
# Presolve time: 0.03s
# Presolved: 196 rows, 331 columns, 23805 nonzeros
# Presolved model has 225 SOS constraint(s)
# Presolved model has 120 quadratic objective terms
# Variable types: 316 continuous, 15 integer (15 binary)
# Root relaxation presolved: 195 rows, 316 columns, 23790 nonzeros
# Root relaxation presolved model has 120 quadratic objective terms
#
#
# Root relaxation: objective 1.219153e+01, 129 iterations, 0.03 seconds (0.02 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   12.19153    0   75  195.00000   12.19153  93.7%     -    0s
# H    0     0                      92.2524277   12.19153  86.8%     -    0s
# H    0     0                      42.5357076   12.19153  71.3%     -    0s
#      0     0   12.19153    0   75   42.53571   12.19153  71.3%     -    0s
#      0     2   12.19153    0   75   42.53571   12.19153  71.3%     -    0s
# H   31    33                      39.3453848   12.19153  69.0%  27.7    0s
# *   60    61              10      27.2986166   12.19153  55.3%  33.5    0s
# H   65    64                      24.1837861   12.19153  49.6%  34.6    0s
# *   69    60              11      21.4657928   12.19153  43.2%  36.8    0s
# H  117    68                      20.1660557   14.09849  30.1%  30.4    0s
#
# Explored 379 nodes (6821 simplex iterations) in 1.55 seconds (1.37 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 7: 20.1661 21.4658 24.1838 ... 195
#
# Optimal solution found (tolerance 3.00e-02)
# Best objective 2.016605574037e+01, best bound 2.016605574037e+01, gap 0.0000%
# [KS] iter 1/6 -> obj=20.1661, gap=0, K^+=2
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 9.2052762399995114e+00
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  9.2052762399995114e+00
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 204 rows, 471 columns and 49769 nonzeros
# Model fingerprint: 0x2aaa79f4
# Model has 253 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 484 simple general constraints
#   484 INDICATOR
# Variable types: 449 continuous, 22 integer (22 binary)
# Coefficient statistics:
#   Matrix range     [5e-09, 6e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
#   QRHS range       [2e+01, 2e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 442 rows and 0 columns
# Presolve removed 0 rows and 140 columns
# Presolve time: 0.09s
# Presolved: 647 rows, 451 columns, 25019 nonzeros
# Presolved model has 120 quadratic objective terms
# Presolved model has 120 quadratic constraint(s)
# Variable types: 436 continuous, 15 integer (15 binary)
# Root relaxation presolved: 647 rows, 331 columns, 24899 nonzeros
# Root relaxation presolved model has 120 quadratic objective terms
#
#
# Root relaxation: objective 1.219153e+01, 167 iterations, 0.03 seconds (0.03 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      20.1660557   12.19153  39.5%     -    0s
#      0     0   12.19153    0    6   20.16606   12.19153  39.5%     -    0s
#      0     0   12.19153    0    6   20.16606   12.19153  39.5%     -    0s
#      0     0   12.19153    0    6   20.16606   12.19153  39.5%     -    0s
#      0     0   12.19153    0    6   20.16606   12.19153  39.5%     -    0s
#      0     0   12.19153    0    6   20.16606   12.19153  39.5%     -    0s
#      0     2   12.19153    0    6   20.16606   12.19153  39.5%     -    3s
# H  102    35                      20.1660555   13.75872  31.8%  32.5    3s
#
# Cutting planes:
#   MIR: 1
#
# Explored 388 nodes (12357 simplex iterations) in 4.85 seconds (2.78 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 20.1661
#
# Optimal solution found (tolerance 3.00e-02)
# Best objective 2.016605545598e+01, best bound 1.983732865890e+01, gap 1.6301%
# [KS] iter 2/6 -> obj=20.1661, gap=0.016301, K^+=3
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 1.0243718075000288e+01
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  1.0243718075000288e+01
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 204 rows, 471 columns and 49769 nonzeros
# Model fingerprint: 0xd2764a59
# Model has 253 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 484 simple general constraints
#   484 INDICATOR
# Variable types: 449 continuous, 22 integer (22 binary)
# Coefficient statistics:
#   Matrix range     [5e-09, 6e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
#   QRHS range       [2e+01, 2e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 442 rows and 0 columns
# Presolve removed 0 rows and 140 columns
# Presolve time: 0.08s
# Presolved: 647 rows, 451 columns, 25019 nonzeros
# Presolved model has 120 quadratic objective terms
# Presolved model has 120 quadratic constraint(s)
# Variable types: 436 continuous, 15 integer (15 binary)
# Root relaxation presolved: 647 rows, 331 columns, 24899 nonzeros
# Root relaxation presolved model has 120 quadratic objective terms
#
#
# Root relaxation: objective 1.219153e+01, 167 iterations, 0.03 seconds (0.03 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      20.1660555   12.19153  39.5%     -    0s
#      0     0   12.19153    0    6   20.16606   12.19153  39.5%     -    0s
#      0     0   12.19153    0    6   20.16606   12.19153  39.5%     -    0s
#      0     0   12.19153    0    6   20.16606   12.19153  39.5%     -    0s
#      0     0   12.19153    0    6   20.16606   12.19153  39.5%     -    0s
#      0     0   12.19153    0    6   20.16606   12.19153  39.5%     -    0s
#      0     2   12.19153    0    6   20.16606   12.19153  39.5%     -    3s
# H  102    35                      20.1660553   13.75872  31.8%  32.5    3s
#    319    38     cutoff   13        20.16606   15.90647  21.1%  34.3    5s
#
# Cutting planes:
#   MIR: 1
#
# Explored 393 nodes (13323 simplex iterations) in 5.20 seconds (3.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 20.1661
#
# Optimal solution found (tolerance 3.00e-02)
# Best objective 2.016605534515e+01, best bound 2.016605534515e+01, gap 0.0000%
# [KS] iter 3/6 -> obj=20.1661, gap=0, K^+=2
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 1.1866721200000029e+01
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  1.1866721200000029e+01
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 204 rows, 471 columns and 49769 nonzeros
# Model fingerprint: 0x67dcd080
# Model has 253 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 484 simple general constraints
#   484 INDICATOR
# Variable types: 449 continuous, 22 integer (22 binary)
# Coefficient statistics:
#   Matrix range     [5e-09, 6e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
#   QRHS range       [2e+01, 2e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 442 rows and 0 columns
# Presolve removed 0 rows and 140 columns
# Presolve time: 0.17s
# Presolved: 647 rows, 451 columns, 25019 nonzeros
# Presolved model has 120 quadratic objective terms
# Presolved model has 120 quadratic constraint(s)
# Variable types: 436 continuous, 15 integer (15 binary)
# Root relaxation presolved: 647 rows, 331 columns, 24899 nonzeros
# Root relaxation presolved model has 120 quadratic objective terms
#
#
# Root relaxation: objective 1.277329e+01, 161 iterations, 0.05 seconds (0.02 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      20.1660547   12.77329  36.7%     -    0s
#      0     0   12.77329    0    6   20.16605   12.77329  36.7%     -    0s
#      0     0   12.77329    0    6   20.16605   12.77329  36.7%     -    0s
#      0     0   12.77329    0    6   20.16605   12.77329  36.7%     -    0s
#      0     0   12.77329    0    6   20.16605   12.77329  36.7%     -    0s
#      0     0   12.77329    0    6   20.16605   12.77329  36.7%     -    0s
# H    0     0                      20.1660545   12.77329  36.7%     -    3s
#      0     2   12.77329    0    6   20.16605   12.77329  36.7%     -    3s
#    261    22   19.60640   10    5   20.16605   17.83191  11.6%  31.2    5s
#
# Cutting planes:
#   MIR: 2
#   Relax-and-lift: 1
#
# Explored 327 nodes (9726 simplex iterations) in 5.19 seconds (2.40 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 20.1661
#
# Optimal solution found (tolerance 3.00e-02)
# Best objective 2.016605453320e+01, best bound 2.016605453320e+01, gap 0.0000%
# [KS] iter 4/6 -> obj=20.1661, gap=0, K^+=3
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 1.5105105949998688e+01
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  1.5105105949998688e+01
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 204 rows, 471 columns and 49769 nonzeros
# Model fingerprint: 0x3d81684b
# Model has 253 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 484 simple general constraints
#   484 INDICATOR
# Variable types: 449 continuous, 22 integer (22 binary)
# Coefficient statistics:
#   Matrix range     [5e-09, 6e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
#   QRHS range       [2e+01, 2e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 442 rows and 0 columns
# Presolve removed 0 rows and 140 columns
# Presolve time: 0.06s
# Presolved: 647 rows, 451 columns, 25020 nonzeros
# Presolved model has 120 quadratic objective terms
# Presolved model has 120 quadratic constraint(s)
# Variable types: 436 continuous, 15 integer (15 binary)
# Root relaxation presolved: 647 rows, 331 columns, 24900 nonzeros
# Root relaxation presolved model has 120 quadratic objective terms
#
#
# Root relaxation: objective 1.205786e+01, 150 iterations, 0.03 seconds (0.02 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   12.05786    0    6          -   12.05786      -     -    0s
#      0     0   12.05786    0    6          -   12.05786      -     -    0s
#      0     0   12.05786    0    7          -   12.05786      -     -    0s
#      0     0   12.05786    0    7          -   12.05786      -     -    0s
#      0     0   12.05786    0    7          -   12.05786      -     -    0s
#      0     2   12.05786    0    7          -   12.05786      -     -    7s
#    157    62 infeasible   11               -   12.40543      -   139   10s
#    648   126   17.70665   11    2          -   13.46420      -   133   15s
#
# Cutting planes:
#   MIR: 11
#
# Explored 680 nodes (90419 simplex iterations) in 15.11 seconds (13.60 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 0
#
# Time limit reached
# Best objective -, best bound 1.377999299299e+01, gap -
# [KS] iter 5/6 -> obj=inf, gap=inf, K^+=0
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 1.4937877099997422e+01
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  1.4937877099997422e+01
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 204 rows, 471 columns and 49769 nonzeros
# Model fingerprint: 0x93e133b4
# Model has 253 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 484 simple general constraints
#   484 INDICATOR
# Variable types: 449 continuous, 22 integer (22 binary)
# Coefficient statistics:
#   Matrix range     [5e-09, 6e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
#   QRHS range       [2e+01, 2e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 442 rows and 0 columns
# Presolve removed 0 rows and 140 columns
# Presolve time: 0.07s
# Presolved: 647 rows, 451 columns, 25019 nonzeros
# Presolved model has 120 quadratic objective terms
# Presolved model has 120 quadratic constraint(s)
# Variable types: 436 continuous, 15 integer (15 binary)
# Root relaxation presolved: 647 rows, 331 columns, 24899 nonzeros
# Root relaxation presolved model has 120 quadratic objective terms
#
#
# Root relaxation: objective 1.232002e+01, 160 iterations, 0.03 seconds (0.02 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   12.32002    0    6          -   12.32002      -     -    0s
#      0     0   12.32002    0    6          -   12.32002      -     -    0s
#      0     0   12.32002    0    6          -   12.32002      -     -    0s
#      0     0   12.32002    0    6          -   12.32002      -     -    0s
#      0     0   12.32002    0    6          -   12.32002      -     -    0s
#      0     2   12.32002    0    6          -   12.32002      -     -    8s
#    145    54 infeasible   12               -   12.32002      -   112   10s
#
# Cutting planes:
#   MIR: 9
#
# Explored 581 nodes (77257 simplex iterations) in 14.94 seconds (14.90 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 0
#
# Time limit reached
# Best objective -, best bound 1.437442853005e+01, gap -
# [KS] iter 6/6 -> obj=inf, gap=inf, K^+=0
# [Alg3] KS#1: UB=20.1661, gap=0
# [Alg3] M=11.629, ||w||_1/B=4.41865
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 3.9999995166666245e+00
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  3.9999995166666245e+00
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 204 rows, 471 columns and 49769 nonzeros
# Model fingerprint: 0x56900eeb
# Model has 253 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 484 simple general constraints
#   484 INDICATOR
# Variable types: 449 continuous, 22 integer (22 binary)
# Coefficient statistics:
#   Matrix range     [5e-09, 6e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
#   QRHS range       [2e+01, 2e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 442 rows and 0 columns
# Presolve removed 0 rows and 140 columns
# Presolve time: 0.06s
# Presolved: 647 rows, 451 columns, 25019 nonzeros
# Presolved model has 120 quadratic objective terms
# Presolved model has 120 quadratic constraint(s)
# Variable types: 436 continuous, 15 integer (15 binary)
# Root relaxation presolved: 647 rows, 331 columns, 24899 nonzeros
# Root relaxation presolved model has 120 quadratic objective terms
#
#
# Root relaxation: objective 1.219153e+01, 167 iterations, 0.02 seconds (0.03 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      20.1660549   12.19153  39.5%     -    0s
#      0     0   12.19153    0    6   20.16605   12.19153  39.5%     -    0s
#      0     0   12.19153    0    6   20.16605   12.19153  39.5%     -    0s
#      0     0   12.19153    0    6   20.16605   12.19153  39.5%     -    0s
#      0     0   12.19153    0    6   20.16605   12.19153  39.5%     -    0s
#      0     0   12.19153    0    6   20.16605   12.19153  39.5%     -    0s
#      0     2   12.19153    0    6   20.16605   12.19153  39.5%     -    2s
# H  102    35                      20.1660546   13.75872  31.8%  32.5    3s
#
# Cutting planes:
#   MIR: 1
#
# Explored 276 nodes (9460 simplex iterations) in 4.01 seconds (2.24 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 20.1661
#
# Time limit reached
# Best objective 2.016605460492e+01, best bound 1.594984262610e+01, gap 20.9075%
# [KS2] iter 1/6 -> obj=20.1661, gap=0.209075, K^+=10
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 3.9725052000008874e+00
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  3.9725052000008874e+00
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 204 rows, 471 columns and 49769 nonzeros
# Model fingerprint: 0x56900eeb
# Model has 253 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 484 simple general constraints
#   484 INDICATOR
# Variable types: 449 continuous, 22 integer (22 binary)
# Coefficient statistics:
#   Matrix range     [5e-09, 6e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
#   QRHS range       [2e+01, 2e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 442 rows and 0 columns
# Presolve removed 0 rows and 140 columns
# Presolve time: 0.06s
# Presolved: 647 rows, 451 columns, 25019 nonzeros
# Presolved model has 120 quadratic objective terms
# Presolved model has 120 quadratic constraint(s)
# Variable types: 436 continuous, 15 integer (15 binary)
# Root relaxation presolved: 647 rows, 331 columns, 24899 nonzeros
# Root relaxation presolved model has 120 quadratic objective terms
#
#
# Root relaxation: objective 1.219153e+01, 167 iterations, 0.03 seconds (0.03 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      20.1660549   12.19153  39.5%     -    0s
#      0     0   12.19153    0    6   20.16605   12.19153  39.5%     -    0s
#      0     0   12.19153    0    6   20.16605   12.19153  39.5%     -    0s
#      0     0   12.19153    0    6   20.16605   12.19153  39.5%     -    0s
#      0     0   12.19153    0    6   20.16605   12.19153  39.5%     -    0s
#      0     0   12.19153    0    6   20.16605   12.19153  39.5%     -    0s
#      0     2   12.19153    0    6   20.16605   12.19153  39.5%     -    2s
# H  102    35                      20.1660546   13.75872  31.8%  32.5    3s
#
# Cutting planes:
#   MIR: 1
#
# Explored 270 nodes (9385 simplex iterations) in 3.98 seconds (2.22 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 20.1661
#
# Time limit reached
# Best objective 2.016605460492e+01, best bound 1.594984262610e+01, gap 20.9075%
# [KS2] iter 2/6 -> obj=20.1661, gap=0.209075, K^+=3
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 3.9320160750012292e+00
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  3.9320160750012292e+00
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 204 rows, 471 columns and 49769 nonzeros
# Model fingerprint: 0x56900eeb
# Model has 253 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 484 simple general constraints
#   484 INDICATOR
# Variable types: 449 continuous, 22 integer (22 binary)
# Coefficient statistics:
#   Matrix range     [5e-09, 6e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
#   QRHS range       [2e+01, 2e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 442 rows and 0 columns
# Presolve removed 0 rows and 140 columns
# Presolve time: 0.06s
# Presolved: 647 rows, 451 columns, 25019 nonzeros
# Presolved model has 120 quadratic objective terms
# Presolved model has 120 quadratic constraint(s)
# Variable types: 436 continuous, 15 integer (15 binary)
# Root relaxation presolved: 647 rows, 331 columns, 24899 nonzeros
# Root relaxation presolved model has 120 quadratic objective terms
#
#
# Root relaxation: objective 1.219153e+01, 167 iterations, 0.03 seconds (0.03 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      20.1660549   12.19153  39.5%     -    0s
#      0     0   12.19153    0    6   20.16605   12.19153  39.5%     -    0s
#      0     0   12.19153    0    6   20.16605   12.19153  39.5%     -    0s
#      0     0   12.19153    0    6   20.16605   12.19153  39.5%     -    0s
#      0     0   12.19153    0    6   20.16605   12.19153  39.5%     -    0s
#      0     0   12.19153    0    6   20.16605   12.19153  39.5%     -    0s
#      0     2   12.19153    0    6   20.16605   12.19153  39.5%     -    2s
# H  102    35                      20.1660546   13.75872  31.8%  32.5    3s
#
# Cutting planes:
#   MIR: 1
#
# Explored 247 nodes (8812 simplex iterations) in 3.94 seconds (2.17 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 20.1661
#
# Time limit reached
# Best objective 2.016605460492e+01, best bound 1.566972143013e+01, gap 22.2965%
# [KS2] iter 3/6 -> obj=20.1661, gap=0.222965, K^+=2
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 3.8771405333342650e+00
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  3.8771405333342650e+00
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 204 rows, 471 columns and 49769 nonzeros
# Model fingerprint: 0x4ba9b817
# Model has 253 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 484 simple general constraints
#   484 INDICATOR
# Variable types: 449 continuous, 22 integer (22 binary)
# Coefficient statistics:
#   Matrix range     [5e-09, 6e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
#   QRHS range       [2e+01, 2e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 442 rows and 0 columns
# Presolve removed 0 rows and 140 columns
# Presolve time: 0.07s
# Presolved: 647 rows, 451 columns, 25019 nonzeros
# Presolved model has 120 quadratic objective terms
# Presolved model has 120 quadratic constraint(s)
# Variable types: 436 continuous, 15 integer (15 binary)
# Root relaxation presolved: 647 rows, 331 columns, 24899 nonzeros
# Root relaxation presolved model has 120 quadratic objective terms
#
#
# Root relaxation: objective 1.277329e+01, 161 iterations, 0.03 seconds (0.02 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      20.1660548   12.77329  36.7%     -    0s
#      0     0   12.77329    0    6   20.16605   12.77329  36.7%     -    0s
#      0     0   12.77329    0    6   20.16605   12.77329  36.7%     -    0s
#      0     0   12.77329    0    6   20.16605   12.77329  36.7%     -    0s
#      0     0   12.77329    0    6   20.16605   12.77329  36.7%     -    0s
#      0     0   12.77329    0    6   20.16605   12.77329  36.7%     -    0s
#      0     2   12.77329    0    6   20.16605   12.77329  36.7%     -    3s
#
# Cutting planes:
#   MIR: 2
#   Relax-and-lift: 1
#
# Explored 143 nodes (5649 simplex iterations) in 3.88 seconds (1.96 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 20.1661
#
# Time limit reached
# Warning: max constraint violation (2.2719e-06) exceeds tolerance
# Best objective 2.016605463917e+01, best bound 1.414420988505e+01, gap 29.8613%
# [KS2] iter 4/6 -> obj=20.1661, gap=0.298613, K^+=3
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 3.7887285500000871e+00
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  3.7887285500000871e+00
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 204 rows, 471 columns and 49769 nonzeros
# Model fingerprint: 0x3d81684b
# Model has 253 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 484 simple general constraints
#   484 INDICATOR
# Variable types: 449 continuous, 22 integer (22 binary)
# Coefficient statistics:
#   Matrix range     [5e-09, 6e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
#   QRHS range       [2e+01, 2e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 442 rows and 0 columns
# Presolve removed 0 rows and 140 columns
# Presolve time: 0.06s
# Presolved: 647 rows, 451 columns, 25020 nonzeros
# Presolved model has 120 quadratic objective terms
# Presolved model has 120 quadratic constraint(s)
# Variable types: 436 continuous, 15 integer (15 binary)
# Root relaxation presolved: 647 rows, 331 columns, 24900 nonzeros
# Root relaxation presolved model has 120 quadratic objective terms
#
#
# Root relaxation: objective 1.205786e+01, 150 iterations, 0.02 seconds (0.02 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   12.05786    0    6          -   12.05786      -     -    0s
#      0     0   12.05786    0    6          -   12.05786      -     -    0s
#      0     0   12.05786    0    7          -   12.05786      -     -    0s
#      0     0   12.05786    0    7          -   12.05786      -     -    0s
#      0     0   12.05786    0    7          -   12.05786      -     -    0s
#
# Cutting planes:
#   MIR: 11
#
# Explored 1 nodes (602 simplex iterations) in 3.79 seconds (2.91 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 0
#
# Time limit reached
# Best objective -, best bound 1.205785599588e+01, gap -
# [KS2] iter 5/6 -> obj=inf, gap=inf, K^+=0
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 3.62424540000211
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  3.62424540000211
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 204 rows, 471 columns and 49769 nonzeros
# Model fingerprint: 0x93e133b4
# Model has 253 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 484 simple general constraints
#   484 INDICATOR
# Variable types: 449 continuous, 22 integer (22 binary)
# Coefficient statistics:
#   Matrix range     [5e-09, 6e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
#   QRHS range       [2e+01, 2e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 442 rows and 0 columns
# Presolve removed 0 rows and 140 columns
# Presolve time: 0.07s
# Presolved: 647 rows, 451 columns, 25019 nonzeros
# Presolved model has 120 quadratic objective terms
# Presolved model has 120 quadratic constraint(s)
# Variable types: 436 continuous, 15 integer (15 binary)
# Root relaxation presolved: 647 rows, 331 columns, 24899 nonzeros
# Root relaxation presolved model has 120 quadratic objective terms
#
#
# Root relaxation: objective 1.232002e+01, 160 iterations, 0.03 seconds (0.02 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   12.32002    0    6          -   12.32002      -     -    0s
#      0     0   12.32002    0    6          -   12.32002      -     -    0s
#      0     0   12.32002    0    6          -   12.32002      -     -    0s
#      0     0   12.32002    0    6          -   12.32002      -     -    0s
#      0     0   12.32002    0    6          -   12.32002      -     -    0s
#
# Cutting planes:
#   MIR: 9
#
# Explored 1 nodes (618 simplex iterations) in 3.64 seconds (2.31 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 0
#
# Time limit reached
# Best objective -, best bound 1.232001760181e+01, gap -
# [KS2] iter 6/6 -> obj=inf, gap=inf, K^+=0
# [Alg3] Accept KS#2: UB=20.1661, gap=0
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 108
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  108
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 197 rows, 471 columns and 49769 nonzeros
# Model fingerprint: 0xf36ea4e5
# Model has 253 quadratic objective terms
# Model has 484 simple general constraints
#   484 INDICATOR
# Variable types: 449 continuous, 22 integer (22 binary)
# Coefficient statistics:
#   Matrix range     [5e-09, 6e+01]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# Loaded user MIP start with objective 195
#
# Presolve removed 1 rows and 0 columns
# Presolve time: 0.03s
# Presolved: 196 rows, 471 columns, 49747 nonzeros
# Presolved model has 484 SOS constraint(s)
# Presolved model has 253 quadratic objective terms
# Variable types: 449 continuous, 22 integer (22 binary)
# Root relaxation presolved: 195 rows, 449 columns, 49725 nonzeros
# Root relaxation presolved model has 253 quadratic objective terms
#
#
# Root relaxation: objective 6.931611e+00, 125 iterations, 0.05 seconds (0.04 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    6.93161    0  264  195.00000    6.93161  96.4%     -    0s
# H    0     0                     103.2420411    6.93161  93.3%     -    0s
# H    0     0                      46.3722963    6.93161  85.1%     -    0s
#      0     0    6.93161    0  264   46.37230    6.93161  85.1%     -    0s
#      0     2    6.93161    0  264   46.37230    6.93161  85.1%     -    0s
# *   60    62              11      34.3579519    6.93161  79.8%  30.9    0s
# *   70    63              12      29.8962852    6.93161  76.8%  43.4    1s
# H  156    85                      27.3105799    7.34412  73.1%  47.3    1s
# *  160    85              12      26.7295301    7.34412  72.5%  48.8    1s
# *  187   102              13      24.9108654    7.34412  70.5%  49.1    2s
# H  213   108                      23.5893871    7.52942  68.1%  51.1    2s
# H  345   126                      20.1660557    7.93500  60.7%  50.6    3s
#    612   180   16.72929   10  144   20.16606    8.39388  58.4%  44.3    5s
#   1682   320     cutoff   18        20.16606   10.95497  45.7%  36.3   10s
#   2648   417     cutoff   12        20.16606   12.39327  38.5%  33.1   15s
#   3276   476     cutoff   17        20.16606   13.26882  34.2%  31.4   20s
#   3789   495   18.38431   11  144   20.16606   13.60119  32.6%  30.2   25s
#   4524   530   17.48950   12  119   20.16606   14.40089  28.6%  29.0   30s
#   5602   571   18.44807   15   96   20.16606   15.14331  24.9%  27.3   35s
#   7249   557     cutoff   18        20.16606   16.00871  20.6%  25.4   41s
#   8375   489   19.51338   17   56   20.16606   16.77370  16.8%  24.1   45s
#   9446   414     cutoff   17        20.16606   16.99092  15.7%  23.0   50s
#  10514   228   20.01516   14  119   20.16606   17.42144  13.6%  21.9   56s
#
# Explored 11771 nodes (242009 simplex iterations) in 57.61 seconds (56.95 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 9: 20.1661 23.5894 24.9109 ... 195
#
# Optimal solution found (tolerance 3.00e-02)
# Best objective 2.016605574037e+01, best bound 2.001749919999e+01, gap 0.7367%
#
# === Comparison (same total time) ===
#                          method      UB     MIPGap runtime  selected_k
# Algorithm-3 (KS+Bounds+BigM+KS) 20.1661          0 120.00s          10
#       Full Co-NLSVM (indicator) 20.1661 0.00736666  69.63s          10

# %%
# 读取 UCI 数据
wholesale_customers = fetch_ucirepo(id=292) 

X_df = wholesale_customers.data.features
y_series = wholesale_customers.data.targets['Region']

# 清洗与对齐
X_df = X_df.replace('?', np.nan).dropna()
y_series = y_series.loc[X_df.index]

feature_names = list(X_df.columns)
X = StandardScaler().fit_transform(X_df.values)

# 正确的标签编码
y_int = pd.to_numeric(y_series, errors='raise').values
y = np.where(y_int == 3, 1.0, -1.0)  # 3=1, 1，2=-1

# 假设你已准备好 X, y（y ∈ {-1,+1}）, 以及 feature_names（可选）
B, C = 5, 1.0
T_total = 120.0   # 两侧统一总时间（秒）
rho = 4

df_cmp = run_comparison(X, y, B, C, total_time=T_total, rho=rho, feature_names=feature_names, verbose=True)
# Out:
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 2.3527504350000527e+01
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  2.3527504350000527e+01
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 442 rows, 476 columns and 13214 nonzeros
# Model fingerprint: 0xae32cabe
# Model has 28 quadratic objective terms
# Model has 49 simple general constraints
#   49 INDICATOR
# Variable types: 469 continuous, 7 integer (7 binary)
# Coefficient statistics:
#   Matrix range     [1e-06, 3e+02]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+00]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# Loaded user MIP start with objective 440
#
# Presolve removed 1 rows and 0 columns
# Presolve time: 0.01s
# Presolved: 441 rows, 476 columns, 13207 nonzeros
# Presolved model has 49 SOS constraint(s)
# Presolved model has 28 quadratic objective terms
# Variable types: 469 continuous, 7 integer (7 binary)
# Root relaxation presolved: 440 rows, 469 columns, 13200 nonzeros
# Root relaxation presolved model has 28 quadratic objective terms
#
#
# Root relaxation: objective 2.455554e+02, 1822 iterations, 0.12 seconds (0.10 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  245.55544    0   14  440.00000  245.55544  44.2%     -    0s
# H    0     0                     254.4973387  245.55544  3.51%     -    0s
# H    0     0                     247.8581047  245.55544  0.93%     -    0s
#
# Explored 1 nodes (1822 simplex iterations) in 0.26 seconds (0.14 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 247.858 440
#
# Optimal solution found (tolerance 3.00e-02)
# Best objective 2.478581046517e+02, best bound 2.455554393092e+02, gap 0.9290%
# [KS] iter 1/2 -> obj=247.858, gap=0.00929026, K^+=3
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 4.6637348099997325e+01
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  4.6637348099997325e+01
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 442 rows, 476 columns and 13214 nonzeros
# Model fingerprint: 0x5b6362eb
# Model has 28 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 49 simple general constraints
#   49 INDICATOR
# Variable types: 469 continuous, 7 integer (7 binary)
# Coefficient statistics:
#   Matrix range     [1e-06, 3e+02]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+00]
#   QRHS range       [2e+02, 2e+02]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 97 rows and 0 columns
# Presolve time: 0.04s
# Presolved: 540 rows, 504 columns, 13871 nonzeros
# Presolved model has 28 quadratic objective terms
# Presolved model has 28 quadratic constraint(s)
# Variable types: 497 continuous, 7 integer (7 binary)
# Root relaxation presolved: 540 rows, 476 columns, 13843 nonzeros
# Root relaxation presolved model has 28 quadratic objective terms
#
#
# Root relaxation: objective 2.455554e+02, 2306 iterations, 0.13 seconds (0.13 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                     247.8155541  245.55544  0.91%     -    0s
#      0     0  245.55544    0    3  247.81555  245.55544  0.91%     -    0s
#
# Explored 1 nodes (2306 simplex iterations) in 0.43 seconds (0.25 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 247.816
#
# Optimal solution found (tolerance 3.00e-02)
# Best objective 2.478155541435e+02, best bound 2.455554393092e+02, gap 0.9120%
# [KS] iter 2/2 -> obj=247.816, gap=0.00912015, K^+=2
# [Alg3] KS#1: UB=247.816, gap=0.00912015
# [Alg3] M=22.2628, ||w||_1/B=0.0709714
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 1.1999996850001480e+01
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  1.1999996850001480e+01
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 442 rows, 476 columns and 13214 nonzeros
# Model fingerprint: 0xf0f15a6f
# Model has 28 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 49 simple general constraints
#   49 INDICATOR
# Variable types: 469 continuous, 7 integer (7 binary)
# Coefficient statistics:
#   Matrix range     [1e-06, 3e+02]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+00]
#   QRHS range       [2e+02, 2e+02]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 97 rows and 0 columns
# Presolve time: 0.03s
# Presolved: 540 rows, 504 columns, 13871 nonzeros
# Presolved model has 28 quadratic objective terms
# Presolved model has 28 quadratic constraint(s)
# Variable types: 497 continuous, 7 integer (7 binary)
# Root relaxation presolved: 540 rows, 476 columns, 13843 nonzeros
# Root relaxation presolved model has 28 quadratic objective terms
#
#
# Root relaxation: objective 2.455554e+02, 2306 iterations, 0.12 seconds (0.13 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                     247.8155541  245.55544  0.91%     -    0s
#      0     0  245.55544    0    3  247.81555  245.55544  0.91%     -    0s
#
# Explored 1 nodes (2306 simplex iterations) in 0.44 seconds (0.25 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 247.816
#
# Optimal solution found (tolerance 3.00e-02)
# Best objective 2.478155541435e+02, best bound 2.455554393092e+02, gap 0.9120%
# [KS2] iter 1/2 -> obj=247.816, gap=0.00912015, K^+=5
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 23.4522810999988
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  23.4522810999988
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 442 rows, 476 columns and 13214 nonzeros
# Model fingerprint: 0xf0f15a6f
# Model has 28 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 49 simple general constraints
#   49 INDICATOR
# Variable types: 469 continuous, 7 integer (7 binary)
# Coefficient statistics:
#   Matrix range     [1e-06, 3e+02]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+00]
#   QRHS range       [2e+02, 2e+02]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 97 rows and 0 columns
# Presolve time: 0.03s
# Presolved: 540 rows, 504 columns, 13871 nonzeros
# Presolved model has 28 quadratic objective terms
# Presolved model has 28 quadratic constraint(s)
# Variable types: 497 continuous, 7 integer (7 binary)
# Root relaxation presolved: 540 rows, 476 columns, 13843 nonzeros
# Root relaxation presolved model has 28 quadratic objective terms
#
#
# Root relaxation: objective 2.455554e+02, 2306 iterations, 0.16 seconds (0.13 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                     247.8155541  245.55544  0.91%     -    0s
#      0     0  245.55544    0    3  247.81555  245.55544  0.91%     -    0s
#
# Explored 1 nodes (2306 simplex iterations) in 0.52 seconds (0.25 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 247.816
#
# Optimal solution found (tolerance 3.00e-02)
# Best objective 2.478155541435e+02, best bound 2.455554393092e+02, gap 0.9120%
# [KS2] iter 2/2 -> obj=247.816, gap=0.00912015, K^+=2
# [Alg3] Accept KS#2: UB=247.816, gap=0.00912015
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 108
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  108
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 442 rows, 476 columns and 13214 nonzeros
# Model fingerprint: 0x6ee0b0a1
# Model has 28 quadratic objective terms
# Model has 49 simple general constraints
#   49 INDICATOR
# Variable types: 469 continuous, 7 integer (7 binary)
# Coefficient statistics:
#   Matrix range     [1e-06, 3e+02]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+00]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# Loaded user MIP start with objective 440
#
# Presolve removed 1 rows and 0 columns
# Presolve time: 0.02s
# Presolved: 441 rows, 476 columns, 13207 nonzeros
# Presolved model has 49 SOS constraint(s)
# Presolved model has 28 quadratic objective terms
# Variable types: 469 continuous, 7 integer (7 binary)
# Root relaxation presolved: 440 rows, 469 columns, 13200 nonzeros
# Root relaxation presolved model has 28 quadratic objective terms
#
#
# Root relaxation: objective 2.455554e+02, 1822 iterations, 0.15 seconds (0.10 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  245.55544    0   14  440.00000  245.55544  44.2%     -    0s
# H    0     0                     254.4973387  245.55544  3.51%     -    0s
# H    0     0                     247.8581047  245.55544  0.93%     -    0s
#
# Explored 1 nodes (1822 simplex iterations) in 0.28 seconds (0.14 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 247.858 440
#
# Optimal solution found (tolerance 3.00e-02)
# Best objective 2.478581046517e+02, best bound 2.455554393092e+02, gap 0.9290%
#
# === Comparison (same total time) ===
#                          method      UB     MIPGap runtime  selected_k
# Algorithm-3 (KS+Bounds+BigM+KS) 247.816 0.00912015 120.00s           5
#       Full Co-NLSVM (indicator) 247.858 0.00929026  12.33s           5

# %%
# 读取 UCI 数据
breast_cancer_wisconsin_original = fetch_ucirepo(id=15)

X_df = breast_cancer_wisconsin_original.data.features
y_series = breast_cancer_wisconsin_original.data.targets['Class']

# 清洗与对齐
X_df = X_df.replace('?', np.nan).dropna()
y_series = y_series.loc[X_df.index]

feature_names = list(X_df.columns)
X = StandardScaler().fit_transform(X_df.values)

# 正确的标签编码（2/4 是整数）
y_int = pd.to_numeric(y_series, errors='raise').values
uniq = np.unique(y_int)
assert set(uniq) == {2, 4}, f"意外的类别：{uniq}"
y = np.where(y_int == 2, 1.0, -1.0)  # 2=+1, 4=-1

# 假设你已准备好 X, y（y ∈ {-1,+1}）, 以及 feature_names（可选）
B, C = 5, 1.0
T_total = 120.0   # 两侧统一总时间（秒）
rho = 4

df_cmp = run_comparison(X, y, B, C, total_time=T_total, rho=rho, feature_names=feature_names, verbose=True)
# Out:
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 1.5570850199997949e+01
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  1.5570850199997949e+01
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 687 rows, 738 columns and 32119 nonzeros
# Model fingerprint: 0x1328cec4
# Model has 45 quadratic objective terms
# Model has 81 simple general constraints
#   81 INDICATOR
# Variable types: 729 continuous, 9 integer (9 binary)
# Coefficient statistics:
#   Matrix range     [2e-03, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+00]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# Loaded user MIP start with objective 683
#
# Presolve removed 343 rows and 359 columns
# Presolve time: 0.03s
# Presolved: 344 rows, 379 columns, 10297 nonzeros
# Presolved model has 49 SOS constraint(s)
# Presolved model has 28 quadratic objective terms
# Variable types: 372 continuous, 7 integer (7 binary)
# Root relaxation presolved: 343 rows, 372 columns, 10290 nonzeros
# Root relaxation presolved model has 28 quadratic objective terms
#
#
# Root relaxation: objective 7.543444e+01, 342 iterations, 0.02 seconds (0.02 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   75.43444    0   14  683.00000   75.43444  89.0%     -    0s
# H    0     0                     288.9004940   75.43444  73.9%     -    0s
# H    0     0                     163.1408796   75.43444  53.8%     -    0s
#      0     0   75.43444    0   14  163.14088   75.43444  53.8%     -    0s
# H    0     0                      98.2894637   75.43444  23.3%     -    0s
#      0     2   75.43444    0   14   98.28946   75.43444  23.3%     -    0s
# *   10     6               5      88.9436709   75.43444  15.2%  48.3    0s
# H   11     6                      83.9689537   75.43444  10.2%  43.9    0s
# *   19     6               5      83.4328650   75.43444  9.59%  51.7    0s
# *   20     6               6      81.3116102   75.43444  7.23%  53.0    0s
#
# Explored 28 nodes (1748 simplex iterations) in 0.25 seconds (0.14 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 7: 81.3116 83.4329 83.969 ... 683
#
# Optimal solution found (tolerance 3.00e-02)
# Best objective 8.131161023790e+01, best bound 8.131161023790e+01, gap 0.0000%
# [KS] iter 1/3 -> obj=81.3116, gap=0, K^+=2
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 2.3102714799999376e+01
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  2.3102714799999376e+01
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 687 rows, 738 columns and 32119 nonzeros
# Model fingerprint: 0x74e52bc1
# Model has 45 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 81 simple general constraints
#   81 INDICATOR
# Variable types: 729 continuous, 9 integer (9 binary)
# Coefficient statistics:
#   Matrix range     [2e-03, 2e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+00]
#   QRHS range       [8e+01, 8e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 95 rows and 0 columns
# Presolve removed 0 rows and 19 columns
# Presolve time: 0.05s
# Presolved: 783 rows, 747 columns, 21404 nonzeros
# Presolved model has 28 quadratic objective terms
# Presolved model has 28 quadratic constraint(s)
# Variable types: 740 continuous, 7 integer (7 binary)
# Root relaxation presolved: 783 rows, 719 columns, 21376 nonzeros
# Root relaxation presolved model has 28 quadratic objective terms
#
#
# Root relaxation: objective 7.233063e+01, 462 iterations, 0.06 seconds (0.04 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      81.3116115   72.33063  11.0%     -    0s
# H    0     0                      81.3116102   72.33063  11.0%     -    0s
#      0     0   72.33063    0    3   81.31161   72.33063  11.0%     -    0s
#      0     0   72.33063    0    3   81.31161   72.33063  11.0%     -    0s
#      0     0   76.90263    0    4   81.31161   76.90263  5.42%     -    0s
#      0     0   76.90263    0    4   81.31161   76.90263  5.42%     -    0s
#
# Cutting planes:
#   MIR: 4
#   Relax-and-lift: 2
#
# Explored 1 nodes (571 simplex iterations) in 0.72 seconds (0.30 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 81.3116
#
# Optimal solution found (tolerance 3.00e-02)
# Best objective 8.131161023790e+01, best bound 8.131161023790e+01, gap 0.0000%
# [KS] iter 2/3 -> obj=81.3116, gap=0, K^+=3
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 45.3395681999973
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  45.3395681999973
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 687 rows, 738 columns and 32119 nonzeros
# Model fingerprint: 0x9a37292e
# Model has 45 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 81 simple general constraints
#   81 INDICATOR
# Variable types: 729 continuous, 9 integer (9 binary)
# Coefficient statistics:
#   Matrix range     [2e-03, 2e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+00]
#   QRHS range       [8e+01, 8e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 95 rows and 0 columns
# Presolve removed 0 rows and 19 columns
# Presolve time: 0.07s
# Presolved: 783 rows, 747 columns, 21404 nonzeros
# Presolved model has 28 quadratic objective terms
# Presolved model has 28 quadratic constraint(s)
# Variable types: 740 continuous, 7 integer (7 binary)
# Root relaxation presolved: 783 rows, 719 columns, 21376 nonzeros
# Root relaxation presolved model has 28 quadratic objective terms
#
#
# Root relaxation: objective 5.556166e+01, 379 iterations, 0.06 seconds (0.04 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      81.3116102   55.56166  31.7%     -    0s
#      0     0   55.56166    0    3   81.31161   55.56166  31.7%     -    0s
#      0     0   55.56166    0    3   81.31161   55.56166  31.7%     -    0s
#      0     0   55.56166    0    4   81.31161   55.56166  31.7%     -    0s
#      0     0   55.56166    0    4   81.31161   55.56166  31.7%     -    0s
#      0     0   55.56166    0    4   81.31161   55.56166  31.7%     -    0s
#      0     0   55.56166    0    3   81.31161   55.56166  31.7%     -    1s
#      0     0   55.56166    0    4   81.31161   55.56166  31.7%     -    1s
# H    0     0                      64.4639999   55.56166  13.8%     -    1s
#
# Cutting planes:
#   MIR: 1
#
# Explored 1 nodes (857 simplex iterations) in 1.81 seconds (0.86 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 64.464 81.3116
#
# Optimal solution found (tolerance 3.00e-02)
# Best objective 6.446399988435e+01, best bound 6.446399988435e+01, gap 0.0000%
# [KS] iter 3/3 -> obj=64.464, gap=0, K^+=1
# [Alg3] KS#1: UB=64.464, gap=0
# [Alg3] M=13.2619, ||w||_1/B=3.56932
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 7.9999983333327691e+00
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  7.9999983333327691e+00
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 686 rows, 738 columns and 32119 nonzeros
# Model fingerprint: 0x4a491e45
# Model has 45 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 81 simple general constraints
#   81 INDICATOR
# Variable types: 729 continuous, 9 integer (9 binary)
# Coefficient statistics:
#   Matrix range     [2e-03, 2e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+00]
#   QRHS range       [6e+01, 6e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 126 rows and 0 columns
# Presolve removed 0 rows and 10 columns
# Presolve time: 0.06s
# Presolved: 813 rows, 764 columns, 26937 nonzeros
# Presolved model has 36 quadratic objective terms
# Presolved model has 36 quadratic constraint(s)
# Variable types: 756 continuous, 8 integer (8 binary)
# Root relaxation presolved: 813 rows, 728 columns, 26901 nonzeros
# Root relaxation presolved model has 36 quadratic objective terms
#
#
# Root relaxation: objective 5.097685e+01, 368 iterations, 0.06 seconds (0.05 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      64.4639999   50.97685  20.9%     -    0s
#      0     0   50.97685    0    4   64.46400   50.97685  20.9%     -    0s
#      0     0   50.97685    0    4   64.46400   50.97685  20.9%     -    0s
#      0     0   50.97685    0    5   64.46400   50.97685  20.9%     -    0s
#      0     0   50.97685    0    5   64.46400   50.97685  20.9%     -    0s
#      0     0   50.97685    0    5   64.46400   50.97685  20.9%     -    0s
#      0     0   50.97685    0    4   64.46400   50.97685  20.9%     -    1s
#      0     0   50.97685    0    5   64.46400   50.97685  20.9%     -    1s
#      0     0   50.97685    0    5   64.46400   50.97685  20.9%     -    1s
#
# Cutting planes:
#   MIR: 5
#   Relax-and-lift: 1
#
# Explored 1 nodes (940 simplex iterations) in 2.17 seconds (1.03 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 64.464
#
# Optimal solution found (tolerance 3.00e-02)
# Best objective 6.446399988435e+01, best bound 6.446399988435e+01, gap 0.0000%
# [KS2] iter 1/3 -> obj=64.464, gap=0, K^+=5
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 1.0836965099999361e+01
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  1.0836965099999361e+01
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 687 rows, 738 columns and 32119 nonzeros
# Model fingerprint: 0xf1c3ad6a
# Model has 45 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 81 simple general constraints
#   81 INDICATOR
# Variable types: 729 continuous, 9 integer (9 binary)
# Coefficient statistics:
#   Matrix range     [2e-03, 2e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+00]
#   QRHS range       [6e+01, 6e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 95 rows and 0 columns
# Presolve removed 0 rows and 19 columns
# Presolve time: 0.08s
# Presolved: 783 rows, 747 columns, 21404 nonzeros
# Presolved model has 28 quadratic objective terms
# Presolved model has 28 quadratic constraint(s)
# Variable types: 740 continuous, 7 integer (7 binary)
# Root relaxation presolved: 783 rows, 719 columns, 21376 nonzeros
# Root relaxation presolved model has 28 quadratic objective terms
#
#
# Root relaxation: objective 5.325474e+01, 343 iterations, 0.05 seconds (0.04 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      64.4639999   53.25474  17.4%     -    0s
#      0     0   53.25474    0    3   64.46400   53.25474  17.4%     -    0s
#      0     0   53.25474    0    3   64.46400   53.25474  17.4%     -    0s
#
# Cutting planes:
#   MIR: 5
#   Relax-and-lift: 1
#
# Explored 1 nodes (382 simplex iterations) in 0.78 seconds (0.26 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 64.464
#
# Optimal solution found (tolerance 3.00e-02)
# Best objective 6.446399988435e+01, best bound 6.446399988435e+01, gap 0.0000%
# [KS2] iter 2/3 -> obj=64.464, gap=0, K^+=3
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 2.0664498999998614e+01
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  2.0664498999998614e+01
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 687 rows, 738 columns and 32119 nonzeros
# Model fingerprint: 0x288a30fa
# Model has 45 quadratic objective terms
# Model has 1 quadratic constraint
# Model has 81 simple general constraints
#   81 INDICATOR
# Variable types: 729 continuous, 9 integer (9 binary)
# Coefficient statistics:
#   Matrix range     [2e-03, 2e+01]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+00]
#   QRHS range       [6e+01, 6e+01]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# User MIP start did not produce a new incumbent solution
#
# Presolve added 95 rows and 0 columns
# Presolve removed 0 rows and 19 columns
# Presolve time: 0.07s
# Presolved: 783 rows, 747 columns, 21404 nonzeros
# Presolved model has 28 quadratic objective terms
# Presolved model has 28 quadratic constraint(s)
# Variable types: 740 continuous, 7 integer (7 binary)
# Root relaxation presolved: 783 rows, 719 columns, 21376 nonzeros
# Root relaxation presolved model has 28 quadratic objective terms
#
#
# Root relaxation: objective 5.556166e+01, 379 iterations, 0.03 seconds (0.04 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      64.4639999   55.56166  13.8%     -    0s
#      0     0   55.56166    0    3   64.46400   55.56166  13.8%     -    0s
#      0     0   55.56166    0    3   64.46400   55.56166  13.8%     -    0s
#
# Cutting planes:
#   MIR: 5
#   Relax-and-lift: 1
#
# Explored 1 nodes (414 simplex iterations) in 0.70 seconds (0.27 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 64.464
#
# Optimal solution found (tolerance 3.00e-02)
# Best objective 6.446399988435e+01, best bound 6.446399988435e+01, gap 0.0000%
# [KS2] iter 3/3 -> obj=64.464, gap=0, K^+=1
# [Alg3] Accept KS#2: UB=64.464, gap=0
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 108
# Set parameter MIPGap to value 0.03
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.5
# Set parameter Presolve to value 2
# Set parameter Cuts to value 1
# Set parameter Seed to value 0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  108
# MIPGap  0.03
# Heuristics  0.5
# MIPFocus  1
# Cuts  1
# Presolve  2
#
# Optimize a model with 685 rows, 738 columns and 32119 nonzeros
# Model fingerprint: 0xde59630e
# Model has 45 quadratic objective terms
# Model has 81 simple general constraints
#   81 INDICATOR
# Variable types: 729 continuous, 9 integer (9 binary)
# Coefficient statistics:
#   Matrix range     [2e-03, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+00]
#   GenCon coe range [1e+00, 1e+00]
# Using branch priorities.
#
# Loaded user MIP start with objective 683
#
# Presolve removed 235 rows and 234 columns
# Presolve time: 0.03s
# Presolved: 450 rows, 504 columns, 21112 nonzeros
# Presolved model has 81 SOS constraint(s)
# Presolved model has 45 quadratic objective terms
# Variable types: 495 continuous, 9 integer (9 binary)
# Root relaxation presolved: 449 rows, 495 columns, 21103 nonzeros
# Root relaxation presolved model has 45 quadratic objective terms
#
#
# Root relaxation: objective 4.423776e+01, 318 iterations, 0.04 seconds (0.03 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   44.23776    0   36  683.00000   44.23776  93.5%     -    0s
# H    0     0                     234.8348208   44.23776  81.2%     -    0s
# H    0     0                     128.4777267   44.23776  65.6%     -    0s
#      0     0   44.23776    0   36  128.47773   44.23776  65.6%     -    0s
# H    0     0                      74.0110506   44.23776  40.2%     -    0s
#      0     2   44.23776    0   36   74.01105   44.23776  40.2%     -    0s
# *   10    13               5      73.2216607   44.23776  39.6%  83.1    0s
# H   22    14                      70.2850507   44.23776  37.1%  60.2    0s
# *   39     6               6      66.9584855   55.56166  17.0%  59.1    0s
# *   41     0               7      64.4639999   55.56166  13.8%  60.3    0s
#
# Explored 51 nodes (3188 simplex iterations) in 0.66 seconds (0.39 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 7: 64.464 66.9585 70.2851 ... 683
#
# Optimal solution found (tolerance 3.00e-02)
# Best objective 6.446399988435e+01, best bound 6.446399988435e+01, gap 0.0000%
#
# === Comparison (same total time) ===
#                          method     UB MIPGap runtime  selected_k
# Algorithm-3 (KS+Bounds+BigM+KS) 64.464      0 120.00s           5
#       Full Co-NLSVM (indicator) 64.464      0  12.69s           5
